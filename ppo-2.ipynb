# %%
import os
import gym
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import SubprocVecEnv
from stable_baselines.common.vec_env import DummyVecEnv
from utils.ppo import PPO
from utils.models import Policy

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
LOGS = os.getcwd()

# %%
def makedirs(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
env_name = 'Pendulum-v0'
run_id = 1
n_steps = 250
total_timesteps = 1000000

LOGS = os.path.join(LOGS, env_name, 'run{}'.format(run_id))
makedirs(LOGS)
tb_log = os.path.join(LOGS, 'tb')
makedirs(tb_log)
model_dir = os.path.join(LOGS, 'models')
makedirs(model_dir)
final_model_dir = os.path.join(LOGS, 'model')
n_cpu = 4

# %%
env = SubprocVecEnv([lambda: gym.make(env_name) for i in range(n_cpu)])

model = PPO(Policy, env, n_steps=n_steps, tensorboard_log=tb_log, verbose=1, full_tensorboard_log=True)
model.learn(total_timesteps, env, save_file=os.path.join(model_dir, 'model'))
model.save(final_model_dir)
del model # remove to demonstrate saving and loading
# Out:
# INFO:tensorflow:Summary name model/pi_fc0/w:0 is illegal; using model/pi_fc0/w_0 instead.
# INFO:tensorflow:Summary name model/pi_fc0/b:0 is illegal; using model/pi_fc0/b_0 instead.
# INFO:tensorflow:Summary name model/vf_fc0/w:0 is illegal; using model/vf_fc0/w_0 instead.
# INFO:tensorflow:Summary name model/vf_fc0/b:0 is illegal; using model/vf_fc0/b_0 instead.
# INFO:tensorflow:Summary name model/pi_fc1/w:0 is illegal; using model/pi_fc1/w_0 instead.
# INFO:tensorflow:Summary name model/pi_fc1/b:0 is illegal; using model/pi_fc1/b_0 instead.
# INFO:tensorflow:Summary name model/vf_fc1/w:0 is illegal; using model/vf_fc1/w_0 instead.
# INFO:tensorflow:Summary name model/vf_fc1/b:0 is illegal; using model/vf_fc1/b_0 instead.
# INFO:tensorflow:Summary name model/vf/w:0 is illegal; using model/vf/w_0 instead.
# INFO:tensorflow:Summary name model/vf/b:0 is illegal; using model/vf/b_0 instead.
# INFO:tensorflow:Summary name model/pi/w:0 is illegal; using model/pi/w_0 instead.
# INFO:tensorflow:Summary name model/pi/b:0 is illegal; using model/pi/b_0 instead.
# INFO:tensorflow:Summary name model/pi/logstd:0 is illegal; using model/pi/logstd_0 instead.
# INFO:tensorflow:Summary name model/q/w:0 is illegal; using model/q/w_0 instead.
# INFO:tensorflow:Summary name model/q/b:0 is illegal; using model/q/b_0 instead.
# INFO:tensorflow:Summary name model/pi_fc0/w:0/gradient is illegal; using model/pi_fc0/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc0/b:0/gradient is illegal; using model/pi_fc0/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc0/w:0/gradient is illegal; using model/vf_fc0/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc0/b:0/gradient is illegal; using model/vf_fc0/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc1/w:0/gradient is illegal; using model/pi_fc1/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc1/b:0/gradient is illegal; using model/pi_fc1/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc1/w:0/gradient is illegal; using model/vf_fc1/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc1/b:0/gradient is illegal; using model/vf_fc1/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf/w:0/gradient is illegal; using model/vf/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf/b:0/gradient is illegal; using model/vf/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/w:0/gradient is illegal; using model/pi/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/b:0/gradient is illegal; using model/pi/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/logstd:0/gradient is illegal; using model/pi/logstd_0/gradient instead.
# No of updates: 1000
# Total timesteps : 1000000
# Batch size: 1000
# ---------------------------------------
# | approxkl           | 1.2642167e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00354        |
# | fps                | 542            |
# | nupdates           | 1              |
# | policy_entropy     | 1.4200308      |
# | policy_loss        | -0.00026630997 |
# | serial_timesteps   | 250            |
# | time_elapsed       | 0.000196       |
# | total_timesteps    | 1008           |
# | value_loss         | 3397.4397      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 6.9980706e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.000301       |
# | fps                | 1013           |
# | nupdates           | 2              |
# | policy_entropy     | 1.4217908      |
# | policy_loss        | -0.00043111094 |
# | serial_timesteps   | 500            |
# | time_elapsed       | 1.85           |
# | total_timesteps    | 2016           |
# | value_loss         | 4322.1016      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00030845025 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00125       |
# | fps                | 969           |
# | nupdates           | 3             |
# | policy_entropy     | 1.4229183     |
# | policy_loss        | -0.0008772357 |
# | serial_timesteps   | 750           |
# | time_elapsed       | 2.84          |
# | total_timesteps    | 3024          |
# | value_loss         | 3461.5444     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.697317e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00307       |
# | fps                | 967           |
# | nupdates           | 4             |
# | policy_entropy     | 1.4251753     |
# | policy_loss        | 0.00017008805 |
# | serial_timesteps   | 1000          |
# | time_elapsed       | 3.87          |
# | total_timesteps    | 4032          |
# | value_loss         | 4630.335      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.6031172e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00917        |
# | fps                | 981            |
# | nupdates           | 5              |
# | policy_entropy     | 1.4267488      |
# | policy_loss        | -0.00016314142 |
# | serial_timesteps   | 1250           |
# | time_elapsed       | 4.91           |
# | total_timesteps    | 5040           |
# | value_loss         | 4090.2388      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.1276197e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0133        |
# | fps                | 930           |
# | nupdates           | 6             |
# | policy_entropy     | 1.4277449     |
# | policy_loss        | 2.003938e-05  |
# | serial_timesteps   | 1500          |
# | time_elapsed       | 5.93          |
# | total_timesteps    | 6048          |
# | value_loss         | 4300.191      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011548978 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.022         |
# | fps                | 955           |
# | nupdates           | 7             |
# | policy_entropy     | 1.4281522     |
# | policy_loss        | -0.0006523654 |
# | serial_timesteps   | 1750          |
# | time_elapsed       | 7.01          |
# | total_timesteps    | 7056          |
# | value_loss         | 3636.7441     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.0593044e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0182        |
# | fps                | 955           |
# | nupdates           | 8             |
# | policy_entropy     | 1.428181      |
# | policy_loss        | 0.00018957099 |
# | serial_timesteps   | 2000          |
# | time_elapsed       | 8.06          |
# | total_timesteps    | 8064          |
# | value_loss         | 4334.824      |
# --------------------------------------
# ----------------------------------------
# | approxkl           | 8.326069e-05    |
# | clipfrac           | 0.0             |
# | explained_variance | 0.024           |
# | fps                | 978             |
# | nupdates           | 9               |
# | policy_entropy     | 1.4274489       |
# | policy_loss        | -0.000120071236 |
# | serial_timesteps   | 2250            |
# | time_elapsed       | 9.11            |
# | total_timesteps    | 9072            |
# | value_loss         | 4815.2354       |
# ----------------------------------------
# ---------------------------------------
# | approxkl           | 7.1093077e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0284         |
# | fps                | 875            |
# | nupdates           | 10             |
# | policy_entropy     | 1.4276003      |
# | policy_loss        | -4.7761354e-05 |
# | serial_timesteps   | 2500           |
# | time_elapsed       | 10.1           |
# | total_timesteps    | 10080          |
# | value_loss         | 5184.318       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00010419947 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.038         |
# | fps                | 923           |
# | nupdates           | 11            |
# | policy_entropy     | 1.4285152     |
# | policy_loss        | -0.0005777471 |
# | serial_timesteps   | 2750          |
# | time_elapsed       | 11.3          |
# | total_timesteps    | 11088         |
# | value_loss         | 4804.6626     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.4624583e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0348        |
# | fps                | 953           |
# | nupdates           | 12            |
# | policy_entropy     | 1.429468      |
# | policy_loss        | 0.0001518665  |
# | serial_timesteps   | 3000          |
# | time_elapsed       | 12.4          |
# | total_timesteps    | 12096         |
# | value_loss         | 3227.9985     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.929981e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0498         |
# | fps                | 930            |
# | nupdates           | 13             |
# | policy_entropy     | 1.4293364      |
# | policy_loss        | -4.7711954e-05 |
# | serial_timesteps   | 3250           |
# | time_elapsed       | 13.4           |
# | total_timesteps    | 13104          |
# | value_loss         | 4663.3228      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 5.177143e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0384         |
# | fps                | 955            |
# | nupdates           | 14             |
# | policy_entropy     | 1.429211       |
# | policy_loss        | -0.00026778958 |
# | serial_timesteps   | 3500           |
# | time_elapsed       | 14.5           |
# | total_timesteps    | 14112          |
# | value_loss         | 5376.831       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.0283387e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0568        |
# | fps                | 955           |
# | nupdates           | 15            |
# | policy_entropy     | 1.4298829     |
# | policy_loss        | 0.00032665266 |
# | serial_timesteps   | 3750          |
# | time_elapsed       | 15.6          |
# | total_timesteps    | 15120         |
# | value_loss         | 4065.123      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 3.753764e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0484       |
# | fps                | 952          |
# | nupdates           | 16           |
# | policy_entropy     | 1.4293816    |
# | policy_loss        | 3.08777e-05  |
# | serial_timesteps   | 4000         |
# | time_elapsed       | 16.6         |
# | total_timesteps    | 16128        |
# | value_loss         | 6157.0474    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 2.8088956e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0629        |
# | fps                | 986           |
# | nupdates           | 17            |
# | policy_entropy     | 1.4311979     |
# | policy_loss        | 0.00012668593 |
# | serial_timesteps   | 4250          |
# | time_elapsed       | 17.7          |
# | total_timesteps    | 17136         |
# | value_loss         | 4580.1455     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.4039822e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.067         |
# | fps                | 970           |
# | nupdates           | 18            |
# | policy_entropy     | 1.4321942     |
# | policy_loss        | -0.000140017  |
# | serial_timesteps   | 4500          |
# | time_elapsed       | 18.7          |
# | total_timesteps    | 18144         |
# | value_loss         | 4231.2295     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.1561695e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.078          |
# | fps                | 942            |
# | nupdates           | 19             |
# | policy_entropy     | 1.4319371      |
# | policy_loss        | -0.00069670996 |
# | serial_timesteps   | 4750           |
# | time_elapsed       | 19.7           |
# | total_timesteps    | 19152          |
# | value_loss         | 4293.4336      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 8.352262e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0773       |
# | fps                | 993          |
# | nupdates           | 20           |
# | policy_entropy     | 1.432408     |
# | policy_loss        | 7.803721e-05 |
# | serial_timesteps   | 5000         |
# | time_elapsed       | 20.8         |
# | total_timesteps    | 20160        |
# | value_loss         | 4075.1282    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 3.3922302e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0695        |
# | fps                | 983           |
# | nupdates           | 21            |
# | policy_entropy     | 1.4327266     |
# | policy_loss        | 4.6793342e-05 |
# | serial_timesteps   | 5250          |
# | time_elapsed       | 21.8          |
# | total_timesteps    | 21168         |
# | value_loss         | 4537.0376     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.1132933e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0823        |
# | fps                | 1035          |
# | nupdates           | 22            |
# | policy_entropy     | 1.4320321     |
# | policy_loss        | 0.00011017213 |
# | serial_timesteps   | 5500          |
# | time_elapsed       | 22.8          |
# | total_timesteps    | 22176         |
# | value_loss         | 3814.533      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.2222706e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0745        |
# | fps                | 957           |
# | nupdates           | 23            |
# | policy_entropy     | 1.4325529     |
# | policy_loss        | 1.7237817e-05 |
# | serial_timesteps   | 5750          |
# | time_elapsed       | 23.8          |
# | total_timesteps    | 23184         |
# | value_loss         | 3894.4482     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000118069314 |
# | clipfrac           | 0.0            |
# | explained_variance | 0.057          |
# | fps                | 955            |
# | nupdates           | 24             |
# | policy_entropy     | 1.4329156      |
# | policy_loss        | 2.6086473e-05  |
# | serial_timesteps   | 6000           |
# | time_elapsed       | 24.8           |
# | total_timesteps    | 24192          |
# | value_loss         | 2855.3804      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.01785645e-05 |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0779         |
# | fps                | 984            |
# | nupdates           | 25             |
# | policy_entropy     | 1.4329575      |
# | policy_loss        | -0.00010390294 |
# | serial_timesteps   | 6250           |
# | time_elapsed       | 25.9           |
# | total_timesteps    | 25200          |
# | value_loss         | 4382.8936      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.941035e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0761        |
# | fps                | 962           |
# | nupdates           | 26            |
# | policy_entropy     | 1.4327191     |
# | policy_loss        | -0.0005638987 |
# | serial_timesteps   | 6500          |
# | time_elapsed       | 26.9          |
# | total_timesteps    | 26208         |
# | value_loss         | 4875.4116     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0035690828  |
# | clipfrac           | 0.047250003   |
# | explained_variance | 0.0898        |
# | fps                | 1009          |
# | nupdates           | 27            |
# | policy_entropy     | 1.4358472     |
# | policy_loss        | -0.0002829402 |
# | serial_timesteps   | 6750          |
# | time_elapsed       | 27.9          |
# | total_timesteps    | 27216         |
# | value_loss         | 5029.2344     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00017160701 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0617        |
# | fps                | 963           |
# | nupdates           | 28            |
# | policy_entropy     | 1.437661      |
# | policy_loss        | 0.000419106   |
# | serial_timesteps   | 7000          |
# | time_elapsed       | 28.9          |
# | total_timesteps    | 28224         |
# | value_loss         | 3540.469      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.3413896e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.083         |
# | fps                | 940           |
# | nupdates           | 29            |
# | policy_entropy     | 1.4381051     |
# | policy_loss        | -2.084315e-05 |
# | serial_timesteps   | 7250          |
# | time_elapsed       | 30            |
# | total_timesteps    | 29232         |
# | value_loss         | 4045.2612     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 2.243118e-07 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0495       |
# | fps                | 954          |
# | nupdates           | 30           |
# | policy_entropy     | 1.4383502    |
# | policy_loss        | 8.148521e-06 |
# | serial_timesteps   | 7500         |
# | time_elapsed       | 31           |
# | total_timesteps    | 30240        |
# | value_loss         | 3468.83      |
# -------------------------------------
# --------------------------------------
# | approxkl           | 8.447887e-07  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0697        |
# | fps                | 943           |
# | nupdates           | 31            |
# | policy_entropy     | 1.4385039     |
# | policy_loss        | -7.323733e-05 |
# | serial_timesteps   | 7750          |
# | time_elapsed       | 32.1          |
# | total_timesteps    | 31248         |
# | value_loss         | 4034.9895     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0019662706 |
# | clipfrac           | 0.007        |
# | explained_variance | 0.046        |
# | fps                | 987          |
# | nupdates           | 32           |
# | policy_entropy     | 1.4382539    |
# | policy_loss        | -0.004003884 |
# | serial_timesteps   | 8000         |
# | time_elapsed       | 33.2         |
# | total_timesteps    | 32256        |
# | value_loss         | 3259.209     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 4.6474463e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0786        |
# | fps                | 969           |
# | nupdates           | 33            |
# | policy_entropy     | 1.4381133     |
# | policy_loss        | 5.9469996e-05 |
# | serial_timesteps   | 8250          |
# | time_elapsed       | 34.2          |
# | total_timesteps    | 33264         |
# | value_loss         | 3299.2964     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.832165e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0778        |
# | fps                | 952           |
# | nupdates           | 34            |
# | policy_entropy     | 1.4417081     |
# | policy_loss        | -0.0004003277 |
# | serial_timesteps   | 8500          |
# | time_elapsed       | 35.2          |
# | total_timesteps    | 34272         |
# | value_loss         | 4053.3987     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 6.7253e-06     |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0888         |
# | fps                | 969            |
# | nupdates           | 35             |
# | policy_entropy     | 1.4436601      |
# | policy_loss        | -0.00012204923 |
# | serial_timesteps   | 8750           |
# | time_elapsed       | 36.3           |
# | total_timesteps    | 35280          |
# | value_loss         | 4243.2417      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0006190707  |
# | clipfrac           | 0.0005        |
# | explained_variance | 0.082         |
# | fps                | 950           |
# | nupdates           | 36            |
# | policy_entropy     | 1.4424095     |
# | policy_loss        | -0.0006459781 |
# | serial_timesteps   | 9000          |
# | time_elapsed       | 37.3          |
# | total_timesteps    | 36288         |
# | value_loss         | 3846.051      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.6456775e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0888        |
# | fps                | 1012          |
# | nupdates           | 37            |
# | policy_entropy     | 1.4415585     |
# | policy_loss        | 0.00012392255 |
# | serial_timesteps   | 9250          |
# | time_elapsed       | 38.4          |
# | total_timesteps    | 37296         |
# | value_loss         | 4069.9983     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0003348421 |
# | clipfrac           | 0.00025      |
# | explained_variance | 0.0922       |
# | fps                | 976          |
# | nupdates           | 38           |
# | policy_entropy     | 1.4449072    |
# | policy_loss        | 0.0002549482 |
# | serial_timesteps   | 9500         |
# | time_elapsed       | 39.4         |
# | total_timesteps    | 38304        |
# | value_loss         | 4153.118     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 5.1001607e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0821        |
# | fps                | 965           |
# | nupdates           | 39            |
# | policy_entropy     | 1.4465874     |
# | policy_loss        | 0.00019396386 |
# | serial_timesteps   | 9750          |
# | time_elapsed       | 40.4          |
# | total_timesteps    | 39312         |
# | value_loss         | 3337.352      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00021233197 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0758        |
# | fps                | 993           |
# | nupdates           | 40            |
# | policy_entropy     | 1.4463042     |
# | policy_loss        | 0.00023844047 |
# | serial_timesteps   | 10000         |
# | time_elapsed       | 41.4          |
# | total_timesteps    | 40320         |
# | value_loss         | 3699.5847     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013125633 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0706        |
# | fps                | 954           |
# | nupdates           | 41            |
# | policy_entropy     | 1.4475485     |
# | policy_loss        | 0.0006313902  |
# | serial_timesteps   | 10250         |
# | time_elapsed       | 42.4          |
# | total_timesteps    | 41328         |
# | value_loss         | 4172.9087     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003671829  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0852        |
# | fps                | 1021          |
# | nupdates           | 42            |
# | policy_entropy     | 1.451069      |
# | policy_loss        | 4.7051006e-05 |
# | serial_timesteps   | 10500         |
# | time_elapsed       | 43.5          |
# | total_timesteps    | 42336         |
# | value_loss         | 3510.195      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.9337309e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0789        |
# | fps                | 987           |
# | nupdates           | 43            |
# | policy_entropy     | 1.4529634     |
# | policy_loss        | 0.00017077147 |
# | serial_timesteps   | 10750         |
# | time_elapsed       | 44.5          |
# | total_timesteps    | 43344         |
# | value_loss         | 3554.9546     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0010727406 |
# | clipfrac           | 0.0025       |
# | explained_variance | 0.0491       |
# | fps                | 985          |
# | nupdates           | 44           |
# | policy_entropy     | 1.4542534    |
# | policy_loss        | 0.0004653953 |
# | serial_timesteps   | 11000        |
# | time_elapsed       | 45.5         |
# | total_timesteps    | 44352        |
# | value_loss         | 2865.1885    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 1.9273895e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0418        |
# | fps                | 990           |
# | nupdates           | 45            |
# | policy_entropy     | 1.4550248     |
# | policy_loss        | 0.00016365238 |
# | serial_timesteps   | 11250         |
# | time_elapsed       | 46.5          |
# | total_timesteps    | 45360         |
# | value_loss         | 6074.0273     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.3566342e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0825        |
# | fps                | 965           |
# | nupdates           | 46            |
# | policy_entropy     | 1.4552053     |
# | policy_loss        | 1.2952562e-05 |
# | serial_timesteps   | 11500         |
# | time_elapsed       | 47.5          |
# | total_timesteps    | 46368         |
# | value_loss         | 4660.9795     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 6.0266466e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0716         |
# | fps                | 982            |
# | nupdates           | 47             |
# | policy_entropy     | 1.4584583      |
# | policy_loss        | -0.00014844647 |
# | serial_timesteps   | 11750          |
# | time_elapsed       | 48.6           |
# | total_timesteps    | 47376          |
# | value_loss         | 5552.3447      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 8.447119e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0788        |
# | fps                | 974           |
# | nupdates           | 48            |
# | policy_entropy     | 1.4602449     |
# | policy_loss        | -6.960711e-05 |
# | serial_timesteps   | 12000         |
# | time_elapsed       | 49.6          |
# | total_timesteps    | 48384         |
# | value_loss         | 4153.5864     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002512146  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0671        |
# | fps                | 986           |
# | nupdates           | 49            |
# | policy_entropy     | 1.4592891     |
# | policy_loss        | 0.00084438425 |
# | serial_timesteps   | 12250         |
# | time_elapsed       | 50.6          |
# | total_timesteps    | 49392         |
# | value_loss         | 3869.6816     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.6317817e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0824        |
# | fps                | 1001          |
# | nupdates           | 50            |
# | policy_entropy     | 1.4587222     |
# | policy_loss        | 9.300792e-05  |
# | serial_timesteps   | 12500         |
# | time_elapsed       | 51.6          |
# | total_timesteps    | 50400         |
# | value_loss         | 5030.4        |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 9.769022e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0932         |
# | fps                | 1003           |
# | nupdates           | 51             |
# | policy_entropy     | 1.4590006      |
# | policy_loss        | -1.5521255e-07 |
# | serial_timesteps   | 12750          |
# | time_elapsed       | 52.6           |
# | total_timesteps    | 51408          |
# | value_loss         | 3525.0679      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00011596909  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0478         |
# | fps                | 1007           |
# | nupdates           | 52             |
# | policy_entropy     | 1.4624285      |
# | policy_loss        | -3.4637786e-05 |
# | serial_timesteps   | 13000          |
# | time_elapsed       | 53.6           |
# | total_timesteps    | 52416          |
# | value_loss         | 4848.2017      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 8.159483e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0781         |
# | fps                | 957            |
# | nupdates           | 53             |
# | policy_entropy     | 1.4640737      |
# | policy_loss        | -5.2715553e-05 |
# | serial_timesteps   | 13250          |
# | time_elapsed       | 54.6           |
# | total_timesteps    | 53424          |
# | value_loss         | 4208.08        |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00032367505 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0812        |
# | fps                | 954           |
# | nupdates           | 54            |
# | policy_entropy     | 1.4624821     |
# | policy_loss        | 0.00078734034 |
# | serial_timesteps   | 13500         |
# | time_elapsed       | 55.7          |
# | total_timesteps    | 54432         |
# | value_loss         | 4548.2256     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.0248378e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.078         |
# | fps                | 952           |
# | nupdates           | 55            |
# | policy_entropy     | 1.4616896     |
# | policy_loss        | 1.8933086e-05 |
# | serial_timesteps   | 13750         |
# | time_elapsed       | 56.7          |
# | total_timesteps    | 55440         |
# | value_loss         | 4044.9878     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.429138e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0731         |
# | fps                | 972            |
# | nupdates           | 56             |
# | policy_entropy     | 1.4631653      |
# | policy_loss        | -4.7377354e-05 |
# | serial_timesteps   | 14000          |
# | time_elapsed       | 57.8           |
# | total_timesteps    | 56448          |
# | value_loss         | 2729.3535      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.5176614e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0776        |
# | fps                | 1022          |
# | nupdates           | 57            |
# | policy_entropy     | 1.4636875     |
# | policy_loss        | -1.547423e-05 |
# | serial_timesteps   | 14250         |
# | time_elapsed       | 58.8          |
# | total_timesteps    | 57456         |
# | value_loss         | 2819.5112     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014968458 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0843        |
# | fps                | 914           |
# | nupdates           | 58            |
# | policy_entropy     | 1.4630469     |
# | policy_loss        | -0.000511333  |
# | serial_timesteps   | 14500         |
# | time_elapsed       | 59.8          |
# | total_timesteps    | 58464         |
# | value_loss         | 3178.517      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00019055778  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0914         |
# | fps                | 979            |
# | nupdates           | 59             |
# | policy_entropy     | 1.4640208      |
# | policy_loss        | -0.00034472722 |
# | serial_timesteps   | 14750          |
# | time_elapsed       | 60.9           |
# | total_timesteps    | 59472          |
# | value_loss         | 3188.6975      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.6572781e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0715        |
# | fps                | 985           |
# | nupdates           | 60            |
# | policy_entropy     | 1.4641287     |
# | policy_loss        | -1.370312e-06 |
# | serial_timesteps   | 15000         |
# | time_elapsed       | 61.9          |
# | total_timesteps    | 60480         |
# | value_loss         | 3573.0654     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.7247457e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0739        |
# | fps                | 948           |
# | nupdates           | 61            |
# | policy_entropy     | 1.4644616     |
# | policy_loss        | 1.8388926e-05 |
# | serial_timesteps   | 15250         |
# | time_elapsed       | 62.9          |
# | total_timesteps    | 61488         |
# | value_loss         | 4195.2217     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.2698822e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.072          |
# | fps                | 976            |
# | nupdates           | 62             |
# | policy_entropy     | 1.4644928      |
# | policy_loss        | -4.9261166e-06 |
# | serial_timesteps   | 15500          |
# | time_elapsed       | 64             |
# | total_timesteps    | 62496          |
# | value_loss         | 3835.347       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.1782247e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0617        |
# | fps                | 937           |
# | nupdates           | 63            |
# | policy_entropy     | 1.4637526     |
# | policy_loss        | 4.4247423e-05 |
# | serial_timesteps   | 15750         |
# | time_elapsed       | 65            |
# | total_timesteps    | 63504         |
# | value_loss         | 3973.4956     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.6240701e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0437        |
# | fps                | 943           |
# | nupdates           | 64            |
# | policy_entropy     | 1.4637041     |
# | policy_loss        | -4.791258e-05 |
# | serial_timesteps   | 16000         |
# | time_elapsed       | 66.1          |
# | total_timesteps    | 64512         |
# | value_loss         | 4177.723      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.1009919e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0576        |
# | fps                | 922           |
# | nupdates           | 65            |
# | policy_entropy     | 1.4635887     |
# | policy_loss        | 4.1567895e-05 |
# | serial_timesteps   | 16250         |
# | time_elapsed       | 67.2          |
# | total_timesteps    | 65520         |
# | value_loss         | 5538.435      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.254091e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0778        |
# | fps                | 931           |
# | nupdates           | 66            |
# | policy_entropy     | 1.4633002     |
# | policy_loss        | 3.1561576e-06 |
# | serial_timesteps   | 16500         |
# | time_elapsed       | 68.2          |
# | total_timesteps    | 66528         |
# | value_loss         | 4693.857      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.2383064e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0504        |
# | fps                | 970           |
# | nupdates           | 67            |
# | policy_entropy     | 1.4633332     |
# | policy_loss        | 0.00011667206 |
# | serial_timesteps   | 16750         |
# | time_elapsed       | 69.3          |
# | total_timesteps    | 67536         |
# | value_loss         | 5578.0825     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.7463436e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.063         |
# | fps                | 971           |
# | nupdates           | 68            |
# | policy_entropy     | 1.463797      |
# | policy_loss        | -3.197974e-05 |
# | serial_timesteps   | 17000         |
# | time_elapsed       | 70.4          |
# | total_timesteps    | 68544         |
# | value_loss         | 4604.5537     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.0900361e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0548        |
# | fps                | 996           |
# | nupdates           | 69            |
# | policy_entropy     | 1.4646916     |
# | policy_loss        | -3.835812e-05 |
# | serial_timesteps   | 17250         |
# | time_elapsed       | 71.4          |
# | total_timesteps    | 69552         |
# | value_loss         | 4430.6504     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.361762e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0535         |
# | fps                | 948            |
# | nupdates           | 70             |
# | policy_entropy     | 1.4652097      |
# | policy_loss        | -0.00016906273 |
# | serial_timesteps   | 17500          |
# | time_elapsed       | 72.4           |
# | total_timesteps    | 70560          |
# | value_loss         | 4839.3027      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00014644579 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0754        |
# | fps                | 934           |
# | nupdates           | 71            |
# | policy_entropy     | 1.467252      |
# | policy_loss        | 0.00028764934 |
# | serial_timesteps   | 17750         |
# | time_elapsed       | 73.5          |
# | total_timesteps    | 71568         |
# | value_loss         | 3805.9114     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.4838832e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0699        |
# | fps                | 967           |
# | nupdates           | 72            |
# | policy_entropy     | 1.4685912     |
# | policy_loss        | 9.108205e-05  |
# | serial_timesteps   | 18000         |
# | time_elapsed       | 74.5          |
# | total_timesteps    | 72576         |
# | value_loss         | 3849.4229     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.2766014e-08 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0516        |
# | fps                | 939           |
# | nupdates           | 73            |
# | policy_entropy     | 1.4689724     |
# | policy_loss        | 1.562509e-05  |
# | serial_timesteps   | 18250         |
# | time_elapsed       | 75.6          |
# | total_timesteps    | 73584         |
# | value_loss         | 5095.503      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.11332765e-05 |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0399         |
# | fps                | 979            |
# | nupdates           | 74             |
# | policy_entropy     | 1.4688156      |
# | policy_loss        | -0.00015964705 |
# | serial_timesteps   | 18500          |
# | time_elapsed       | 76.6           |
# | total_timesteps    | 74592          |
# | value_loss         | 4020.6003      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.4857893e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0682        |
# | fps                | 1002          |
# | nupdates           | 75            |
# | policy_entropy     | 1.4688541     |
# | policy_loss        | -0.0004386038 |
# | serial_timesteps   | 18750         |
# | time_elapsed       | 77.7          |
# | total_timesteps    | 75600         |
# | value_loss         | 4673.025      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 1.776283e-06 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0667       |
# | fps                | 952          |
# | nupdates           | 76           |
# | policy_entropy     | 1.46899      |
# | policy_loss        | 8.31361e-06  |
# | serial_timesteps   | 19000        |
# | time_elapsed       | 78.7         |
# | total_timesteps    | 76608        |
# | value_loss         | 4127.7485    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 1.4727092e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0405        |
# | fps                | 951           |
# | nupdates           | 77            |
# | policy_entropy     | 1.4691153     |
# | policy_loss        | 3.6378653e-05 |
# | serial_timesteps   | 19250         |
# | time_elapsed       | 79.7          |
# | total_timesteps    | 77616         |
# | value_loss         | 5141.182      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.8046345e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0652        |
# | fps                | 1000          |
# | nupdates           | 78            |
# | policy_entropy     | 1.4691763     |
# | policy_loss        | -8.051332e-05 |
# | serial_timesteps   | 19500         |
# | time_elapsed       | 80.8          |
# | total_timesteps    | 78624         |
# | value_loss         | 3779.1082     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020577192 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.067         |
# | fps                | 989           |
# | nupdates           | 79            |
# | policy_entropy     | 1.4693013     |
# | policy_loss        | 4.840506e-05  |
# | serial_timesteps   | 19750         |
# | time_elapsed       | 81.8          |
# | total_timesteps    | 79632         |
# | value_loss         | 2567.493      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.461462e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0537         |
# | fps                | 979            |
# | nupdates           | 80             |
# | policy_entropy     | 1.4692733      |
# | policy_loss        | -4.4896493e-05 |
# | serial_timesteps   | 20000          |
# | time_elapsed       | 82.8           |
# | total_timesteps    | 80640          |
# | value_loss         | 3996.306       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.6696484e-07  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0469         |
# | fps                | 986            |
# | nupdates           | 81             |
# | policy_entropy     | 1.469126       |
# | policy_loss        | -1.5297383e-05 |
# | serial_timesteps   | 20250          |
# | time_elapsed       | 83.8           |
# | total_timesteps    | 81648          |
# | value_loss         | 5780.85        |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 5.1816196e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0519         |
# | fps                | 971            |
# | nupdates           | 82             |
# | policy_entropy     | 1.4689063      |
# | policy_loss        | -2.3118408e-05 |
# | serial_timesteps   | 20500          |
# | time_elapsed       | 84.8           |
# | total_timesteps    | 82656          |
# | value_loss         | 4717.1084      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.9865005e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0473         |
# | fps                | 945            |
# | nupdates           | 83             |
# | policy_entropy     | 1.468822       |
# | policy_loss        | -0.00022086399 |
# | serial_timesteps   | 20750          |
# | time_elapsed       | 85.9           |
# | total_timesteps    | 83664          |
# | value_loss         | 4531.646       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00057438057 |
# | clipfrac           | 0.00025       |
# | explained_variance | 0.0395        |
# | fps                | 945           |
# | nupdates           | 84            |
# | policy_entropy     | 1.4689618     |
# | policy_loss        | 0.00012270272 |
# | serial_timesteps   | 21000         |
# | time_elapsed       | 86.9          |
# | total_timesteps    | 84672         |
# | value_loss         | 5159.1997     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.4746985e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0306        |
# | fps                | 1001          |
# | nupdates           | 85            |
# | policy_entropy     | 1.4690386     |
# | policy_loss        | 4.8852886e-05 |
# | serial_timesteps   | 21250         |
# | time_elapsed       | 88            |
# | total_timesteps    | 85680         |
# | value_loss         | 5309.4106     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.0417661e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0681        |
# | fps                | 974           |
# | nupdates           | 86            |
# | policy_entropy     | 1.4687078     |
# | policy_loss        | 6.407702e-05  |
# | serial_timesteps   | 21500         |
# | time_elapsed       | 89            |
# | total_timesteps    | 86688         |
# | value_loss         | 2987.2024     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.4319523e-07  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0345         |
# | fps                | 994            |
# | nupdates           | 87             |
# | policy_entropy     | 1.4685342      |
# | policy_loss        | -3.7178947e-05 |
# | serial_timesteps   | 21750          |
# | time_elapsed       | 90             |
# | total_timesteps    | 87696          |
# | value_loss         | 3071.182       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.9201112e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0446        |
# | fps                | 958           |
# | nupdates           | 88            |
# | policy_entropy     | 1.4684557     |
# | policy_loss        | -0.0005220052 |
# | serial_timesteps   | 22000         |
# | time_elapsed       | 91            |
# | total_timesteps    | 88704         |
# | value_loss         | 3180.691      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00031457876  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.042          |
# | fps                | 992            |
# | nupdates           | 89             |
# | policy_entropy     | 1.4683568      |
# | policy_loss        | -0.00083062786 |
# | serial_timesteps   | 22250          |
# | time_elapsed       | 92.1           |
# ...
# | time_elapsed       | 981            |
# | total_timesteps    | 976752         |
# | value_loss         | 1955.9791      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00016709881  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0253         |
# | fps                | 1111           |
# | nupdates           | 970            |
# | policy_entropy     | 1.5102609      |
# | policy_loss        | -0.00010332669 |
# | serial_timesteps   | 242500         |
# | time_elapsed       | 981            |
# | total_timesteps    | 977760         |
# | value_loss         | 2130.5083      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00012457602  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00487        |
# | fps                | 1057           |
# | nupdates           | 971            |
# | policy_entropy     | 1.5101169      |
# | policy_loss        | -0.00054081506 |
# | serial_timesteps   | 242750         |
# | time_elapsed       | 982            |
# | total_timesteps    | 978768         |
# | value_loss         | 1617.489       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00013643413  |
# | clipfrac           | 0.00025        |
# | explained_variance | 0.00106        |
# | fps                | 1182           |
# | nupdates           | 972            |
# | policy_entropy     | 1.510029       |
# | policy_loss        | -0.00080937153 |
# | serial_timesteps   | 243000         |
# | time_elapsed       | 983            |
# | total_timesteps    | 979776         |
# | value_loss         | 2204.1248      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00012334902 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00202       |
# | fps                | 1084          |
# | nupdates           | 973           |
# | policy_entropy     | 1.5096786     |
# | policy_loss        | 0.00040498163 |
# | serial_timesteps   | 243250        |
# | time_elapsed       | 984           |
# | total_timesteps    | 980784        |
# | value_loss         | 1543.6698     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00014323297  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0181         |
# | fps                | 1085           |
# | nupdates           | 974            |
# | policy_entropy     | 1.5089709      |
# | policy_loss        | -0.00064735685 |
# | serial_timesteps   | 243500         |
# | time_elapsed       | 985            |
# | total_timesteps    | 981792         |
# | value_loss         | 2004.4454      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00014740096  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0212         |
# | fps                | 1108           |
# | nupdates           | 975            |
# | policy_entropy     | 1.508676       |
# | policy_loss        | -0.00091115624 |
# | serial_timesteps   | 243750         |
# | time_elapsed       | 986            |
# | total_timesteps    | 982800         |
# | value_loss         | 2000.6178      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00073519885 |
# | clipfrac           | 0.00275       |
# | explained_variance | 0.00681       |
# | fps                | 1092          |
# | nupdates           | 976           |
# | policy_entropy     | 1.5086424     |
# | policy_loss        | -0.001546359  |
# | serial_timesteps   | 244000        |
# | time_elapsed       | 987           |
# | total_timesteps    | 983808        |
# | value_loss         | 2473.9988     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000774455   |
# | clipfrac           | 0.002         |
# | explained_variance | 0.00438       |
# | fps                | 1118          |
# | nupdates           | 977           |
# | policy_entropy     | 1.5091648     |
# | policy_loss        | -0.0015381404 |
# | serial_timesteps   | 244250        |
# | time_elapsed       | 988           |
# | total_timesteps    | 984816        |
# | value_loss         | 1722.0012     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018012093 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00153       |
# | fps                | 1111          |
# | nupdates           | 978           |
# | policy_entropy     | 1.5104264     |
# | policy_loss        | -0.0012159104 |
# | serial_timesteps   | 244500        |
# | time_elapsed       | 989           |
# | total_timesteps    | 985824        |
# | value_loss         | 1884.2258     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006315888  |
# | clipfrac           | 0.0005        |
# | explained_variance | -0.0032       |
# | fps                | 1119          |
# | nupdates           | 979           |
# | policy_entropy     | 1.5107993     |
# | policy_loss        | 0.00041500255 |
# | serial_timesteps   | 244750        |
# | time_elapsed       | 990           |
# | total_timesteps    | 986832        |
# | value_loss         | 1534.1908     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.7699485e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00818        |
# | fps                | 1118           |
# | nupdates           | 980            |
# | policy_entropy     | 1.5111966      |
# | policy_loss        | -2.7442784e-05 |
# | serial_timesteps   | 245000         |
# | time_elapsed       | 991            |
# | total_timesteps    | 987840         |
# | value_loss         | 1991.8811      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.5525704e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0243         |
# | fps                | 1108           |
# | nupdates           | 981            |
# | policy_entropy     | 1.5114497      |
# | policy_loss        | -1.1071592e-05 |
# | serial_timesteps   | 245250         |
# | time_elapsed       | 991            |
# | total_timesteps    | 988848         |
# | value_loss         | 1655.5508      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 6.773846e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00535       |
# | fps                | 1120          |
# | nupdates           | 982           |
# | policy_entropy     | 1.5116493     |
# | policy_loss        | -8.655536e-05 |
# | serial_timesteps   | 245500        |
# | time_elapsed       | 992           |
# | total_timesteps    | 989856        |
# | value_loss         | 1707.9036     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.3333163e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0512        |
# | fps                | 1081          |
# | nupdates           | 983           |
# | policy_entropy     | 1.51195       |
# | policy_loss        | -0.0002055743 |
# | serial_timesteps   | 245750        |
# | time_elapsed       | 993           |
# | total_timesteps    | 990864        |
# | value_loss         | 1447.5546     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00050419464 |
# | clipfrac           | 0.0015        |
# | explained_variance | 0.00237       |
# | fps                | 1076          |
# | nupdates           | 984           |
# | policy_entropy     | 1.5121921     |
# | policy_loss        | -0.001081022  |
# | serial_timesteps   | 246000        |
# | time_elapsed       | 994           |
# | total_timesteps    | 991872        |
# | value_loss         | 2257.418      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016214914 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0101        |
# | fps                | 1120          |
# | nupdates           | 985           |
# | policy_entropy     | 1.5125368     |
# | policy_loss        | 8.365803e-05  |
# | serial_timesteps   | 246250        |
# | time_elapsed       | 995           |
# | total_timesteps    | 992880        |
# | value_loss         | 1522.9515     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002579947  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0136        |
# | fps                | 1080          |
# | nupdates           | 986           |
# | policy_entropy     | 1.5118258     |
# | policy_loss        | 3.4724842e-05 |
# | serial_timesteps   | 246500        |
# | time_elapsed       | 996           |
# | total_timesteps    | 993888        |
# | value_loss         | 1683.4235     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00021825067 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0412       |
# | fps                | 1123          |
# | nupdates           | 987           |
# | policy_entropy     | 1.5115637     |
# | policy_loss        | -0.0015007965 |
# | serial_timesteps   | 246750        |
# | time_elapsed       | 997           |
# | total_timesteps    | 994896        |
# | value_loss         | 1475.7483     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00032308727 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0789        |
# | fps                | 1042          |
# | nupdates           | 988           |
# | policy_entropy     | 1.5115457     |
# | policy_loss        | -0.0008925618 |
# | serial_timesteps   | 247000        |
# | time_elapsed       | 998           |
# | total_timesteps    | 995904        |
# | value_loss         | 1969.737      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.5797006e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00176       |
# | fps                | 1091          |
# | nupdates           | 989           |
# | policy_entropy     | 1.5115671     |
# | policy_loss        | -6.428461e-05 |
# | serial_timesteps   | 247250        |
# | time_elapsed       | 999           |
# | total_timesteps    | 996912        |
# | value_loss         | 2371.9087     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.0425763e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00193        |
# | fps                | 1127           |
# | nupdates           | 990            |
# | policy_entropy     | 1.5115951      |
# | policy_loss        | -0.00021306898 |
# | serial_timesteps   | 247500         |
# | time_elapsed       | 1e+03          |
# | total_timesteps    | 997920         |
# | value_loss         | 1981.5048      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0006831641 |
# | clipfrac           | 0.002        |
# | explained_variance | 0.0041       |
# | fps                | 1086         |
# | nupdates           | 991          |
# | policy_entropy     | 1.5112224    |
# | policy_loss        | -0.001590066 |
# | serial_timesteps   | 247750       |
# | time_elapsed       | 1e+03        |
# | total_timesteps    | 998928       |
# | value_loss         | 1714.4052    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0009148503  |
# | clipfrac           | 0.0045        |
# | explained_variance | 0.00785       |
# | fps                | 1125          |
# | nupdates           | 992           |
# | policy_entropy     | 1.5111074     |
# | policy_loss        | -0.0008455517 |
# | serial_timesteps   | 248000        |
# | time_elapsed       | 1e+03         |
# | total_timesteps    | 999936        |
# | value_loss         | 2202.671      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 9.6926844e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00144        |
# | fps                | 1056           |
# | nupdates           | 993            |
# | policy_entropy     | 1.5119182      |
# | policy_loss        | -7.0805763e-06 |
# | serial_timesteps   | 248250         |
# | time_elapsed       | 1e+03          |
# | total_timesteps    | 1000944        |
# | value_loss         | 1941.9663      |
# ---------------------------------------
# ------------------------------------
# | approxkl           | 0.030414669 |
# | clipfrac           | 0.24700002  |
# | explained_variance | 0.00548     |
# | fps                | 1077        |
# | nupdates           | 994         |
# | policy_entropy     | 1.5096054   |
# | policy_loss        | 0.009827898 |
# | serial_timesteps   | 248500      |
# | time_elapsed       | 1e+03       |
# | total_timesteps    | 1001952     |
# | value_loss         | 1806.2114   |
# ------------------------------------
# --------------------------------------
# | approxkl           | 0.00042561156 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.212        |
# | fps                | 1122          |
# | nupdates           | 995           |
# | policy_entropy     | 1.5081341     |
# | policy_loss        | -0.0008866758 |
# | serial_timesteps   | 248750        |
# | time_elapsed       | 1e+03         |
# | total_timesteps    | 1002960       |
# | value_loss         | 2266.7344     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.6673517e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.142         |
# | fps                | 1103           |
# | nupdates           | 996            |
# | policy_entropy     | 1.5078658      |
# | policy_loss        | -2.0632104e-05 |
# | serial_timesteps   | 249000         |
# | time_elapsed       | 1.01e+03       |
# | total_timesteps    | 1003968        |
# | value_loss         | 2700.516       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 6.553128e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.169        |
# | fps                | 1117          |
# | nupdates           | 997           |
# | policy_entropy     | 1.5078167     |
# | policy_loss        | -4.003042e-05 |
# | serial_timesteps   | 249250        |
# | time_elapsed       | 1.01e+03      |
# | total_timesteps    | 1004976       |
# | value_loss         | 2415.4885     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.2115469e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.244         |
# | fps                | 1054           |
# | nupdates           | 998            |
# | policy_entropy     | 1.507881       |
# | policy_loss        | -0.00017408103 |
# | serial_timesteps   | 249500         |
# | time_elapsed       | 1.01e+03       |
# | total_timesteps    | 1005984        |
# | value_loss         | 2636.574       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.1556895e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.595        |
# | fps                | 1113          |
# | nupdates           | 999           |
# | policy_entropy     | 1.50795       |
# | policy_loss        | 2.595111e-05  |
# | serial_timesteps   | 249750        |
# | time_elapsed       | 1.01e+03      |
# | total_timesteps    | 1006992       |
# | value_loss         | 2771.7715     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.1456445e-07 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00838      |
# | fps                | 1073          |
# | nupdates           | 1000          |
# | policy_entropy     | 1.5081042     |
# | policy_loss        | 1.9501062e-05 |
# | serial_timesteps   | 250000        |
# | time_elapsed       | 1.01e+03      |
# | total_timesteps    | 1008000       |
# | value_loss         | 2348.0603     |
# --------------------------------------

# %%
from stable_baselines.common.policies import FeedForwardPolicy

# %%
model = PPO2.load(final_model_dir)

# Enjoy trained agent
env = gym.make(env_name)
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
