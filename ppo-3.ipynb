# %%
import os
import gym
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import SubprocVecEnv
from stable_baselines.common.vec_env import DummyVecEnv
from utils.ppo import PPO
from utils.models import Policy, CNNPolicy

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
LOGS = os.getcwd()

# %%
def makedirs(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
env_name = 'CarRacing-v0'
run_id = 1
n_steps = 250
total_timesteps = 10000000
cnn_policy = True

LOGS = os.path.join(LOGS, env_name, 'run{}'.format(run_id))
makedirs(LOGS)
tb_log = os.path.join(LOGS, 'tb')
makedirs(tb_log)
model_dir = os.path.join(LOGS, 'models')
makedirs(model_dir)
final_model_dir = os.path.join(LOGS, 'model')
n_cpu = 4

# %%
env = SubprocVecEnv([lambda: gym.make(env_name) for i in range(n_cpu)])

if cnn_policy:
    print('Using CNN policy network')
    model = PPO(CNNPolicy, env, n_steps=n_steps, tensorboard_log=tb_log, verbose=1, full_tensorboard_log=True)
else:
    print('Using MLP policy network')
    model = PPO(Policy, env, n_steps=n_steps, tensorboard_log=tb_log, verbose=1, full_tensorboard_log=True)
model.learn(total_timesteps, env, save_file=os.path.join(model_dir, 'model'))
model.save(final_model_dir)
del model # remove to demonstrate saving and loading
# Out:
# Using CNN policy network
# INFO:tensorflow:Summary name model/c1/w:0 is illegal; using model/c1/w_0 instead.
# INFO:tensorflow:Summary name model/c1/b:0 is illegal; using model/c1/b_0 instead.
# INFO:tensorflow:Summary name model/c2/w:0 is illegal; using model/c2/w_0 instead.
# INFO:tensorflow:Summary name model/c2/b:0 is illegal; using model/c2/b_0 instead.
# INFO:tensorflow:Summary name model/c3/w:0 is illegal; using model/c3/w_0 instead.
# INFO:tensorflow:Summary name model/c3/b:0 is illegal; using model/c3/b_0 instead.
# INFO:tensorflow:Summary name model/fc1/w:0 is illegal; using model/fc1/w_0 instead.
# INFO:tensorflow:Summary name model/fc1/b:0 is illegal; using model/fc1/b_0 instead.
# INFO:tensorflow:Summary name model/vf/w:0 is illegal; using model/vf/w_0 instead.
# INFO:tensorflow:Summary name model/vf/b:0 is illegal; using model/vf/b_0 instead.
# INFO:tensorflow:Summary name model/pi/w:0 is illegal; using model/pi/w_0 instead.
# INFO:tensorflow:Summary name model/pi/b:0 is illegal; using model/pi/b_0 instead.
# INFO:tensorflow:Summary name model/pi/logstd:0 is illegal; using model/pi/logstd_0 instead.
# INFO:tensorflow:Summary name model/q/w:0 is illegal; using model/q/w_0 instead.
# INFO:tensorflow:Summary name model/q/b:0 is illegal; using model/q/b_0 instead.
# INFO:tensorflow:Summary name model/c1/w:0/gradient is illegal; using model/c1/w_0/gradient instead.
# INFO:tensorflow:Summary name model/c1/b:0/gradient is illegal; using model/c1/b_0/gradient instead.
# INFO:tensorflow:Summary name model/c2/w:0/gradient is illegal; using model/c2/w_0/gradient instead.
# INFO:tensorflow:Summary name model/c2/b:0/gradient is illegal; using model/c2/b_0/gradient instead.
# INFO:tensorflow:Summary name model/c3/w:0/gradient is illegal; using model/c3/w_0/gradient instead.
# INFO:tensorflow:Summary name model/c3/b:0/gradient is illegal; using model/c3/b_0/gradient instead.
# INFO:tensorflow:Summary name model/fc1/w:0/gradient is illegal; using model/fc1/w_0/gradient instead.
# INFO:tensorflow:Summary name model/fc1/b:0/gradient is illegal; using model/fc1/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf/w:0/gradient is illegal; using model/vf/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf/b:0/gradient is illegal; using model/vf/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/w:0/gradient is illegal; using model/pi/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/b:0/gradient is illegal; using model/pi/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/logstd:0/gradient is illegal; using model/pi/logstd_0/gradient instead.
# No of updates: 10000
# Total timesteps : 10000000
# Batch size: 1000
# -------------------------------------
# | approxkl           | 0.006182891  |
# | clipfrac           | 0.078999996  |
# | explained_variance | 0.00355      |
# | fps                | 72           |
# | nupdates           | 1            |
# | policy_entropy     | 4.257036     |
# | policy_loss        | -0.006796607 |
# | serial_timesteps   | 250          |
# | time_elapsed       | 0.000337     |
# | total_timesteps    | 1008         |
# | value_loss         | 0.9620365    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0038276948  |
# | clipfrac           | 0.046749998   |
# | explained_variance | 0.000217      |
# | fps                | 91            |
# | nupdates           | 2             |
# | policy_entropy     | 4.259351      |
# | policy_loss        | -0.0055315755 |
# | serial_timesteps   | 500           |
# | time_elapsed       | 13.8          |
# | total_timesteps    | 2016          |
# | value_loss         | 0.6515771     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0016210005  |
# | clipfrac           | 0.00975       |
# | explained_variance | 2.13e-05      |
# | fps                | 91            |
# | nupdates           | 3             |
# | policy_entropy     | 4.2625914     |
# | policy_loss        | -0.0012563401 |
# | serial_timesteps   | 750           |
# | time_elapsed       | 24.7          |
# | total_timesteps    | 3024          |
# | value_loss         | 0.5645558     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0032016255  |
# | clipfrac           | 0.0205        |
# | explained_variance | 0.00112       |
# | fps                | 91            |
# | nupdates           | 4             |
# | policy_entropy     | 4.263072      |
# | policy_loss        | -0.0012714387 |
# | serial_timesteps   | 1000          |
# | time_elapsed       | 35.6          |
# | total_timesteps    | 4032          |
# | value_loss         | 0.5586141     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.005236247   |
# | clipfrac           | 0.066         |
# | explained_variance | 0.0462        |
# | fps                | 92            |
# | nupdates           | 5             |
# | policy_entropy     | 4.2644305     |
# | policy_loss        | -0.0062323166 |
# | serial_timesteps   | 1250          |
# | time_elapsed       | 46.6          |
# | total_timesteps    | 5040          |
# | value_loss         | 0.6208364     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.005819328   |
# | clipfrac           | 0.08399999    |
# | explained_variance | 0.00201       |
# | fps                | 93            |
# | nupdates           | 6             |
# | policy_entropy     | 4.2641916     |
# | policy_loss        | -0.0051022074 |
# | serial_timesteps   | 1500          |
# | time_elapsed       | 57.3          |
# | total_timesteps    | 6048          |
# | value_loss         | 0.5604849     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0023055165   |
# | clipfrac           | 0.017          |
# | explained_variance | -0.000236      |
# | fps                | 95             |
# | nupdates           | 7              |
# | policy_entropy     | 4.262487       |
# | policy_loss        | -0.00039689947 |
# | serial_timesteps   | 1750           |
# | time_elapsed       | 68             |
# | total_timesteps    | 7056           |
# | value_loss         | 0.61634946     |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0031421613 |
# | clipfrac           | 0.0325       |
# | explained_variance | -0.0478      |
# | fps                | 94           |
# | nupdates           | 8            |
# | policy_entropy     | 4.263399     |
# | policy_loss        | -0.002668904 |
# | serial_timesteps   | 2000         |
# | time_elapsed       | 78.5         |
# | total_timesteps    | 8064         |
# | value_loss         | 0.6539082    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0036848353  |
# | clipfrac           | 0.03825       |
# | explained_variance | 0.0547        |
# | fps                | 92            |
# | nupdates           | 9             |
# | policy_entropy     | 4.2613716     |
# | policy_loss        | -0.0014297431 |
# | serial_timesteps   | 2250          |
# | time_elapsed       | 89.1          |
# | total_timesteps    | 9072          |
# | value_loss         | 0.6101917     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0049403817  |
# | clipfrac           | 0.066         |
# | explained_variance | 0.000624      |
# | fps                | 93            |
# | nupdates           | 10            |
# | policy_entropy     | 4.253355      |
# | policy_loss        | -0.0045839935 |
# | serial_timesteps   | 2500          |
# | time_elapsed       | 99.8          |
# | total_timesteps    | 10080         |
# | value_loss         | 0.83679515    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0026472562  |
# | clipfrac           | 0.02575       |
# | explained_variance | -0.0197       |
# | fps                | 94            |
# | nupdates           | 11            |
# | policy_entropy     | 4.249263      |
# | policy_loss        | -0.0016212226 |
# | serial_timesteps   | 2750          |
# | time_elapsed       | 111           |
# | total_timesteps    | 11088         |
# | value_loss         | 0.78325427    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.007066193   |
# | clipfrac           | 0.09600001    |
# | explained_variance | 0.102         |
# | fps                | 93            |
# | nupdates           | 12            |
# | policy_entropy     | 4.2492347     |
# | policy_loss        | -0.0030083596 |
# | serial_timesteps   | 3000          |
# | time_elapsed       | 121           |
# | total_timesteps    | 12096         |
# | value_loss         | 0.6276586     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.005414115   |
# | clipfrac           | 0.07375       |
# | explained_variance | 0.0725        |
# | fps                | 94            |
# | nupdates           | 13            |
# | policy_entropy     | 4.247184      |
# | policy_loss        | -0.0027425003 |
# | serial_timesteps   | 3250          |
# | time_elapsed       | 132           |
# | total_timesteps    | 13104         |
# | value_loss         | 0.64136213    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0030734905  |
# | clipfrac           | 0.02925       |
# | explained_variance | 0.0171        |
# | fps                | 91            |
# | nupdates           | 14            |
# | policy_entropy     | 4.244354      |
# | policy_loss        | -0.0012180555 |
# | serial_timesteps   | 3500          |
# | time_elapsed       | 142           |
# | total_timesteps    | 14112         |
# | value_loss         | 0.74305636    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.00542726   |
# | clipfrac           | 0.066750005  |
# | explained_variance | 0.0225       |
# | fps                | 93           |
# | nupdates           | 15           |
# | policy_entropy     | 4.2425375    |
# | policy_loss        | 0.0016334872 |
# | serial_timesteps   | 3750         |
# | time_elapsed       | 153          |
# | total_timesteps    | 15120        |
# | value_loss         | 0.64025205   |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.0041086795   |
# | clipfrac           | 0.038499996    |
# | explained_variance | 0.0212         |
# | fps                | 92             |
# | nupdates           | 16             |
# | policy_entropy     | 4.2414656      |
# | policy_loss        | -0.00041342992 |
# | serial_timesteps   | 4000           |
# | time_elapsed       | 164            |
# | total_timesteps    | 16128          |
# | value_loss         | 0.6137426      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0013824438  |
# | clipfrac           | 0.0085        |
# | explained_variance | 0.0668        |
# | fps                | 92            |
# | nupdates           | 17            |
# | policy_entropy     | 4.2410164     |
# | policy_loss        | -0.0017708107 |
# | serial_timesteps   | 4250          |
# | time_elapsed       | 175           |
# | total_timesteps    | 17136         |
# | value_loss         | 0.6261955     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0078433035  |
# | clipfrac           | 0.107         |
# | explained_variance | 0.0162        |
# | fps                | 93            |
# | nupdates           | 18            |
# | policy_entropy     | 4.241934      |
# | policy_loss        | -0.0053071813 |
# | serial_timesteps   | 4500          |
# | time_elapsed       | 186           |
# | total_timesteps    | 18144         |
# | value_loss         | 0.55176425    |
# --------------------------------------

# %%
from stable_baselines.common.policies import FeedForwardPolicy

# %%
model = PPO2.load(final_model_dir)

# Enjoy trained agent
env = gym.make(env_name)
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
