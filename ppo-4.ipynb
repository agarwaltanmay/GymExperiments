# %%
import os
import gym
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import SubprocVecEnv
from stable_baselines.common.vec_env import DummyVecEnv
from utils.ppo import PPO
from utils.models import Policy, CNNPolicy

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
LOGS = os.getcwd()

# %%
def makedirs(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
env_name = 'LunarLanderContinuous-v2'
run_id = 1
n_steps = 250
total_timesteps = 1000000
cnn_policy = False

LOGS = os.path.join(LOGS, env_name, 'run{}'.format(run_id))
makedirs(LOGS)
tb_log = os.path.join(LOGS, 'tb')
makedirs(tb_log)
model_dir = os.path.join(LOGS, 'models')
makedirs(model_dir)
final_model_dir = os.path.join(LOGS, 'model')
n_cpu = 4

# %%
env = SubprocVecEnv([lambda: gym.make(env_name) for i in range(n_cpu)])

if cnn_policy:
    print('Using CNN policy network')
    model = PPO(CNNPolicy, env, n_steps=n_steps, tensorboard_log=tb_log, verbose=1, full_tensorboard_log=True)
else:
    print('Using MLP policy network')
    model = PPO(Policy, env, n_steps=n_steps, tensorboard_log=tb_log, verbose=1, full_tensorboard_log=True)
model.learn(total_timesteps, env, save_file=os.path.join(model_dir, 'model'))
model.save(final_model_dir)
del model # remove to demonstrate saving and loading
# Out:
# Using MLP policy network
# INFO:tensorflow:Summary name model/pi_fc0/w:0 is illegal; using model/pi_fc0/w_0 instead.
# INFO:tensorflow:Summary name model/pi_fc0/b:0 is illegal; using model/pi_fc0/b_0 instead.
# INFO:tensorflow:Summary name model/vf_fc0/w:0 is illegal; using model/vf_fc0/w_0 instead.
# INFO:tensorflow:Summary name model/vf_fc0/b:0 is illegal; using model/vf_fc0/b_0 instead.
# INFO:tensorflow:Summary name model/pi_fc1/w:0 is illegal; using model/pi_fc1/w_0 instead.
# INFO:tensorflow:Summary name model/pi_fc1/b:0 is illegal; using model/pi_fc1/b_0 instead.
# INFO:tensorflow:Summary name model/vf_fc1/w:0 is illegal; using model/vf_fc1/w_0 instead.
# INFO:tensorflow:Summary name model/vf_fc1/b:0 is illegal; using model/vf_fc1/b_0 instead.
# INFO:tensorflow:Summary name model/vf/w:0 is illegal; using model/vf/w_0 instead.
# INFO:tensorflow:Summary name model/vf/b:0 is illegal; using model/vf/b_0 instead.
# INFO:tensorflow:Summary name model/pi/w:0 is illegal; using model/pi/w_0 instead.
# INFO:tensorflow:Summary name model/pi/b:0 is illegal; using model/pi/b_0 instead.
# INFO:tensorflow:Summary name model/pi/logstd:0 is illegal; using model/pi/logstd_0 instead.
# INFO:tensorflow:Summary name model/q/w:0 is illegal; using model/q/w_0 instead.
# INFO:tensorflow:Summary name model/q/b:0 is illegal; using model/q/b_0 instead.
# INFO:tensorflow:Summary name model/pi_fc0/w:0/gradient is illegal; using model/pi_fc0/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc0/b:0/gradient is illegal; using model/pi_fc0/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc0/w:0/gradient is illegal; using model/vf_fc0/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc0/b:0/gradient is illegal; using model/vf_fc0/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc1/w:0/gradient is illegal; using model/pi_fc1/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc1/b:0/gradient is illegal; using model/pi_fc1/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc1/w:0/gradient is illegal; using model/vf_fc1/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc1/b:0/gradient is illegal; using model/vf_fc1/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf/w:0/gradient is illegal; using model/vf/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf/b:0/gradient is illegal; using model/vf/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/w:0/gradient is illegal; using model/pi/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/b:0/gradient is illegal; using model/pi/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/logstd:0/gradient is illegal; using model/pi/logstd_0/gradient instead.
# No of updates: 1000
# Total timesteps : 1000000
# Batch size: 1000
# --------------------------------------
# | approxkl           | 0.00012497968 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00154       |
# | fps                | 488           |
# | nupdates           | 1             |
# | policy_entropy     | 2.8381422     |
# | policy_loss        | -0.0017895745 |
# | serial_timesteps   | 250           |
# | time_elapsed       | 0.000134      |
# | total_timesteps    | 1008          |
# | value_loss         | 823.15393     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000121122604 |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00115       |
# | fps                | 826            |
# | nupdates           | 2              |
# | policy_entropy     | 2.8381011      |
# | policy_loss        | -0.0008440319  |
# | serial_timesteps   | 500            |
# | time_elapsed       | 2.05           |
# | total_timesteps    | 2016           |
# | value_loss         | 681.917        |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 3.569649e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00118       |
# | fps                | 807            |
# | nupdates           | 3              |
# | policy_entropy     | 2.838807       |
# | policy_loss        | -0.00019320779 |
# | serial_timesteps   | 750            |
# | time_elapsed       | 3.27           |
# | total_timesteps    | 3024           |
# | value_loss         | 961.4588       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.1779095e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.000207     |
# | fps                | 855           |
# | nupdates           | 4             |
# | policy_entropy     | 2.83989       |
# | policy_loss        | 5.025226e-05  |
# | serial_timesteps   | 1000          |
# | time_elapsed       | 4.51          |
# | total_timesteps    | 4032          |
# | value_loss         | 1194.7443     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.120903e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000474      |
# | fps                | 860           |
# | nupdates           | 5             |
# | policy_entropy     | 2.8422236     |
# | policy_loss        | -0.0003952474 |
# | serial_timesteps   | 1250          |
# | time_elapsed       | 5.68          |
# | total_timesteps    | 5040          |
# | value_loss         | 1030.5596     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012924493 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000428      |
# | fps                | 801           |
# | nupdates           | 6             |
# | policy_entropy     | 2.8440456     |
# | policy_loss        | -0.0004726298 |
# | serial_timesteps   | 1500          |
# | time_elapsed       | 6.85          |
# | total_timesteps    | 6048          |
# | value_loss         | 1092.1005     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.6701796e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00145        |
# | fps                | 850            |
# | nupdates           | 7              |
# | policy_entropy     | 2.8454354      |
# | policy_loss        | -0.00087329024 |
# | serial_timesteps   | 1750           |
# | time_elapsed       | 8.1            |
# | total_timesteps    | 7056           |
# | value_loss         | 1093.6882      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0003576557  |
# | clipfrac           | 0.0005        |
# | explained_variance | 0.00169       |
# | fps                | 798           |
# | nupdates           | 8             |
# | policy_entropy     | 2.8459826     |
# | policy_loss        | -0.0023924736 |
# | serial_timesteps   | 2000          |
# | time_elapsed       | 9.28          |
# | total_timesteps    | 8064          |
# | value_loss         | 925.14557     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014726559 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00748      |
# | fps                | 787           |
# | nupdates           | 9             |
# | policy_entropy     | 2.8462198     |
# | policy_loss        | -0.0012933842 |
# | serial_timesteps   | 2250          |
# | time_elapsed       | 10.5          |
# | total_timesteps    | 9072          |
# | value_loss         | 759.4561      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024456985 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00244      |
# | fps                | 821           |
# | nupdates           | 10            |
# | policy_entropy     | 2.8448975     |
# | policy_loss        | -0.0018644825 |
# | serial_timesteps   | 2500          |
# | time_elapsed       | 11.8          |
# | total_timesteps    | 10080         |
# | value_loss         | 879.2055      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.791204e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0107       |
# | fps                | 832           |
# | nupdates           | 11            |
# | policy_entropy     | 2.8444755     |
# | policy_loss        | -0.0002605864 |
# | serial_timesteps   | 2750          |
# | time_elapsed       | 13            |
# | total_timesteps    | 11088         |
# | value_loss         | 1019.298      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.547676e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0266       |
# | fps                | 863           |
# | nupdates           | 12            |
# | policy_entropy     | 2.8451319     |
# | policy_loss        | 0.00045908216 |
# | serial_timesteps   | 3000          |
# | time_elapsed       | 14.2          |
# | total_timesteps    | 12096         |
# | value_loss         | 613.09344     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.0207011e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0146       |
# | fps                | 814           |
# | nupdates           | 13            |
# | policy_entropy     | 2.842715      |
# | policy_loss        | -0.0005128372 |
# | serial_timesteps   | 3250          |
# | time_elapsed       | 15.4          |
# | total_timesteps    | 13104         |
# | value_loss         | 343.76205     |
# --------------------------------------
# ----------------------------------------
# | approxkl           | 3.8644997e-05   |
# | clipfrac           | 0.0             |
# | explained_variance | -0.0129         |
# | fps                | 825             |
# | nupdates           | 14              |
# | policy_entropy     | 2.8418078       |
# | policy_loss        | -1.49809985e-05 |
# | serial_timesteps   | 3500            |
# | time_elapsed       | 16.6            |
# | total_timesteps    | 14112           |
# | value_loss         | 466.9823        |
# ----------------------------------------
# --------------------------------------
# | approxkl           | 7.8045254e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0194       |
# | fps                | 893           |
# | nupdates           | 15            |
# | policy_entropy     | 2.8439248     |
# | policy_loss        | -0.0007036129 |
# | serial_timesteps   | 3750          |
# | time_elapsed       | 17.9          |
# | total_timesteps    | 15120         |
# | value_loss         | 517.126       |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.9550303e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0206        |
# | fps                | 818            |
# | nupdates           | 16             |
# | policy_entropy     | 2.8459635      |
# | policy_loss        | -0.00023510447 |
# | serial_timesteps   | 4000           |
# | time_elapsed       | 19             |
# | total_timesteps    | 16128          |
# | value_loss         | 685.81616      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.6293756e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.03         |
# | fps                | 831           |
# | nupdates           | 17            |
# | policy_entropy     | 2.846624      |
# | policy_loss        | -0.0001447236 |
# | serial_timesteps   | 4250          |
# | time_elapsed       | 20.2          |
# | total_timesteps    | 17136         |
# | value_loss         | 477.4824      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.180648e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.019         |
# | fps                | 844            |
# | nupdates           | 18             |
# | policy_entropy     | 2.8473613      |
# | policy_loss        | -0.00021774473 |
# | serial_timesteps   | 4500           |
# | time_elapsed       | 21.4           |
# | total_timesteps    | 18144          |
# | value_loss         | 356.2422       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 6.3468964e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0201       |
# | fps                | 849           |
# | nupdates           | 19            |
# | policy_entropy     | 2.8470225     |
# | policy_loss        | -0.0009437508 |
# | serial_timesteps   | 4750          |
# | time_elapsed       | 22.6          |
# | total_timesteps    | 19152         |
# | value_loss         | 365.75723     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.613969e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.008         |
# | fps                | 837            |
# | nupdates           | 20             |
# | policy_entropy     | 2.8477612      |
# | policy_loss        | -0.00032761937 |
# | serial_timesteps   | 5000           |
# | time_elapsed       | 23.8           |
# | total_timesteps    | 20160          |
# | value_loss         | 481.1683       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.3400036e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0235       |
# | fps                | 820           |
# | nupdates           | 21            |
# | policy_entropy     | 2.8483841     |
# | policy_loss        | -0.0002579512 |
# | serial_timesteps   | 5250          |
# | time_elapsed       | 25            |
# | total_timesteps    | 21168         |
# | value_loss         | 793.8381      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 6.709622e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0062        |
# | fps                | 811            |
# | nupdates           | 22             |
# | policy_entropy     | 2.8484583      |
# | policy_loss        | -0.00048778838 |
# | serial_timesteps   | 5500           |
# | time_elapsed       | 26.2           |
# | total_timesteps    | 22176          |
# | value_loss         | 474.8946       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 5.1776704e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00215       |
# | fps                | 869            |
# | nupdates           | 23             |
# | policy_entropy     | 2.8511245      |
# | policy_loss        | -0.00036466293 |
# | serial_timesteps   | 5750           |
# | time_elapsed       | 27.4           |
# | total_timesteps    | 23184          |
# | value_loss         | 316.72168      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 8.614599e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0172        |
# | fps                | 797            |
# | nupdates           | 24             |
# | policy_entropy     | 2.8527067      |
# | policy_loss        | -0.00038440325 |
# | serial_timesteps   | 6000           |
# | time_elapsed       | 28.6           |
# | total_timesteps    | 24192          |
# | value_loss         | 530.64685      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.005688e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00179        |
# | fps                | 846            |
# | nupdates           | 25             |
# | policy_entropy     | 2.8539371      |
# | policy_loss        | -0.00018391146 |
# | serial_timesteps   | 6250           |
# | time_elapsed       | 29.8           |
# | total_timesteps    | 25200          |
# | value_loss         | 322.32858      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.6088272e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0358        |
# | fps                | 810            |
# | nupdates           | 26             |
# | policy_entropy     | 2.8543947      |
# | policy_loss        | -0.00042741362 |
# | serial_timesteps   | 6500           |
# | time_elapsed       | 31             |
# | total_timesteps    | 26208          |
# | value_loss         | 609.8241       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.66388e-06   |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0119       |
# | fps                | 873           |
# | nupdates           | 27            |
# | policy_entropy     | 2.8543844     |
# | policy_loss        | -8.788877e-05 |
# | serial_timesteps   | 6750          |
# | time_elapsed       | 32.3          |
# | total_timesteps    | 27216         |
# | value_loss         | 416.23404     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.7470093e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00923       |
# | fps                | 852            |
# | nupdates           | 28             |
# | policy_entropy     | 2.8534067      |
# | policy_loss        | -0.00035596418 |
# | serial_timesteps   | 7000           |
# | time_elapsed       | 33.4           |
# | total_timesteps    | 28224          |
# | value_loss         | 291.19534      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.0160594e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0201        |
# | fps                | 789            |
# | nupdates           | 29             |
# | policy_entropy     | 2.8531022      |
# | policy_loss        | -0.00016061719 |
# | serial_timesteps   | 7250           |
# | time_elapsed       | 34.6           |
# | total_timesteps    | 29232          |
# | value_loss         | 444.83185      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.9703584e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00581      |
# | fps                | 796           |
# | nupdates           | 30            |
# | policy_entropy     | 2.8528976     |
# | policy_loss        | -0.0004955658 |
# | serial_timesteps   | 7500          |
# | time_elapsed       | 35.9          |
# | total_timesteps    | 30240         |
# | value_loss         | 418.5288      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.1396017e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0426        |
# | fps                | 830            |
# | nupdates           | 31             |
# | policy_entropy     | 2.8530436      |
# | policy_loss        | -0.00016883513 |
# | serial_timesteps   | 7750           |
# | time_elapsed       | 37.1           |
# | total_timesteps    | 31248          |
# | value_loss         | 374.97394      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.43181e-05   |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0201       |
# | fps                | 853           |
# | nupdates           | 32            |
# | policy_entropy     | 2.8535933     |
# | policy_loss        | -0.0012330905 |
# | serial_timesteps   | 8000          |
# | time_elapsed       | 38.3          |
# | total_timesteps    | 32256         |
# | value_loss         | 539.83826     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011164896 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0343       |
# | fps                | 793           |
# | nupdates           | 33            |
# | policy_entropy     | 2.8543603     |
# | policy_loss        | -0.0015182181 |
# | serial_timesteps   | 8250          |
# | time_elapsed       | 39.5          |
# | total_timesteps    | 33264         |
# | value_loss         | 515.6247      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.488719e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0195        |
# | fps                | 903            |
# | nupdates           | 34             |
# | policy_entropy     | 2.8548865      |
# | policy_loss        | -0.00041651173 |
# | serial_timesteps   | 8500           |
# | time_elapsed       | 40.8           |
# | total_timesteps    | 34272          |
# | value_loss         | 458.59067      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 6.314001e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.058         |
# | fps                | 834            |
# | nupdates           | 35             |
# | policy_entropy     | 2.854557       |
# | policy_loss        | -0.00051618536 |
# | serial_timesteps   | 8750           |
# | time_elapsed       | 41.9           |
# | total_timesteps    | 35280          |
# | value_loss         | 396.5803       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.4443063e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0181       |
# | fps                | 792           |
# | nupdates           | 36            |
# | policy_entropy     | 2.854457      |
# | policy_loss        | -0.0007238407 |
# | serial_timesteps   | 9000          |
# | time_elapsed       | 43.1          |
# | total_timesteps    | 36288         |
# | value_loss         | 367.8539      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.811082e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0127        |
# | fps                | 855            |
# | nupdates           | 37             |
# | policy_entropy     | 2.8539972      |
# | policy_loss        | -0.00010234401 |
# | serial_timesteps   | 9250           |
# | time_elapsed       | 44.3           |
# | total_timesteps    | 37296          |
# | value_loss         | 359.88235      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.2882155e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00867       |
# | fps                | 827            |
# | nupdates           | 38             |
# | policy_entropy     | 2.8538046      |
# | policy_loss        | -0.00035662454 |
# | serial_timesteps   | 9500           |
# | time_elapsed       | 45.5           |
# | total_timesteps    | 38304          |
# | value_loss         | 197.35555      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.724456e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0138       |
# | fps                | 767           |
# | nupdates           | 39            |
# | policy_entropy     | 2.8533452     |
# | policy_loss        | -0.0002751111 |
# | serial_timesteps   | 9750          |
# | time_elapsed       | 46.7          |
# | total_timesteps    | 39312         |
# | value_loss         | 190.16263     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.4005333e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0225        |
# | fps                | 852            |
# | nupdates           | 40             |
# | policy_entropy     | 2.85401        |
# | policy_loss        | -0.00019709925 |
# | serial_timesteps   | 10000          |
# | time_elapsed       | 48             |
# | total_timesteps    | 40320          |
# | value_loss         | 448.2123       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.6809785e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0482        |
# | fps                | 810            |
# | nupdates           | 41             |
# | policy_entropy     | 2.8549156      |
# | policy_loss        | -0.00015132922 |
# | serial_timesteps   | 10250          |
# | time_elapsed       | 49.2           |
# | total_timesteps    | 41328          |
# | value_loss         | 368.3815       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 4.2814936e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00264       |
# | fps                | 837            |
# | nupdates           | 42             |
# | policy_entropy     | 2.8558362      |
# | policy_loss        | -0.00070718816 |
# | serial_timesteps   | 10500          |
# | time_elapsed       | 50.5           |
# | total_timesteps    | 42336          |
# | value_loss         | 197.8258       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 4.052723e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0132        |
# | fps                | 811            |
# | nupdates           | 43             |
# | policy_entropy     | 2.8562028      |
# | policy_loss        | -0.00092908955 |
# | serial_timesteps   | 10750          |
# | time_elapsed       | 51.7           |
# | total_timesteps    | 43344          |
# | value_loss         | 342.48453      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.3114259e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.000354      |
# | fps                | 804            |
# | nupdates           | 44             |
# | policy_entropy     | 2.8561544      |
# | policy_loss        | -0.00046216996 |
# | serial_timesteps   | 11000          |
# | time_elapsed       | 52.9           |
# | total_timesteps    | 44352          |
# | value_loss         | 309.61893      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.1378582e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0295       |
# | fps                | 879           |
# | nupdates           | 45            |
# | policy_entropy     | 2.8566282     |
# | policy_loss        | -0.0001002972 |
# | serial_timesteps   | 11250         |
# | time_elapsed       | 54.1          |
# | total_timesteps    | 45360         |
# | value_loss         | 412.80466     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.7931396e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0145       |
# | fps                | 808           |
# | nupdates           | 46            |
# | policy_entropy     | 2.8575065     |
# | policy_loss        | -0.0006684684 |
# | serial_timesteps   | 11500         |
# | time_elapsed       | 55.3          |
# | total_timesteps    | 46368         |
# | value_loss         | 227.61946     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.445348e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0223       |
# | fps                | 842           |
# | nupdates           | 47            |
# | policy_entropy     | 2.8577728     |
# | policy_loss        | -0.0006710541 |
# | serial_timesteps   | 11750         |
# | time_elapsed       | 56.5          |
# | total_timesteps    | 47376         |
# | value_loss         | 361.16562     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.344471e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00659      |
# | fps                | 775           |
# | nupdates           | 48            |
# | policy_entropy     | 2.8577518     |
# | policy_loss        | -0.0013226282 |
# | serial_timesteps   | 12000         |
# | time_elapsed       | 57.7          |
# | total_timesteps    | 48384         |
# | value_loss         | 348.45422     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.5765766e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00947       |
# | fps                | 793            |
# | nupdates           | 49             |
# | policy_entropy     | 2.8589852      |
# | policy_loss        | -9.4510186e-05 |
# | serial_timesteps   | 12250          |
# | time_elapsed       | 59             |
# | total_timesteps    | 49392          |
# | value_loss         | 203.41377      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 4.0123392e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00648      |
# | fps                | 827           |
# | nupdates           | 50            |
# | policy_entropy     | 2.860804      |
# | policy_loss        | -0.0008572998 |
# | serial_timesteps   | 12500         |
# | time_elapsed       | 60.3          |
# | total_timesteps    | 50400         |
# | value_loss         | 218.68082     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 6.6171815e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0147        |
# | fps                | 808            |
# | nupdates           | 51             |
# | policy_entropy     | 2.862832       |
# | policy_loss        | -0.00067031756 |
# | serial_timesteps   | 12750          |
# | time_elapsed       | 61.5           |
# | total_timesteps    | 51408          |
# | value_loss         | 399.31244      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 4.0237745e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0307       |
# | fps                | 817           |
# | nupdates           | 52            |
# | policy_entropy     | 2.8634558     |
# | policy_loss        | -0.0005478467 |
# | serial_timesteps   | 13000         |
# | time_elapsed       | 62.7          |
# | total_timesteps    | 52416         |
# | value_loss         | 395.61307     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.4926935e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00193      |
# | fps                | 809           |
# | nupdates           | 53            |
# | policy_entropy     | 2.8632805     |
# | policy_loss        | -0.0015082931 |
# | serial_timesteps   | 13250         |
# | time_elapsed       | 63.9          |
# | total_timesteps    | 53424         |
# | value_loss         | 367.63333     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.0752445e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0872       |
# | fps                | 803           |
# | nupdates           | 54            |
# | policy_entropy     | 2.8633947     |
# | policy_loss        | -0.0007187666 |
# | serial_timesteps   | 13500         |
# | time_elapsed       | 65.2          |
# | total_timesteps    | 54432         |
# | value_loss         | 356.7227      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00025715915 |
# | clipfrac           | 0.00025       |
# | explained_variance | -0.0137       |
# | fps                | 810           |
# | nupdates           | 55            |
# | policy_entropy     | 2.8653052     |
# | policy_loss        | -0.0010446124 |
# | serial_timesteps   | 13750         |
# | time_elapsed       | 66.4          |
# | total_timesteps    | 55440         |
# | value_loss         | 320.14398     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.12597e-05    |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0238         |
# | fps                | 601            |
# | nupdates           | 56             |
# | policy_entropy     | 2.8667834      |
# | policy_loss        | -0.00034965677 |
# | serial_timesteps   | 14000          |
# | time_elapsed       | 67.7           |
# | total_timesteps    | 56448          |
# | value_loss         | 143.78197      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.6617388e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00967       |
# | fps                | 729           |
# | nupdates           | 57            |
# | policy_entropy     | 2.8676546     |
# | policy_loss        | -0.0009279702 |
# | serial_timesteps   | 14250         |
# | time_elapsed       | 69.3          |
# | total_timesteps    | 57456         |
# | value_loss         | 189.11661     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0029175451  |
# | clipfrac           | 0.02875       |
# | explained_variance | -0.00578      |
# | fps                | 787           |
# | nupdates           | 58            |
# | policy_entropy     | 2.8663116     |
# | policy_loss        | -0.0058049336 |
# | serial_timesteps   | 14500         |
# | time_elapsed       | 70.7          |
# | total_timesteps    | 58464         |
# | value_loss         | 148.69151     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.002257773  |
# | clipfrac           | 0.01625      |
# | explained_variance | -0.00635     |
# | fps                | 824          |
# | nupdates           | 59           |
# | policy_entropy     | 2.860987     |
# | policy_loss        | -0.004139369 |
# | serial_timesteps   | 14750        |
# | time_elapsed       | 72           |
# | total_timesteps    | 59472        |
# | value_loss         | 183.44717    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00058296265 |
# | clipfrac           | 0.00075       |
# | explained_variance | -0.00395      |
# | fps                | 732           |
# | nupdates           | 60            |
# | policy_entropy     | 2.8553994     |
# | policy_loss        | -0.0006533718 |
# | serial_timesteps   | 15000         |
# | time_elapsed       | 73.2          |
# | total_timesteps    | 60480         |
# | value_loss         | 695.2001      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.658375e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.038         |
# | fps                | 609           |
# | nupdates           | 61            |
# | policy_entropy     | 2.853183      |
# | policy_loss        | -0.0002678751 |
# | serial_timesteps   | 15250         |
# | time_elapsed       | 74.6          |
# | total_timesteps    | 61488         |
# | value_loss         | 257.16235     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.4376408e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00535        |
# | fps                | 524            |
# | nupdates           | 62             |
# | policy_entropy     | 2.852376       |
# | policy_loss        | -0.00013489905 |
# | serial_timesteps   | 15500          |
# | time_elapsed       | 76.2           |
# | total_timesteps    | 62496          |
# | value_loss         | 324.0538       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00012830472 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0227        |
# | fps                | 445           |
# | nupdates           | 63            |
# | policy_entropy     | 2.8506749     |
# | policy_loss        | -0.0011965728 |
# | serial_timesteps   | 15750         |
# | time_elapsed       | 78.1          |
# | total_timesteps    | 63504         |
# | value_loss         | 175.38983     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00028357052 |
# | clipfrac           | 0.00025       |
# | explained_variance | 0.00491       |
# | fps                | 519           |
# | nupdates           | 64            |
# | policy_entropy     | 2.8487039     |
# | policy_loss        | -0.0013876004 |
# | serial_timesteps   | 16000         |
# | time_elapsed       | 80.4          |
# | total_timesteps    | 64512         |
# | value_loss         | 101.49412     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006326812  |
# | clipfrac           | 0.00075       |
# | explained_variance | 0.0517        |
# | fps                | 440           |
# | nupdates           | 65            |
# | policy_entropy     | 2.8466053     |
# | policy_loss        | -0.0011891716 |
# | serial_timesteps   | 16250         |
# | time_elapsed       | 82.3          |
# | total_timesteps    | 65520         |
# | value_loss         | 85.73243      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000654577   |
# | clipfrac           | 0.00225       |
# | explained_variance | 0.168         |
# | fps                | 406           |
# | nupdates           | 66            |
# | policy_entropy     | 2.8464947     |
# | policy_loss        | -0.0037081777 |
# | serial_timesteps   | 16500         |
# | time_elapsed       | 84.6          |
# | total_timesteps    | 66528         |
# | value_loss         | 49.073265     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001290227   |
# | clipfrac           | 0.00825       |
# | explained_variance | 0.0549        |
# | fps                | 444           |
# | nupdates           | 67            |
# | policy_entropy     | 2.8492477     |
# | policy_loss        | -0.0055187074 |
# | serial_timesteps   | 16750         |
# | time_elapsed       | 87            |
# | total_timesteps    | 67536         |
# | value_loss         | 86.094444     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0025222427  |
# | clipfrac           | 0.0235        |
# | explained_variance | 0.0727        |
# | fps                | 464           |
# | nupdates           | 68            |
# | policy_entropy     | 2.8519979     |
# | policy_loss        | -0.0050559165 |
# | serial_timesteps   | 17000         |
# | time_elapsed       | 89.3          |
# | total_timesteps    | 68544         |
# | value_loss         | 125.58696     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00081988866 |
# | clipfrac           | 0.00175       |
# | explained_variance | 0.0391        |
# | fps                | 603           |
# | nupdates           | 69            |
# | policy_entropy     | 2.8534331     |
# | policy_loss        | -0.0019429807 |
# | serial_timesteps   | 17250         |
# | time_elapsed       | 91.5          |
# | total_timesteps    | 69552         |
# | value_loss         | 129.02975     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019229621 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.133         |
# | fps                | 548           |
# | nupdates           | 70            |
# | policy_entropy     | 2.853309      |
# | policy_loss        | -0.0016762026 |
# | serial_timesteps   | 17500         |
# | time_elapsed       | 93.1          |
# | total_timesteps    | 70560         |
# | value_loss         | 68.80144      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005144858  |
# | clipfrac           | 0.00125       |
# | explained_variance | 0.0697        |
# | fps                | 509           |
# | nupdates           | 71            |
# | policy_entropy     | 2.8541028     |
# | policy_loss        | -0.0015437523 |
# | serial_timesteps   | 17750         |
# | time_elapsed       | 94.9          |
# | total_timesteps    | 71568         |
# | value_loss         | 103.661255    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00048405572 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0858        |
# | fps                | 438           |
# | nupdates           | 72            |
# | policy_entropy     | 2.8564851     |
# | policy_loss        | -0.0012560898 |
# | serial_timesteps   | 18000         |
# | time_elapsed       | 96.9          |
# | total_timesteps    | 72576         |
# | value_loss         | 89.47124      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00092270126 |
# | clipfrac           | 0.0034999999  |
# | explained_variance | 0.0387        |
# | fps                | 448           |
# | nupdates           | 73            |
# | policy_entropy     | 2.8587413     |
# | policy_loss        | -0.004716703  |
# | serial_timesteps   | 18250         |
# | time_elapsed       | 99.2          |
# | total_timesteps    | 73584         |
# | value_loss         | 317.21335     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006902963  |
# | clipfrac           | 0.0015        |
# | explained_variance | 0.0865        |
# | fps                | 454           |
# | nupdates           | 74            |
# | policy_entropy     | 2.85937       |
# | policy_loss        | -0.0011340611 |
# | serial_timesteps   | 18500         |
# | time_elapsed       | 101           |
# | total_timesteps    | 74592         |
# | value_loss         | 201.10309     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.209419e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0417        |
# | fps                | 481           |
# | nupdates           | 75            |
# | policy_entropy     | 2.858395      |
# | policy_loss        | -0.0010873172 |
# | serial_timesteps   | 18750         |
# | time_elapsed       | 104           |
# | total_timesteps    | 75600         |
# | value_loss         | 141.79938     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00040911516 |
# | clipfrac           | 0.00075       |
# | explained_variance | 0.023         |
# | fps                | 500           |
# | nupdates           | 76            |
# | policy_entropy     | 2.853931      |
# | policy_loss        | -0.001508303  |
# | serial_timesteps   | 19000         |
# | time_elapsed       | 106           |
# | total_timesteps    | 76608         |
# | value_loss         | 182.23264     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0004150143 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.078        |
# | fps                | 499          |
# | nupdates           | 77           |
# | policy_entropy     | 2.8491352    |
# | policy_loss        | -0.000698618 |
# | serial_timesteps   | 19250        |
# | time_elapsed       | 108          |
# | total_timesteps    | 77616        |
# | value_loss         | 137.41385    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0006655718  |
# | clipfrac           | 0.0034999999  |
# | explained_variance | 0.0494        |
# | fps                | 581           |
# | nupdates           | 78            |
# | policy_entropy     | 2.847319      |
# | policy_loss        | -0.0033562067 |
# | serial_timesteps   | 19500         |
# | time_elapsed       | 110           |
# | total_timesteps    | 78624         |
# | value_loss         | 96.28621      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0014667364  |
# | clipfrac           | 0.009750001   |
# | explained_variance | 0.0751        |
# | fps                | 514           |
# | nupdates           | 79            |
# | policy_entropy     | 2.8436916     |
# | policy_loss        | -0.0035269097 |
# | serial_timesteps   | 19750         |
# | time_elapsed       | 111           |
# | total_timesteps    | 79632         |
# | value_loss         | 72.18471      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00087057427 |
# | clipfrac           | 0.00175       |
# | explained_variance | 0.0467        |
# | fps                | 409           |
# | nupdates           | 80            |
# | policy_entropy     | 2.8378446     |
# | policy_loss        | -0.0023135056 |
# | serial_timesteps   | 20000         |
# | time_elapsed       | 113           |
# | total_timesteps    | 80640         |
# | value_loss         | 110.765144    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00015661134  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.116          |
# | fps                | 373            |
# | nupdates           | 81             |
# | policy_entropy     | 2.8359914      |
# | policy_loss        | -0.00050754525 |
# | serial_timesteps   | 20250          |
# | time_elapsed       | 116            |
# | total_timesteps    | 81648          |
# | value_loss         | 88.99394       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0005729322  |
# | clipfrac           | 0.0035        |
# | explained_variance | -0.00655      |
# | fps                | 528           |
# | nupdates           | 82            |
# | policy_entropy     | 2.8358274     |
# | policy_loss        | -0.0038133895 |
# | serial_timesteps   | 20500         |
# | time_elapsed       | 119           |
# | total_timesteps    | 82656         |
# | value_loss         | 209.53284     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00049653306 |
# | clipfrac           | 0.00075       |
# | explained_variance | -0.00903      |
# | fps                | 456           |
# | nupdates           | 83            |
# | policy_entropy     | 2.8360841     |
# | policy_loss        | 0.00046733115 |
# | serial_timesteps   | 20750         |
# | time_elapsed       | 120           |
# | total_timesteps    | 83664         |
# | value_loss         | 163.01367     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00040593222 |
# | clipfrac           | 0.0005        |
# | explained_variance | 0.186         |
# | fps                | 411           |
# | nupdates           | 84            |
# | policy_entropy     | 2.8367014     |
# | policy_loss        | -0.0010883383 |
# | serial_timesteps   | 21000         |
# | time_elapsed       | 123           |
# | total_timesteps    | 84672         |
# | value_loss         | 57.09067      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00096949656 |
# | clipfrac           | 0.0045        |
# | explained_variance | 0.134         |
# | fps                | 414           |
# | nupdates           | 85            |
# | policy_entropy     | 2.8336055     |
# | policy_loss        | -0.0030940927 |
# | serial_timesteps   | 21250         |
# | time_elapsed       | 125           |
# | total_timesteps    | 85680         |
# | value_loss         | 65.74599      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0009376253  |
# | clipfrac           | 0.00275       |
# | explained_variance | 0.0738        |
# | fps                | 497           |
# | nupdates           | 86            |
# | policy_entropy     | 2.8303583     |
# | policy_loss        | -0.0025144273 |
# | serial_timesteps   | 21500         |
# | time_elapsed       | 127           |
# | total_timesteps    | 86688         |
# | value_loss         | 134.36609     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.001368815  |
# | clipfrac           | 0.01175      |
# | explained_variance | 0.0705       |
# | fps                | 566          |
# | nupdates           | 87           |
# | policy_entropy     | 2.8287888    |
# | policy_loss        | -0.002828067 |
# | serial_timesteps   | 21750        |
# | time_elapsed       | 129          |
# | total_timesteps    | 87696        |
# | value_loss         | 97.83535     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0016804058  |
# | clipfrac           | 0.00775       |
# | explained_variance | -0.00483      |
# | fps                | 595           |
# | nupdates           | 88            |
# | policy_entropy     | 2.8276358     |
# | policy_loss        | -0.0029793116 |
# | serial_timesteps   | 22000         |
# | time_elapsed       | 131           |
# | total_timesteps    | 88704         |
# | value_loss         | 291.67993     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013884535  |
# | clipfrac           | 0.00325       |
# | explained_variance | 0.00596       |
# | fps                | 522           |
# | nupdates           | 89            |
# ...
# | policy_entropy     | 2.7375107     |
# | policy_loss        | -0.0027817884 |
# | serial_timesteps   | 242250        |
# | time_elapsed       | 2.09e+03      |
# | total_timesteps    | 976752        |
# | value_loss         | 4.7889967     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019994741  |
# | clipfrac           | 0.0175        |
# | explained_variance | 0.619         |
# | fps                | 436           |
# | nupdates           | 970           |
# | policy_entropy     | 2.7376075     |
# | policy_loss        | -0.0017770235 |
# | serial_timesteps   | 242500        |
# | time_elapsed       | 2.09e+03      |
# | total_timesteps    | 977760        |
# | value_loss         | 34.983574     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.002447018  |
# | clipfrac           | 0.021499999  |
# | explained_variance | 0.481        |
# | fps                | 496          |
# | nupdates           | 971          |
# | policy_entropy     | 2.7392712    |
# | policy_loss        | -0.006667463 |
# | serial_timesteps   | 242750       |
# | time_elapsed       | 2.09e+03     |
# | total_timesteps    | 978768       |
# | value_loss         | 49.082554    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.0002599866   |
# | clipfrac           | 0.00025        |
# | explained_variance | 0.442          |
# | fps                | 568            |
# | nupdates           | 972            |
# | policy_entropy     | 2.740095       |
# | policy_loss        | -0.00068819115 |
# | serial_timesteps   | 243000         |
# | time_elapsed       | 2.09e+03       |
# | total_timesteps    | 979776         |
# | value_loss         | 52.266693      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.006685471   |
# | clipfrac           | 0.089999996   |
# | explained_variance | 0.603         |
# | fps                | 464           |
# | nupdates           | 973           |
# | policy_entropy     | 2.7401817     |
# | policy_loss        | -0.0036036812 |
# | serial_timesteps   | 243250        |
# | time_elapsed       | 2.1e+03       |
# | total_timesteps    | 980784        |
# | value_loss         | 32.76827      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0023236119  |
# | clipfrac           | 0.017500002   |
# | explained_variance | 0.598         |
# | fps                | 455           |
# | nupdates           | 974           |
# | policy_entropy     | 2.7413414     |
# | policy_loss        | -0.0033430443 |
# | serial_timesteps   | 243500        |
# | time_elapsed       | 2.1e+03       |
# | total_timesteps    | 981792        |
# | value_loss         | 10.275275     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017836131  |
# | clipfrac           | 0.01475       |
# | explained_variance | 0.761         |
# | fps                | 502           |
# | nupdates           | 975           |
# | policy_entropy     | 2.7403715     |
# | policy_loss        | -0.0017176624 |
# | serial_timesteps   | 243750        |
# | time_elapsed       | 2.1e+03       |
# | total_timesteps    | 982800        |
# | value_loss         | 8.493237      |
# --------------------------------------
# ------------------------------------
# | approxkl           | 0.002736924 |
# | clipfrac           | 0.028       |
# | explained_variance | 0.601       |
# | fps                | 507         |
# | nupdates           | 976         |
# | policy_entropy     | 2.738868    |
# | policy_loss        | 9.11573e-05 |
# | serial_timesteps   | 244000      |
# | time_elapsed       | 2.1e+03     |
# | total_timesteps    | 983808      |
# | value_loss         | 32.458572   |
# ------------------------------------
# --------------------------------------
# | approxkl           | 0.0028661317  |
# | clipfrac           | 0.027250001   |
# | explained_variance | 0.745         |
# | fps                | 468           |
# | nupdates           | 977           |
# | policy_entropy     | 2.7395298     |
# | policy_loss        | -0.0028007936 |
# | serial_timesteps   | 244250        |
# | time_elapsed       | 2.1e+03       |
# | total_timesteps    | 984816        |
# | value_loss         | 3.3438308     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005744621  |
# | clipfrac           | 0.00325       |
# | explained_variance | 0.204         |
# | fps                | 370           |
# | nupdates           | 978           |
# | policy_entropy     | 2.7385602     |
# | policy_loss        | -0.0021886316 |
# | serial_timesteps   | 244500        |
# | time_elapsed       | 2.11e+03      |
# | total_timesteps    | 985824        |
# | value_loss         | 120.61685     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0016139077  |
# | clipfrac           | 0.00825       |
# | explained_variance | 0.936         |
# | fps                | 524           |
# | nupdates           | 979           |
# | policy_entropy     | 2.7378976     |
# | policy_loss        | -0.0007980128 |
# | serial_timesteps   | 244750        |
# | time_elapsed       | 2.11e+03      |
# | total_timesteps    | 986832        |
# | value_loss         | 2.483998      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.001863884    |
# | clipfrac           | 0.01175        |
# | explained_variance | 0.846          |
# | fps                | 489            |
# | nupdates           | 980            |
# | policy_entropy     | 2.7358072      |
# | policy_loss        | -1.9370185e-05 |
# | serial_timesteps   | 245000         |
# | time_elapsed       | 2.11e+03       |
# | total_timesteps    | 987840         |
# | value_loss         | 4.440522       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0031864946  |
# | clipfrac           | 0.04225       |
# | explained_variance | 0.759         |
# | fps                | 400           |
# | nupdates           | 981           |
# | policy_entropy     | 2.7351773     |
# | policy_loss        | -0.0049695787 |
# | serial_timesteps   | 245250        |
# | time_elapsed       | 2.11e+03      |
# | total_timesteps    | 988848        |
# | value_loss         | 3.944662      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0048447     |
# | clipfrac           | 0.060500003   |
# | explained_variance | 0.916         |
# | fps                | 335           |
# | nupdates           | 982           |
# | policy_entropy     | 2.7330365     |
# | policy_loss        | -0.0070393793 |
# | serial_timesteps   | 245500        |
# | time_elapsed       | 2.12e+03      |
# | total_timesteps    | 989856        |
# | value_loss         | 3.5837        |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0024965557   |
# | clipfrac           | 0.02475        |
# | explained_variance | 0.321          |
# | fps                | 477            |
# | nupdates           | 983            |
# | policy_entropy     | 2.732073       |
# | policy_loss        | -0.00016150763 |
# | serial_timesteps   | 245750         |
# | time_elapsed       | 2.12e+03       |
# | total_timesteps    | 990864         |
# | value_loss         | 51.893997      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0070093255  |
# | clipfrac           | 0.09199999    |
# | explained_variance | 0.871         |
# | fps                | 500           |
# | nupdates           | 984           |
# | policy_entropy     | 2.736896      |
# | policy_loss        | -0.0045516184 |
# | serial_timesteps   | 246000        |
# | time_elapsed       | 2.12e+03      |
# | total_timesteps    | 991872        |
# | value_loss         | 6.7378187     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0016074261  |
# | clipfrac           | 0.01425       |
# | explained_variance | 0.468         |
# | fps                | 526           |
# | nupdates           | 985           |
# | policy_entropy     | 2.7365906     |
# | policy_loss        | -0.0012163392 |
# | serial_timesteps   | 246250        |
# | time_elapsed       | 2.12e+03      |
# | total_timesteps    | 992880        |
# | value_loss         | 32.747547     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00041083305  |
# | clipfrac           | 0.00025        |
# | explained_variance | 0.335          |
# | fps                | 452            |
# | nupdates           | 986            |
# | policy_entropy     | 2.7359126      |
# | policy_loss        | -0.00032931924 |
# | serial_timesteps   | 246500         |
# | time_elapsed       | 2.12e+03       |
# | total_timesteps    | 993888         |
# | value_loss         | 149.70866      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0039249216 |
# | clipfrac           | 0.0525       |
# | explained_variance | 0.827        |
# | fps                | 474          |
# | nupdates           | 987          |
# | policy_entropy     | 2.736384     |
# | policy_loss        | -0.004060014 |
# | serial_timesteps   | 246750       |
# | time_elapsed       | 2.13e+03     |
# | total_timesteps    | 994896       |
# | value_loss         | 2.1464906    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00801032    |
# | clipfrac           | 0.114         |
# | explained_variance | 0.549         |
# | fps                | 398           |
# | nupdates           | 988           |
# | policy_entropy     | 2.73721       |
# | policy_loss        | -0.0036578164 |
# | serial_timesteps   | 247000        |
# | time_elapsed       | 2.13e+03      |
# | total_timesteps    | 995904        |
# | value_loss         | 5.4228015     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0030857718  |
# | clipfrac           | 0.028499998   |
# | explained_variance | 0.252         |
# | fps                | 442           |
# | nupdates           | 989           |
# | policy_entropy     | 2.7348564     |
# | policy_loss        | -0.0032447497 |
# | serial_timesteps   | 247250        |
# | time_elapsed       | 2.13e+03      |
# | total_timesteps    | 996912        |
# | value_loss         | 98.9048       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00047786906 |
# | clipfrac           | 0.00075       |
# | explained_variance | 0.921         |
# | fps                | 457           |
# | nupdates           | 990           |
# | policy_entropy     | 2.7337017     |
# | policy_loss        | -0.0007124421 |
# | serial_timesteps   | 247500        |
# | time_elapsed       | 2.13e+03      |
# | total_timesteps    | 997920        |
# | value_loss         | 2.952924      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0041654324  |
# | clipfrac           | 0.05075       |
# | explained_variance | 0.826         |
# | fps                | 421           |
# | nupdates           | 991           |
# | policy_entropy     | 2.7336698     |
# | policy_loss        | -0.0031632122 |
# | serial_timesteps   | 247750        |
# | time_elapsed       | 2.14e+03      |
# | total_timesteps    | 998928        |
# | value_loss         | 8.913413      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0020115138  |
# | clipfrac           | 0.014         |
# | explained_variance | 0.469         |
# | fps                | 329           |
# | nupdates           | 992           |
# | policy_entropy     | 2.7317019     |
# | policy_loss        | -0.0024399655 |
# | serial_timesteps   | 248000        |
# | time_elapsed       | 2.14e+03      |
# | total_timesteps    | 999936        |
# | value_loss         | 44.96919      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00029152556  |
# | clipfrac           | 0.0005         |
# | explained_variance | 0.423          |
# | fps                | 474            |
# | nupdates           | 993            |
# | policy_entropy     | 2.7294295      |
# | policy_loss        | -0.00042207853 |
# | serial_timesteps   | 248250         |
# | time_elapsed       | 2.14e+03       |
# | total_timesteps    | 1000944        |
# | value_loss         | 75.859055      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00092451565 |
# | clipfrac           | 0.01075       |
# | explained_variance | 0.406         |
# | fps                | 498           |
# | nupdates           | 994           |
# | policy_entropy     | 2.7286246     |
# | policy_loss        | -0.0046896623 |
# | serial_timesteps   | 248500        |
# | time_elapsed       | 2.14e+03      |
# | total_timesteps    | 1001952       |
# | value_loss         | 41.070194     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.003758839   |
# | clipfrac           | 0.0445        |
# | explained_variance | 0.376         |
# | fps                | 401           |
# | nupdates           | 995           |
# | policy_entropy     | 2.7260022     |
# | policy_loss        | -0.0008766848 |
# | serial_timesteps   | 248750        |
# | time_elapsed       | 2.15e+03      |
# | total_timesteps    | 1002960       |
# | value_loss         | 17.705103     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010673238  |
# | clipfrac           | 0.00175       |
# | explained_variance | 0.63          |
# | fps                | 326           |
# | nupdates           | 996           |
# | policy_entropy     | 2.7221897     |
# | policy_loss        | -0.0015000311 |
# | serial_timesteps   | 249000        |
# | time_elapsed       | 2.15e+03      |
# | total_timesteps    | 1003968       |
# | value_loss         | 4.0014925     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0038976986  |
# | clipfrac           | 0.047         |
# | explained_variance | 0.818         |
# | fps                | 404           |
# | nupdates           | 997           |
# | policy_entropy     | 2.7179835     |
# | policy_loss        | -0.0034862643 |
# | serial_timesteps   | 249250        |
# | time_elapsed       | 2.15e+03      |
# | total_timesteps    | 1004976       |
# | value_loss         | 7.3807187     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.004065322   |
# | clipfrac           | 0.04825       |
# | explained_variance | 0.535         |
# | fps                | 453           |
# | nupdates           | 998           |
# | policy_entropy     | 2.717542      |
# | policy_loss        | -0.0053338283 |
# | serial_timesteps   | 249500        |
# | time_elapsed       | 2.15e+03      |
# | total_timesteps    | 1005984       |
# | value_loss         | 38.5675       |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.002715258  |
# | clipfrac           | 0.02275      |
# | explained_variance | 0.445        |
# | fps                | 471          |
# | nupdates           | 999          |
# | policy_entropy     | 2.7203245    |
# | policy_loss        | 0.0007363907 |
# | serial_timesteps   | 249750       |
# | time_elapsed       | 2.16e+03     |
# | total_timesteps    | 1006992      |
# | value_loss         | 34.38342     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0006561212  |
# | clipfrac           | 0.003         |
# | explained_variance | 0.284         |
# | fps                | 428           |
# | nupdates           | 1000          |
# | policy_entropy     | 2.7222936     |
# | policy_loss        | 9.1305235e-05 |
# | serial_timesteps   | 250000        |
# | time_elapsed       | 2.16e+03      |
# | total_timesteps    | 1008000       |
# | value_loss         | 123.114716    |
# --------------------------------------

# %%
from stable_baselines.common.policies import FeedForwardPolicy

# %%
model = PPO2.load(final_model_dir)

# Enjoy trained agent
env = gym.make(env_name)
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
