# %%
import os
import gym
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import SubprocVecEnv
from stable_baselines.common.vec_env import DummyVecEnv
from utils.ppo import PPO
from utils.models import Policy, CNNPolicy

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
LOGS = os.getcwd()

# %%
def makedirs(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
env_name = 'BipedalWalker-v2'
run_id = 1
n_steps = 250
total_timesteps = 10000000
cnn_policy = False

LOGS = os.path.join(LOGS, env_name, 'run{}'.format(run_id))
makedirs(LOGS)
tb_log = os.path.join(LOGS, 'tb')
makedirs(tb_log)
model_dir = os.path.join(LOGS, 'models')
makedirs(model_dir)
final_model_dir = os.path.join(LOGS, 'model')
n_cpu = 4

# %%
env = SubprocVecEnv([lambda: gym.make(env_name) for i in range(n_cpu)])

if cnn_policy:
    print('Using CNN policy network')
    model = PPO(CNNPolicy, env, n_steps=n_steps, tensorboard_log=tb_log, verbose=1, full_tensorboard_log=True)
else:
    print('Using MLP policy network')
    model = PPO(Policy, env, n_steps=n_steps, tensorboard_log=tb_log, verbose=1, full_tensorboard_log=True)
model.learn(total_timesteps, env, save_file=os.path.join(model_dir, 'model'))
model.save(final_model_dir)
del model # remove to demonstrate saving and loading
# Out:
# Using MLP policy network
# INFO:tensorflow:Summary name model/pi_fc0/w:0 is illegal; using model/pi_fc0/w_0 instead.
# INFO:tensorflow:Summary name model/pi_fc0/b:0 is illegal; using model/pi_fc0/b_0 instead.
# INFO:tensorflow:Summary name model/vf_fc0/w:0 is illegal; using model/vf_fc0/w_0 instead.
# INFO:tensorflow:Summary name model/vf_fc0/b:0 is illegal; using model/vf_fc0/b_0 instead.
# INFO:tensorflow:Summary name model/pi_fc1/w:0 is illegal; using model/pi_fc1/w_0 instead.
# INFO:tensorflow:Summary name model/pi_fc1/b:0 is illegal; using model/pi_fc1/b_0 instead.
# INFO:tensorflow:Summary name model/vf_fc1/w:0 is illegal; using model/vf_fc1/w_0 instead.
# INFO:tensorflow:Summary name model/vf_fc1/b:0 is illegal; using model/vf_fc1/b_0 instead.
# INFO:tensorflow:Summary name model/vf/w:0 is illegal; using model/vf/w_0 instead.
# INFO:tensorflow:Summary name model/vf/b:0 is illegal; using model/vf/b_0 instead.
# INFO:tensorflow:Summary name model/pi/w:0 is illegal; using model/pi/w_0 instead.
# INFO:tensorflow:Summary name model/pi/b:0 is illegal; using model/pi/b_0 instead.
# INFO:tensorflow:Summary name model/pi/logstd:0 is illegal; using model/pi/logstd_0 instead.
# INFO:tensorflow:Summary name model/q/w:0 is illegal; using model/q/w_0 instead.
# INFO:tensorflow:Summary name model/q/b:0 is illegal; using model/q/b_0 instead.
# INFO:tensorflow:Summary name model/pi_fc0/w:0/gradient is illegal; using model/pi_fc0/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc0/b:0/gradient is illegal; using model/pi_fc0/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc0/w:0/gradient is illegal; using model/vf_fc0/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc0/b:0/gradient is illegal; using model/vf_fc0/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc1/w:0/gradient is illegal; using model/pi_fc1/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc1/b:0/gradient is illegal; using model/pi_fc1/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc1/w:0/gradient is illegal; using model/vf_fc1/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc1/b:0/gradient is illegal; using model/vf_fc1/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf/w:0/gradient is illegal; using model/vf/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf/b:0/gradient is illegal; using model/vf/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/w:0/gradient is illegal; using model/pi/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/b:0/gradient is illegal; using model/pi/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/logstd:0/gradient is illegal; using model/pi/logstd_0/gradient instead.
# No of updates: 10000
# Total timesteps : 10000000
# Batch size: 1000
# --------------------------------------
# | approxkl           | 0.0003005803  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0129        |
# | fps                | 462           |
# | nupdates           | 1             |
# | policy_entropy     | 5.6787567     |
# | policy_loss        | -0.0020355335 |
# | serial_timesteps   | 250           |
# | time_elapsed       | 0.000455      |
# | total_timesteps    | 1008          |
# | value_loss         | 359.75467     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00011997898  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0162         |
# | fps                | 809            |
# | nupdates           | 2              |
# | policy_entropy     | 5.6843886      |
# | policy_loss        | -0.00024871432 |
# | serial_timesteps   | 500            |
# | time_elapsed       | 2.17           |
# | total_timesteps    | 2016           |
# | value_loss         | 126.41263      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00031807902 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.135        |
# | fps                | 768           |
# | nupdates           | 3             |
# | policy_entropy     | 5.685255      |
# | policy_loss        | -0.0024141665 |
# | serial_timesteps   | 750           |
# | time_elapsed       | 3.41          |
# | total_timesteps    | 3024          |
# | value_loss         | 0.75854546    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0010147913  |
# | clipfrac           | 0.00175       |
# | explained_variance | 0.165         |
# | fps                | 789           |
# | nupdates           | 4             |
# | policy_entropy     | 5.6851845     |
# | policy_loss        | -0.0036921466 |
# | serial_timesteps   | 1000          |
# | time_elapsed       | 4.71          |
# | total_timesteps    | 4032          |
# | value_loss         | 0.5359313     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0013296339 |
# | clipfrac           | 0.00375      |
# | explained_variance | 0.103        |
# | fps                | 822          |
# | nupdates           | 5            |
# | policy_entropy     | 5.6834216    |
# | policy_loss        | -0.003911665 |
# | serial_timesteps   | 1250         |
# | time_elapsed       | 5.98         |
# | total_timesteps    | 5040         |
# | value_loss         | 0.4497465    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0017675719  |
# | clipfrac           | 0.010500001   |
# | explained_variance | 0.188         |
# | fps                | 825           |
# | nupdates           | 6             |
# | policy_entropy     | 5.6815133     |
# | policy_loss        | -0.0035536801 |
# | serial_timesteps   | 1500          |
# | time_elapsed       | 7.2           |
# | total_timesteps    | 6048          |
# | value_loss         | 0.3008804     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00086417247 |
# | clipfrac           | 0.00025       |
# | explained_variance | 0.224         |
# | fps                | 817           |
# | nupdates           | 7             |
# | policy_entropy     | 5.6805997     |
# | policy_loss        | -0.002191846  |
# | serial_timesteps   | 1750          |
# | time_elapsed       | 8.41          |
# | total_timesteps    | 7056          |
# | value_loss         | 0.454924      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0007456586  |
# | clipfrac           | 0.0005        |
# | explained_variance | 0.00417       |
# | fps                | 727           |
# | nupdates           | 8             |
# | policy_entropy     | 5.6815033     |
# | policy_loss        | -0.0008665942 |
# | serial_timesteps   | 2000          |
# | time_elapsed       | 9.64          |
# | total_timesteps    | 8064          |
# | value_loss         | 67.0236       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00042264588 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0596       |
# | fps                | 797           |
# | nupdates           | 9             |
# | policy_entropy     | 5.6857977     |
# | policy_loss        | -0.001127294  |
# | serial_timesteps   | 2250          |
# | time_elapsed       | 11            |
# | total_timesteps    | 9072          |
# | value_loss         | 0.21726921    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017250369  |
# | clipfrac           | 0.0105        |
# | explained_variance | -0.00866      |
# | fps                | 756           |
# | nupdates           | 10            |
# | policy_entropy     | 5.6892686     |
# | policy_loss        | -0.0038834899 |
# | serial_timesteps   | 2500          |
# | time_elapsed       | 12.3          |
# | total_timesteps    | 10080         |
# | value_loss         | 0.12793611    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0024994519 |
# | clipfrac           | 0.0175       |
# | explained_variance | -0.0643      |
# | fps                | 758          |
# | nupdates           | 11           |
# | policy_entropy     | 5.6876435    |
# | policy_loss        | -0.003201112 |
# | serial_timesteps   | 2750         |
# | time_elapsed       | 13.6         |
# | total_timesteps    | 11088        |
# | value_loss         | 0.10016782   |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.00016729426  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0184        |
# | fps                | 745            |
# | nupdates           | 12             |
# | policy_entropy     | 5.6810856      |
# | policy_loss        | -0.00082313636 |
# | serial_timesteps   | 3000           |
# | time_elapsed       | 14.9           |
# | total_timesteps    | 12096          |
# | value_loss         | 0.08053862     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00068820996 |
# | clipfrac           | 0.00075       |
# | explained_variance | 0.000791      |
# | fps                | 746           |
# | nupdates           | 13            |
# | policy_entropy     | 5.6729407     |
# | policy_loss        | -0.0021678142 |
# | serial_timesteps   | 3250          |
# | time_elapsed       | 16.3          |
# | total_timesteps    | 13104         |
# | value_loss         | 0.08885931    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0011088367  |
# | clipfrac           | 0.00325       |
# | explained_variance | 0.227         |
# | fps                | 773           |
# | nupdates           | 14            |
# | policy_entropy     | 5.66863       |
# | policy_loss        | -0.0019453376 |
# | serial_timesteps   | 3500          |
# | time_elapsed       | 17.6          |
# | total_timesteps    | 14112         |
# | value_loss         | 0.42677584    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005225697  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00571      |
# | fps                | 782           |
# | nupdates           | 15            |
# | policy_entropy     | 5.6685276     |
# | policy_loss        | 0.00012907965 |
# | serial_timesteps   | 3750          |
# | time_elapsed       | 18.9          |
# | total_timesteps    | 15120         |
# | value_loss         | 233.36679     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00026230447 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0124        |
# | fps                | 816           |
# | nupdates           | 16            |
# | policy_entropy     | 5.6687384     |
# | policy_loss        | -0.0009839212 |
# | serial_timesteps   | 4000          |
# | time_elapsed       | 20.2          |
# | total_timesteps    | 16128         |
# | value_loss         | 123.541214    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0007616637   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0149         |
# | fps                | 840            |
# | nupdates           | 17             |
# | policy_entropy     | 5.669574       |
# | policy_loss        | -0.00013732427 |
# | serial_timesteps   | 4250           |
# | time_elapsed       | 21.4           |
# | total_timesteps    | 17136          |
# | value_loss         | 122.14657      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0010405794  |
# | clipfrac           | 0.0015        |
# | explained_variance | 0.0313        |
# | fps                | 825           |
# | nupdates           | 18            |
# | policy_entropy     | 5.672087      |
# | policy_loss        | -0.0005300391 |
# | serial_timesteps   | 4500          |
# | time_elapsed       | 22.6          |
# | total_timesteps    | 18144         |
# | value_loss         | 39.080093     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00022168038  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0205         |
# | fps                | 804            |
# | nupdates           | 19             |
# | policy_entropy     | 5.6738443      |
# | policy_loss        | -0.00077840977 |
# | serial_timesteps   | 4750           |
# | time_elapsed       | 23.8           |
# | total_timesteps    | 19152          |
# | value_loss         | 39.90006       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0028858583  |
# | clipfrac           | 0.03275       |
# | explained_variance | 0.265         |
# | fps                | 758           |
# | nupdates           | 20            |
# | policy_entropy     | 5.675667      |
# | policy_loss        | -0.0054953927 |
# | serial_timesteps   | 5000          |
# | time_elapsed       | 25.1          |
# | total_timesteps    | 20160         |
# | value_loss         | 0.056020148   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0009039091  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0307        |
# | fps                | 726           |
# | nupdates           | 21            |
# | policy_entropy     | 5.6715283     |
# | policy_loss        | 6.1171726e-05 |
# | serial_timesteps   | 5250          |
# | time_elapsed       | 26.4          |
# | total_timesteps    | 21168         |
# | value_loss         | 82.58005      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00024876886 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00512       |
# | fps                | 769           |
# | nupdates           | 22            |
# | policy_entropy     | 5.669967      |
# | policy_loss        | -6.73654e-06  |
# | serial_timesteps   | 5500          |
# | time_elapsed       | 27.8          |
# | total_timesteps    | 22176         |
# | value_loss         | 317.3294      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014001252 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0205        |
# | fps                | 737           |
# | nupdates           | 23            |
# | policy_entropy     | 5.6702895     |
# | policy_loss        | -0.0008552494 |
# | serial_timesteps   | 5750          |
# | time_elapsed       | 29.1          |
# | total_timesteps    | 23184         |
# | value_loss         | 79.93967      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00048831885 |
# | clipfrac           | 0.00025       |
# | explained_variance | -0.216        |
# | fps                | 769           |
# | nupdates           | 24            |
# | policy_entropy     | 5.6716866     |
# | policy_loss        | -0.0018727812 |
# | serial_timesteps   | 6000          |
# | time_elapsed       | 30.4          |
# | total_timesteps    | 24192         |
# | value_loss         | 0.10373083    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0019207792  |
# | clipfrac           | 0.01275       |
# | explained_variance | 0.0794        |
# | fps                | 802           |
# | nupdates           | 25            |
# | policy_entropy     | 5.669331      |
# | policy_loss        | -0.0022866155 |
# | serial_timesteps   | 6250          |
# | time_elapsed       | 31.7          |
# | total_timesteps    | 25200         |
# | value_loss         | 0.22674133    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00033496873 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.455         |
# | fps                | 772           |
# | nupdates           | 26            |
# | policy_entropy     | 5.6683555     |
# | policy_loss        | -0.0016251702 |
# | serial_timesteps   | 6500          |
# | time_elapsed       | 33            |
# | total_timesteps    | 26208         |
# | value_loss         | 0.060294934   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00095327647 |
# | clipfrac           | 0.00075       |
# | explained_variance | 0.338         |
# | fps                | 768           |
# | nupdates           | 27            |
# | policy_entropy     | 5.665755      |
# | policy_loss        | -0.0023689503 |
# | serial_timesteps   | 6750          |
# | time_elapsed       | 34.3          |
# | total_timesteps    | 27216         |
# | value_loss         | 0.066573374   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00096468057 |
# | clipfrac           | 0.002         |
# | explained_variance | 0.385         |
# | fps                | 775           |
# | nupdates           | 28            |
# | policy_entropy     | 5.6619387     |
# | policy_loss        | -0.0030926957 |
# | serial_timesteps   | 7000          |
# | time_elapsed       | 35.6          |
# | total_timesteps    | 28224         |
# | value_loss         | 0.06782583    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0014348213   |
# | clipfrac           | 0.0022500001   |
# | explained_variance | 0.0662         |
# | fps                | 775            |
# | nupdates           | 29             |
# | policy_entropy     | 5.659297       |
# | policy_loss        | -0.00046511763 |
# | serial_timesteps   | 7250           |
# | time_elapsed       | 36.9           |
# | total_timesteps    | 29232          |
# | value_loss         | 38.23678       |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0001404727 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0516       |
# | fps                | 774          |
# | nupdates           | 30           |
# | policy_entropy     | 5.659305     |
# | policy_loss        | 6.357266e-05 |
# | serial_timesteps   | 7500         |
# | time_elapsed       | 38.2         |
# | total_timesteps    | 30240        |
# | value_loss         | 38.58839     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00036230113 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0697        |
# | fps                | 792           |
# | nupdates           | 31            |
# | policy_entropy     | 5.6570673     |
# | policy_loss        | -0.0017565457 |
# | serial_timesteps   | 7750          |
# | time_elapsed       | 39.5          |
# | total_timesteps    | 31248         |
# | value_loss         | 35.838467     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002808182  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0772        |
# | fps                | 858           |
# | nupdates           | 32            |
# | policy_entropy     | 5.658225      |
# | policy_loss        | 0.00065063965 |
# | serial_timesteps   | 8000          |
# | time_elapsed       | 40.7          |
# | total_timesteps    | 32256         |
# | value_loss         | 75.370445     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014088348 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0693        |
# | fps                | 814           |
# | nupdates           | 33            |
# | policy_entropy     | 5.659475      |
# | policy_loss        | -0.000616763  |
# | serial_timesteps   | 8250          |
# | time_elapsed       | 41.9          |
# | total_timesteps    | 33264         |
# | value_loss         | 118.659706    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012677508 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0948        |
# | fps                | 767           |
# | nupdates           | 34            |
# | policy_entropy     | 5.6601615     |
# | policy_loss        | -0.0005167315 |
# | serial_timesteps   | 8500          |
# | time_elapsed       | 43.1          |
# | total_timesteps    | 34272         |
# | value_loss         | 74.18279      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00033019675 |
# | clipfrac           | 0.0005        |
# | explained_variance | 0.459         |
# | fps                | 884           |
# | nupdates           | 35            |
# | policy_entropy     | 5.659875      |
# | policy_loss        | -0.0010145775 |
# | serial_timesteps   | 8750          |
# | time_elapsed       | 44.4          |
# | total_timesteps    | 35280         |
# | value_loss         | 0.4105406     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00057915883 |
# | clipfrac           | 0.0005        |
# | explained_variance | 0.0669        |
# | fps                | 803           |
# | nupdates           | 36            |
# | policy_entropy     | 5.6594005     |
# | policy_loss        | 0.0018953811  |
# | serial_timesteps   | 9000          |
# | time_elapsed       | 45.6          |
# | total_timesteps    | 36288         |
# | value_loss         | 183.49547     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00018680227  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0473         |
# | fps                | 829            |
# | nupdates           | 37             |
# | policy_entropy     | 5.6580224      |
# | policy_loss        | -0.00022132967 |
# | serial_timesteps   | 9250           |
# | time_elapsed       | 46.8           |
# | total_timesteps    | 37296          |
# | value_loss         | 102.05069      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 4.9978244e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0767         |
# | fps                | 827            |
# | nupdates           | 38             |
# | policy_entropy     | 5.658468       |
# | policy_loss        | -0.00010980868 |
# | serial_timesteps   | 9500           |
# | time_elapsed       | 48             |
# | total_timesteps    | 38304          |
# | value_loss         | 109.37402      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00067522103 |
# | clipfrac           | 0.001         |
# | explained_variance | 0.543         |
# | fps                | 805           |
# | nupdates           | 39            |
# | policy_entropy     | 5.6606126     |
# | policy_loss        | -0.0035550175 |
# | serial_timesteps   | 9750          |
# | time_elapsed       | 49.2          |
# | total_timesteps    | 39312         |
# | value_loss         | 0.28514764    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0034427855 |
# | clipfrac           | 0.035499997  |
# | explained_variance | 0.711        |
# | fps                | 770          |
# | nupdates           | 40           |
# | policy_entropy     | 5.6619363    |
# | policy_loss        | -0.005549318 |
# | serial_timesteps   | 10000        |
# | time_elapsed       | 50.5         |
# | total_timesteps    | 40320        |
# | value_loss         | 0.2296259    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0030396034  |
# | clipfrac           | 0.037249997   |
# | explained_variance | 0.602         |
# | fps                | 826           |
# | nupdates           | 41            |
# | policy_entropy     | 5.659892      |
# | policy_loss        | -0.0057948097 |
# | serial_timesteps   | 10250         |
# | time_elapsed       | 51.8          |
# | total_timesteps    | 41328         |
# | value_loss         | 0.19480893    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0020405464  |
# | clipfrac           | 0.013250001   |
# | explained_variance | 0.832         |
# | fps                | 830           |
# | nupdates           | 42            |
# | policy_entropy     | 5.6545744     |
# | policy_loss        | -0.0035942749 |
# | serial_timesteps   | 10500         |
# | time_elapsed       | 53            |
# | total_timesteps    | 42336         |
# | value_loss         | 0.092441306   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0005618336   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0721         |
# | fps                | 791            |
# | nupdates           | 43             |
# | policy_entropy     | 5.6500583      |
# | policy_loss        | -0.00018588957 |
# | serial_timesteps   | 10750          |
# | time_elapsed       | 54.2           |
# | total_timesteps    | 43344          |
# | value_loss         | 38.1008        |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00023252185 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.05          |
# | fps                | 785           |
# | nupdates           | 44            |
# | policy_entropy     | 5.6493835     |
# | policy_loss        | 0.00014798385 |
# | serial_timesteps   | 11000         |
# | time_elapsed       | 55.5          |
# | total_timesteps    | 44352         |
# | value_loss         | 115.727135    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020864728 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0743        |
# | fps                | 775           |
# | nupdates           | 45            |
# | policy_entropy     | 5.6500826     |
# | policy_loss        | -0.0011060532 |
# | serial_timesteps   | 11250         |
# | time_elapsed       | 56.8          |
# | total_timesteps    | 45360         |
# | value_loss         | 73.652214     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00029951174 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0576        |
# | fps                | 782           |
# | nupdates           | 46            |
# | policy_entropy     | 5.6507587     |
# | policy_loss        | -0.00101497   |
# | serial_timesteps   | 11500         |
# | time_elapsed       | 58            |
# | total_timesteps    | 46368         |
# | value_loss         | 76.03463      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012220336 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0972        |
# | fps                | 793           |
# | nupdates           | 47            |
# | policy_entropy     | 5.651762      |
# | policy_loss        | 0.00023262878 |
# | serial_timesteps   | 11750         |
# | time_elapsed       | 59.3          |
# | total_timesteps    | 47376         |
# | value_loss         | 40.462116     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000355742   |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0932        |
# | fps                | 757           |
# | nupdates           | 48            |
# | policy_entropy     | 5.652645      |
# | policy_loss        | 5.5516066e-05 |
# | serial_timesteps   | 12000         |
# | time_elapsed       | 60.6          |
# | total_timesteps    | 48384         |
# | value_loss         | 55.3015       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0011758993  |
# | clipfrac           | 0.00475       |
# | explained_variance | 0.638         |
# | fps                | 807           |
# | nupdates           | 49            |
# | policy_entropy     | 5.65282       |
# | policy_loss        | -0.0015919305 |
# | serial_timesteps   | 12250         |
# | time_elapsed       | 61.9          |
# | total_timesteps    | 49392         |
# | value_loss         | 0.11259285    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00014858141  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.113          |
# | fps                | 809            |
# | nupdates           | 50             |
# | policy_entropy     | 5.65539        |
# | policy_loss        | -0.00028045528 |
# | serial_timesteps   | 12500          |
# | time_elapsed       | 63.2           |
# | total_timesteps    | 50400          |
# | value_loss         | 36.768074      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 6.669834e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0147       |
# | fps                | 767          |
# | nupdates           | 51           |
# | policy_entropy     | 5.65692      |
# | policy_loss        | 3.760854e-05 |
# | serial_timesteps   | 12750        |
# | time_elapsed       | 64.4         |
# | total_timesteps    | 51408        |
# | value_loss         | 304.30142    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 8.228746e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0578        |
# | fps                | 749           |
# | nupdates           | 52            |
# | policy_entropy     | 5.6570992     |
# | policy_loss        | -0.0002762283 |
# | serial_timesteps   | 13000         |
# | time_elapsed       | 65.7          |
# | total_timesteps    | 52416         |
# | value_loss         | 282.07217     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.153748e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00646       |
# | fps                | 792           |
# | nupdates           | 53            |
# | policy_entropy     | 5.6561093     |
# | policy_loss        | 1.1084906e-06 |
# | serial_timesteps   | 13250         |
# | time_elapsed       | 67            |
# | total_timesteps    | 53424         |
# | value_loss         | 226.17834     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.0342504e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0177        |
# | fps                | 777           |
# | nupdates           | 54            |
# | policy_entropy     | 5.655573      |
# | policy_loss        | -4.56992e-06  |
# | serial_timesteps   | 13500         |
# | time_elapsed       | 68.3          |
# | total_timesteps    | 54432         |
# | value_loss         | 272.17737     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.47229e-05    |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0731         |
# | fps                | 755            |
# | nupdates           | 55             |
# | policy_entropy     | 5.655501       |
# | policy_loss        | -0.00082374306 |
# | serial_timesteps   | 13750          |
# | time_elapsed       | 69.6           |
# | total_timesteps    | 55440          |
# | value_loss         | 244.11108      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00015994303 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0811        |
# | fps                | 788           |
# | nupdates           | 56            |
# | policy_entropy     | 5.655173      |
# | policy_loss        | -0.0001297089 |
# | serial_timesteps   | 14000         |
# | time_elapsed       | 70.9          |
# | total_timesteps    | 56448         |
# | value_loss         | 180.32736     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.0526804e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.13           |
# | fps                | 779            |
# | nupdates           | 57             |
# | policy_entropy     | 5.655257       |
# | policy_loss        | -2.3307177e-05 |
# | serial_timesteps   | 14250          |
# | time_elapsed       | 72.2           |
# | total_timesteps    | 57456          |
# | value_loss         | 132.35582      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 7.5704265e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.148          |
# | fps                | 788            |
# | nupdates           | 58             |
# | policy_entropy     | 5.6550593      |
# | policy_loss        | -0.00025471585 |
# | serial_timesteps   | 14500          |
# | time_elapsed       | 73.5           |
# | total_timesteps    | 58464          |
# | value_loss         | 70.89539       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00013443698 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.131         |
# | fps                | 793           |
# | nupdates           | 59            |
# | policy_entropy     | 5.6546807     |
# | policy_loss        | 0.00024360481 |
# | serial_timesteps   | 14750         |
# | time_elapsed       | 74.8          |
# | total_timesteps    | 59472         |
# | value_loss         | 64.96363      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.9474085e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.12          |
# | fps                | 775           |
# | nupdates           | 60            |
# | policy_entropy     | 5.655544      |
# | policy_loss        | 0.00023661053 |
# | serial_timesteps   | 15000         |
# | time_elapsed       | 76            |
# | total_timesteps    | 60480         |
# | value_loss         | 106.06167     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.555655e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.184          |
# | fps                | 818            |
# | nupdates           | 61             |
# | policy_entropy     | 5.657519       |
# | policy_loss        | -0.00014603115 |
# | serial_timesteps   | 15250          |
# | time_elapsed       | 77.3           |
# | total_timesteps    | 61488          |
# | value_loss         | 68.532394      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.894975e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0616        |
# | fps                | 818           |
# | nupdates           | 62            |
# | policy_entropy     | 5.659364      |
# | policy_loss        | -0.0005797305 |
# | serial_timesteps   | 15500         |
# | time_elapsed       | 78.5          |
# | total_timesteps    | 62496         |
# | value_loss         | 76.26477      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010679554 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.218         |
# | fps                | 812           |
# | nupdates           | 63            |
# | policy_entropy     | 5.6615148     |
# | policy_loss        | -0.0004710285 |
# | serial_timesteps   | 15750         |
# | time_elapsed       | 79.8          |
# | total_timesteps    | 63504         |
# | value_loss         | 33.90655      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.731637e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0549        |
# | fps                | 804           |
# | nupdates           | 64            |
# | policy_entropy     | 5.6630874     |
# | policy_loss        | -0.0013361012 |
# | serial_timesteps   | 16000         |
# | time_elapsed       | 81            |
# | total_timesteps    | 64512         |
# | value_loss         | 39.330708     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0026679535  |
# | clipfrac           | 0.02725       |
# | explained_variance | 0.607         |
# | fps                | 808           |
# | nupdates           | 65            |
# | policy_entropy     | 5.665122      |
# | policy_loss        | -0.0039966158 |
# | serial_timesteps   | 16250         |
# | time_elapsed       | 82.2          |
# | total_timesteps    | 65520         |
# | value_loss         | 0.25461373    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.000854962   |
# | clipfrac           | 0.00075       |
# | explained_variance | 0.187         |
# | fps                | 776           |
# | nupdates           | 66            |
# | policy_entropy     | 5.6643744     |
# | policy_loss        | -0.0031655147 |
# | serial_timesteps   | 16500         |
# | time_elapsed       | 83.5          |
# | total_timesteps    | 66528         |
# | value_loss         | 33.874557     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00041675035 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.23          |
# | fps                | 792           |
# | nupdates           | 67            |
# | policy_entropy     | 5.665534      |
# | policy_loss        | 0.0015081682  |
# | serial_timesteps   | 16750         |
# | time_elapsed       | 84.8          |
# | total_timesteps    | 67536         |
# | value_loss         | 32.296165     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00078094366 |
# | clipfrac           | 0.0005        |
# | explained_variance | 0.242         |
# | fps                | 820           |
# | nupdates           | 68            |
# | policy_entropy     | 5.6666503     |
# | policy_loss        | -0.0024196128 |
# | serial_timesteps   | 17000         |
# | time_elapsed       | 86            |
# | total_timesteps    | 68544         |
# | value_loss         | 33.484463     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00199831    |
# | clipfrac           | 0.01225       |
# | explained_variance | 0.872         |
# | fps                | 794           |
# | nupdates           | 69            |
# | policy_entropy     | 5.666756      |
# | policy_loss        | -0.0030599062 |
# | serial_timesteps   | 17250         |
# | time_elapsed       | 87.3          |
# | total_timesteps    | 69552         |
# | value_loss         | 0.4120716     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0011532642   |
# | clipfrac           | 0.0025         |
# | explained_variance | 0.253          |
# | fps                | 771            |
# | nupdates           | 70             |
# | policy_entropy     | 5.6645985      |
# | policy_loss        | -0.00074538495 |
# | serial_timesteps   | 17500          |
# | time_elapsed       | 88.5           |
# | total_timesteps    | 70560          |
# | value_loss         | 89.57587       |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0047844835 |
# | clipfrac           | 0.069749996  |
# | explained_variance | 0.842        |
# | fps                | 811          |
# | nupdates           | 71           |
# | policy_entropy     | 5.666405     |
# | policy_loss        | -0.009078552 |
# | serial_timesteps   | 17750        |
# | time_elapsed       | 89.8         |
# | total_timesteps    | 71568        |
# | value_loss         | 0.20576543   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0036703711  |
# | clipfrac           | 0.039499998   |
# | explained_variance | -0.00977      |
# | fps                | 835           |
# | nupdates           | 72            |
# | policy_entropy     | 5.6723757     |
# | policy_loss        | -0.0059782937 |
# | serial_timesteps   | 18000         |
# | time_elapsed       | 91.1          |
# | total_timesteps    | 72576         |
# | value_loss         | 0.1364781     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0060486747  |
# | clipfrac           | 0.081250004   |
# | explained_variance | 0.116         |
# | fps                | 775           |
# | nupdates           | 73            |
# | policy_entropy     | 5.670695      |
# | policy_loss        | -0.0062028263 |
# | serial_timesteps   | 18250         |
# | time_elapsed       | 92.3          |
# | total_timesteps    | 73584         |
# | value_loss         | 0.24835184    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0022809743 |
# | clipfrac           | 0.021000002  |
# | explained_variance | -0.209       |
# | fps                | 780          |
# | nupdates           | 74           |
# | policy_entropy     | 5.6630473    |
# | policy_loss        | -0.005401417 |
# | serial_timesteps   | 18500        |
# | time_elapsed       | 93.6         |
# | total_timesteps    | 74592        |
# | value_loss         | 0.13784108   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.004989605  |
# | clipfrac           | 0.064        |
# | explained_variance | 0.237        |
# | fps                | 820          |
# | nupdates           | 75           |
# | policy_entropy     | 5.6577544    |
# | policy_loss        | -0.004991099 |
# | serial_timesteps   | 18750        |
# | time_elapsed       | 94.8         |
# | total_timesteps    | 75600        |
# | value_loss         | 0.2526828    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00077654136 |
# | clipfrac           | 0.0015        |
# | explained_variance | -0.149        |
# | fps                | 776           |
# | nupdates           | 76            |
# | policy_entropy     | 5.6531267     |
# | policy_loss        | -0.0018950063 |
# | serial_timesteps   | 19000         |
# | time_elapsed       | 96.1          |
# | total_timesteps    | 76608         |
# | value_loss         | 45.869247     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0007197611  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.256         |
# | fps                | 802           |
# | nupdates           | 77            |
# | policy_entropy     | 5.6556063     |
# | policy_loss        | -0.0002594555 |
# | serial_timesteps   | 19250         |
# | time_elapsed       | 97.4          |
# | total_timesteps    | 77616         |
# | value_loss         | 35.791252     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0012678644  |
# | clipfrac           | 0.0052500004  |
# | explained_variance | -1.03         |
# | fps                | 793           |
# | nupdates           | 78            |
# | policy_entropy     | 5.653906      |
# | policy_loss        | -0.0021348353 |
# | serial_timesteps   | 19500         |
# | time_elapsed       | 98.6          |
# | total_timesteps    | 78624         |
# | value_loss         | 0.10718335    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0039733867  |
# | clipfrac           | 0.04675       |
# | explained_variance | -0.276        |
# | fps                | 805           |
# | nupdates           | 79            |
# | policy_entropy     | 5.6497793     |
# | policy_loss        | -0.0074370005 |
# | serial_timesteps   | 19750         |
# | time_elapsed       | 99.9          |
# | total_timesteps    | 79632         |
# | value_loss         | 0.08524601    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0030506265  |
# | clipfrac           | 0.03125       |
# | explained_variance | -0.385        |
# | fps                | 797           |
# | nupdates           | 80            |
# | policy_entropy     | 5.641277      |
# | policy_loss        | -0.0035208256 |
# | serial_timesteps   | 20000         |
# | time_elapsed       | 101           |
# | total_timesteps    | 80640         |
# | value_loss         | 0.27508724    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0021580895  |
# | clipfrac           | 0.0165        |
# | explained_variance | 0.429         |
# | fps                | 793           |
# | nupdates           | 81            |
# | policy_entropy     | 5.6350284     |
# | policy_loss        | -0.0040757367 |
# | serial_timesteps   | 20250         |
# | time_elapsed       | 102           |
# | total_timesteps    | 81648         |
# | value_loss         | 0.18411785    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0018768002  |
# | clipfrac           | 0.011         |
# | explained_variance | 0.154         |
# | fps                | 814           |
# | nupdates           | 82            |
# | policy_entropy     | 5.634047      |
# | policy_loss        | -0.0018169602 |
# | serial_timesteps   | 20500         |
# | time_elapsed       | 104           |
# | total_timesteps    | 82656         |
# | value_loss         | 0.15430447    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0012919962  |
# | clipfrac           | 0.0019999999  |
# | explained_variance | 0.206         |
# | fps                | 784           |
# | nupdates           | 83            |
# | policy_entropy     | 5.6354895     |
# | policy_loss        | -0.0018650894 |
# | serial_timesteps   | 20750         |
# | time_elapsed       | 105           |
# | total_timesteps    | 83664         |
# | value_loss         | 36.380775     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.003533096   |
# | clipfrac           | 0.0315        |
# | explained_variance | 0.21          |
# | fps                | 778           |
# | nupdates           | 84            |
# | policy_entropy     | 5.6386204     |
# | policy_loss        | -0.0031992302 |
# | serial_timesteps   | 21000         |
# | time_elapsed       | 106           |
# | total_timesteps    | 84672         |
# | value_loss         | 0.3558616     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017668186  |
# | clipfrac           | 0.009         |
# | explained_variance | -0.532        |
# | fps                | 790           |
# | nupdates           | 85            |
# | policy_entropy     | 5.634662      |
# | policy_loss        | -0.0023370695 |
# | serial_timesteps   | 21250         |
# | time_elapsed       | 107           |
# | total_timesteps    | 85680         |
# | value_loss         | 0.046609104   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002925396  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.214         |
# | fps                | 812           |
# | nupdates           | 86            |
# | policy_entropy     | 5.6285896     |
# | policy_loss        | -0.0001059657 |
# | serial_timesteps   | 21500         |
# | time_elapsed       | 109           |
# | total_timesteps    | 86688         |
# | value_loss         | 33.495712     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0020686195  |
# | clipfrac           | 0.0155        |
# | explained_variance | -0.0975       |
# | fps                | 810           |
# | nupdates           | 87            |
# | policy_entropy     | 5.625813      |
# | policy_loss        | -0.0028463101 |
# | serial_timesteps   | 21750         |
# | time_elapsed       | 110           |
# | total_timesteps    | 87696         |
# | value_loss         | 0.048951272   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017929666  |
# | clipfrac           | 0.01475       |
# | explained_variance | 0.155         |
# | fps                | 809           |
# | nupdates           | 88            |
# | policy_entropy     | 5.617612      |
# | policy_loss        | -0.0045835217 |
# | serial_timesteps   | 22000         |
# | time_elapsed       | 111           |
# | total_timesteps    | 88704         |
# | value_loss         | 0.28310293    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0037827662  |
# | clipfrac           | 0.043250002   |
# | explained_variance | -0.129        |
# | fps                | 799           |
# | nupdates           | 89            |
# | policy_entropy     | 5.61117       |
# | policy_loss        | -0.0019334353 |
# | serial_timesteps   | 22250         |
# | time_elapsed       | 112           |
# | total_timesteps    | 89712         |
# | value_loss         | 0.03571425    |
# --------------------------------------
# ...
# | fps                | 798          |
# | nupdates           | 108          |
# | policy_entropy     | 5.4985433    |
# | policy_loss        | -0.004407774 |
# | serial_timesteps   | 27000        |
# | time_elapsed       | 136          |
# | total_timesteps    | 108864       |
# | value_loss         | 0.013779023  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.003058005   |
# | clipfrac           | 0.0295        |
# | explained_variance | 0.608         |
# | fps                | 804           |
# | nupdates           | 109           |
# | policy_entropy     | 5.490768      |
# | policy_loss        | -0.0027156936 |
# | serial_timesteps   | 27250         |
# | time_elapsed       | 137           |
# | total_timesteps    | 109872        |
# | value_loss         | 0.5157162     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0061456356 |
# | clipfrac           | 0.08925      |
# | explained_variance | -0.148       |
# | fps                | 793          |
# | nupdates           | 110          |
# | policy_entropy     | 5.4852977    |
# | policy_loss        | -0.005076144 |
# | serial_timesteps   | 27500        |
# | time_elapsed       | 139          |
# | total_timesteps    | 110880       |
# | value_loss         | 0.01609459   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.003416671  |
# | clipfrac           | 0.039        |
# | explained_variance | -0.112       |
# | fps                | 817          |
# | nupdates           | 111          |
# | policy_entropy     | 5.4771004    |
# | policy_loss        | -0.003855174 |
# | serial_timesteps   | 27750        |
# | time_elapsed       | 140          |
# | total_timesteps    | 111888       |
# | value_loss         | 0.016232947  |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.00095584436  |
# | clipfrac           | 0.0015         |
# | explained_variance | -0.163         |
# | fps                | 821            |
# | nupdates           | 112            |
# | policy_entropy     | 5.4696784      |
# | policy_loss        | -0.00081558386 |
# | serial_timesteps   | 28000          |
# | time_elapsed       | 141            |
# | total_timesteps    | 112896         |
# | value_loss         | 0.017957555    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0011245633  |
# | clipfrac           | 0.0015000001  |
# | explained_variance | 0.378         |
# | fps                | 762           |
# | nupdates           | 113           |
# | policy_entropy     | 5.4638658     |
# | policy_loss        | -0.0010047187 |
# | serial_timesteps   | 28250         |
# | time_elapsed       | 142           |
# | total_timesteps    | 113904        |
# | value_loss         | 0.43910986    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0024882406  |
# | clipfrac           | 0.02425       |
# | explained_variance | 0.446         |
# | fps                | 796           |
# | nupdates           | 114           |
# | policy_entropy     | 5.459044      |
# | policy_loss        | -0.0033968776 |
# | serial_timesteps   | 28500         |
# | time_elapsed       | 144           |
# | total_timesteps    | 114912        |
# | value_loss         | 0.025531346   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001844948   |
# | clipfrac           | 0.01          |
# | explained_variance | 0.164         |
# | fps                | 847           |
# | nupdates           | 115           |
# | policy_entropy     | 5.450992      |
# | policy_loss        | -0.0023449783 |
# | serial_timesteps   | 28750         |
# | time_elapsed       | 145           |
# | total_timesteps    | 115920        |
# | value_loss         | 0.20830977    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00059163733 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0447        |
# | fps                | 749           |
# | nupdates           | 116           |
# | policy_entropy     | 5.447113      |
# | policy_loss        | 0.0003438039  |
# | serial_timesteps   | 29000         |
# | time_elapsed       | 146           |
# | total_timesteps    | 116928        |
# | value_loss         | 0.35089663    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0039747595 |
# | clipfrac           | 0.044250004  |
# | explained_variance | 0.191        |
# | fps                | 859          |
# | nupdates           | 117          |
# | policy_entropy     | 5.4434657    |
# | policy_loss        | -0.003973414 |
# | serial_timesteps   | 29250        |
# | time_elapsed       | 147          |
# | total_timesteps    | 117936       |
# | value_loss         | 0.017320437  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0005259288  |
# | clipfrac           | 0.00025       |
# | explained_variance | 0.221         |
# | fps                | 824           |
# | nupdates           | 118           |
# | policy_entropy     | 5.4357023     |
# | policy_loss        | -0.0009943622 |
# | serial_timesteps   | 29500         |
# | time_elapsed       | 149           |
# | total_timesteps    | 118944        |
# | value_loss         | 0.01698304    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00091531425 |
# | clipfrac           | 0.001         |
# | explained_variance | -0.193        |
# | fps                | 820           |
# | nupdates           | 119           |
# | policy_entropy     | 5.4307017     |
# | policy_loss        | -0.0010342423 |
# | serial_timesteps   | 29750         |
# | time_elapsed       | 150           |
# | total_timesteps    | 119952        |
# | value_loss         | 0.29264772    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0026752304  |
# | clipfrac           | 0.024999999   |
# | explained_variance | 0.0266        |
# | fps                | 820           |
# | nupdates           | 120           |
# | policy_entropy     | 5.4300947     |
# | policy_loss        | -0.0030770674 |
# | serial_timesteps   | 30000         |
# | time_elapsed       | 151           |
# | total_timesteps    | 120960        |
# | value_loss         | 0.24189539    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0031749005  |
# | clipfrac           | 0.026250001   |
# | explained_variance | 0.351         |
# | fps                | 820           |
# | nupdates           | 121           |
# | policy_entropy     | 5.4236016     |
# | policy_loss        | -0.0035272918 |
# | serial_timesteps   | 30250         |
# | time_elapsed       | 152           |
# | total_timesteps    | 121968        |
# | value_loss         | 0.017710274   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00056263077 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0445        |
# | fps                | 842           |
# | nupdates           | 122           |
# | policy_entropy     | 5.415824      |
# | policy_loss        | -0.0011971423 |
# | serial_timesteps   | 30500         |
# | time_elapsed       | 154           |
# | total_timesteps    | 122976        |
# | value_loss         | 0.43522704    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0036502185  |
# | clipfrac           | 0.03975       |
# | explained_variance | 0.244         |
# | fps                | 819           |
# | nupdates           | 123           |
# | policy_entropy     | 5.409902      |
# | policy_loss        | -0.0042373785 |
# | serial_timesteps   | 30750         |
# | time_elapsed       | 155           |
# | total_timesteps    | 123984        |
# | value_loss         | 0.02367222    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0083120065 |
# | clipfrac           | 0.12250001   |
# | explained_variance | 0.115        |
# | fps                | 800          |
# | nupdates           | 124          |
# | policy_entropy     | 5.400799     |
# | policy_loss        | -0.012475172 |
# | serial_timesteps   | 31000        |
# | time_elapsed       | 156          |
# | total_timesteps    | 124992       |
# | value_loss         | 0.01649677   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0034007037  |
# | clipfrac           | 0.04025       |
# | explained_variance | 0.311         |
# | fps                | 814           |
# | nupdates           | 125           |
# | policy_entropy     | 5.393164      |
# | policy_loss        | -0.0042778933 |
# | serial_timesteps   | 31250         |
# | time_elapsed       | 157           |
# | total_timesteps    | 126000        |
# | value_loss         | 0.17006253    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0027850834 |
# | clipfrac           | 0.025750002  |
# | explained_variance | 0.13         |
# | fps                | 808          |
# | nupdates           | 126          |
# | policy_entropy     | 5.387292     |
# | policy_loss        | -0.002748467 |
# | serial_timesteps   | 31500        |
# | time_elapsed       | 158          |
# | total_timesteps    | 127008       |
# | value_loss         | 0.22703256   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.004781708   |
# | clipfrac           | 0.0625        |
# | explained_variance | 0.588         |
# | fps                | 849           |
# | nupdates           | 127           |
# | policy_entropy     | 5.383466      |
# | policy_loss        | -0.0051965667 |
# | serial_timesteps   | 31750         |
# | time_elapsed       | 160           |
# | total_timesteps    | 128016        |
# | value_loss         | 0.03294815    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001387351   |
# | clipfrac           | 0.007         |
# | explained_variance | 0.677         |
# | fps                | 827           |
# | nupdates           | 128           |
# | policy_entropy     | 5.3789945     |
# | policy_loss        | -0.0032880888 |
# | serial_timesteps   | 32000         |
# | time_elapsed       | 161           |
# | total_timesteps    | 129024        |
# | value_loss         | 0.43421358    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00061837817 |
# | clipfrac           | 0.0005        |
# | explained_variance | 0.0747        |
# | fps                | 793           |
# | nupdates           | 129           |
# | policy_entropy     | 5.37661       |
# | policy_loss        | -0.000882361  |
# | serial_timesteps   | 32250         |
# | time_elapsed       | 162           |
# | total_timesteps    | 130032        |
# | value_loss         | 37.698475     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0007524098 |
# | clipfrac           | 0.001        |
# | explained_variance | 0.421        |
# | fps                | 840          |
# | nupdates           | 130          |
# | policy_entropy     | 5.376614     |
# | policy_loss        | -0.002059623 |
# | serial_timesteps   | 32500        |
# | time_elapsed       | 163          |
# | total_timesteps    | 131040       |
# | value_loss         | 0.042022835  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.001988983   |
# | clipfrac           | 0.01675       |
# | explained_variance | 0.319         |
# | fps                | 812           |
# | nupdates           | 131           |
# | policy_entropy     | 5.376182      |
# | policy_loss        | -0.0017768061 |
# | serial_timesteps   | 32750         |
# | time_elapsed       | 165           |
# | total_timesteps    | 132048        |
# | value_loss         | 0.039794628   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0020914925  |
# | clipfrac           | 0.0105        |
# | explained_variance | 0.178         |
# | fps                | 817           |
# | nupdates           | 132           |
# | policy_entropy     | 5.377905      |
# | policy_loss        | -0.0028885778 |
# | serial_timesteps   | 33000         |
# | time_elapsed       | 166           |
# | total_timesteps    | 133056        |
# | value_loss         | 0.27457625    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0021523205  |
# | clipfrac           | 0.01925       |
# | explained_variance | 0.195         |
# | fps                | 724           |
# | nupdates           | 133           |
# | policy_entropy     | 5.375888      |
# | policy_loss        | -0.0035071257 |
# | serial_timesteps   | 33250         |
# | time_elapsed       | 167           |
# | total_timesteps    | 134064        |
# | value_loss         | 0.06341106    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0016525049  |
# | clipfrac           | 0.0084999995  |
# | explained_variance | 0.16          |
# | fps                | 837           |
# | nupdates           | 134           |
# | policy_entropy     | 5.370645      |
# | policy_loss        | -0.0025282884 |
# | serial_timesteps   | 33500         |
# | time_elapsed       | 168           |
# | total_timesteps    | 135072        |
# | value_loss         | 0.042395107   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0007100047  |
# | clipfrac           | 0.00025       |
# | explained_variance | 0.244         |
# | fps                | 817           |
# | nupdates           | 135           |
# | policy_entropy     | 5.3679023     |
# | policy_loss        | -0.0013436435 |
# | serial_timesteps   | 33750         |
# | time_elapsed       | 170           |
# | total_timesteps    | 136080        |
# | value_loss         | 34.34925      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0029147584  |
# | clipfrac           | 0.028750002   |
# | explained_variance | 0.391         |
# | fps                | 830           |
# | nupdates           | 136           |
# | policy_entropy     | 5.367073      |
# | policy_loss        | -0.0045035025 |
# | serial_timesteps   | 34000         |
# | time_elapsed       | 171           |
# | total_timesteps    | 137088        |
# | value_loss         | 0.042940207   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0017619401  |
# | clipfrac           | 0.00925       |
# | explained_variance | 0.293         |
# | fps                | 855           |
# | nupdates           | 137           |
# | policy_entropy     | 5.367752      |
# | policy_loss        | -0.0020568406 |
# | serial_timesteps   | 34250         |
# | time_elapsed       | 172           |
# | total_timesteps    | 138096        |
# | value_loss         | 0.062507376   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0018114632  |
# | clipfrac           | 0.013         |
# | explained_variance | 0.457         |
# | fps                | 803           |
# | nupdates           | 138           |
# | policy_entropy     | 5.3722405     |
# | policy_loss        | -0.0029273261 |
# | serial_timesteps   | 34500         |
# | time_elapsed       | 173           |
# | total_timesteps    | 139104        |
# | value_loss         | 0.15168878    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006257897  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.122        |
# | fps                | 831           |
# | nupdates           | 139           |
# | policy_entropy     | 5.374222      |
# | policy_loss        | -0.0014647976 |
# | serial_timesteps   | 34750         |
# | time_elapsed       | 174           |
# | total_timesteps    | 140112        |
# | value_loss         | 45.64133      |
# --------------------------------------

# %%
from stable_baselines.common.policies import FeedForwardPolicy

# %%
model = PPO2.load(final_model_dir)

# Enjoy trained agent
env = gym.make(env_name)
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
