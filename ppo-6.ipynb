# %%
import os
import gym
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import SubprocVecEnv
from stable_baselines.common.vec_env import DummyVecEnv
from utils.ppo import PPO
from utils.models import Policy, CNNPolicy

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
LOGS = os.getcwd()

# %%
def makedirs(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
env_name = 'BipedalWalkerHardcore-v2'
run_id = 1
n_steps = 250
total_timesteps = 10000000
cnn_policy = False

LOGS = os.path.join(LOGS, env_name, 'run{}'.format(run_id))
makedirs(LOGS)
tb_log = os.path.join(LOGS, 'tb')
makedirs(tb_log)
model_dir = os.path.join(LOGS, 'models')
makedirs(model_dir)
final_model_dir = os.path.join(LOGS, 'model')
n_cpu = 4

# %%
env = SubprocVecEnv([lambda: gym.make(env_name) for i in range(n_cpu)])

if cnn_policy:
    print('Using CNN policy network')
    model = PPO(CNNPolicy, env, n_steps=n_steps, tensorboard_log=tb_log, verbose=1, full_tensorboard_log=True)
else:
    print('Using MLP policy network')
    model = PPO(Policy, env, n_steps=n_steps, tensorboard_log=tb_log, verbose=1, full_tensorboard_log=True)
model.learn(total_timesteps, env, save_file=os.path.join(model_dir, 'model'))
model.save(final_model_dir)
del model # remove to demonstrate saving and loading
# Out:
# Using MLP policy network
# INFO:tensorflow:Summary name model/pi_fc0/w:0 is illegal; using model/pi_fc0/w_0 instead.
# INFO:tensorflow:Summary name model/pi_fc0/b:0 is illegal; using model/pi_fc0/b_0 instead.
# INFO:tensorflow:Summary name model/vf_fc0/w:0 is illegal; using model/vf_fc0/w_0 instead.
# INFO:tensorflow:Summary name model/vf_fc0/b:0 is illegal; using model/vf_fc0/b_0 instead.
# INFO:tensorflow:Summary name model/pi_fc1/w:0 is illegal; using model/pi_fc1/w_0 instead.
# INFO:tensorflow:Summary name model/pi_fc1/b:0 is illegal; using model/pi_fc1/b_0 instead.
# INFO:tensorflow:Summary name model/vf_fc1/w:0 is illegal; using model/vf_fc1/w_0 instead.
# INFO:tensorflow:Summary name model/vf_fc1/b:0 is illegal; using model/vf_fc1/b_0 instead.
# INFO:tensorflow:Summary name model/vf/w:0 is illegal; using model/vf/w_0 instead.
# INFO:tensorflow:Summary name model/vf/b:0 is illegal; using model/vf/b_0 instead.
# INFO:tensorflow:Summary name model/pi/w:0 is illegal; using model/pi/w_0 instead.
# INFO:tensorflow:Summary name model/pi/b:0 is illegal; using model/pi/b_0 instead.
# INFO:tensorflow:Summary name model/pi/logstd:0 is illegal; using model/pi/logstd_0 instead.
# INFO:tensorflow:Summary name model/q/w:0 is illegal; using model/q/w_0 instead.
# INFO:tensorflow:Summary name model/q/b:0 is illegal; using model/q/b_0 instead.
# INFO:tensorflow:Summary name model/pi_fc0/w:0/gradient is illegal; using model/pi_fc0/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc0/b:0/gradient is illegal; using model/pi_fc0/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc0/w:0/gradient is illegal; using model/vf_fc0/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc0/b:0/gradient is illegal; using model/vf_fc0/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc1/w:0/gradient is illegal; using model/pi_fc1/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc1/b:0/gradient is illegal; using model/pi_fc1/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc1/w:0/gradient is illegal; using model/vf_fc1/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc1/b:0/gradient is illegal; using model/vf_fc1/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf/w:0/gradient is illegal; using model/vf/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf/b:0/gradient is illegal; using model/vf/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/w:0/gradient is illegal; using model/pi/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/b:0/gradient is illegal; using model/pi/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/logstd:0/gradient is illegal; using model/pi/logstd_0/gradient instead.
# No of updates: 10000
# Total timesteps : 10000000
# Batch size: 1000
# --------------------------------------
# | approxkl           | 0.00018181806 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00115      |
# | fps                | 461           |
# | nupdates           | 1             |
# | policy_entropy     | 5.6767745     |
# | policy_loss        | -0.001676548  |
# | serial_timesteps   | 250           |
# | time_elapsed       | 0.000211      |
# | total_timesteps    | 1008          |
# | value_loss         | 407.4164      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000105008075 |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00599        |
# | fps                | 855            |
# | nupdates           | 2              |
# | policy_entropy     | 5.6781936      |
# | policy_loss        | -0.00029852125 |
# | serial_timesteps   | 500            |
# | time_elapsed       | 2.17           |
# | total_timesteps    | 2016           |
# | value_loss         | 144.84364      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00067412166 |
# | clipfrac           | 0.0015        |
# | explained_variance | 0.0397        |
# | fps                | 792           |
# | nupdates           | 3             |
# | policy_entropy     | 5.680085      |
# | policy_loss        | -0.0040652854 |
# | serial_timesteps   | 750           |
# | time_elapsed       | 3.34          |
# | total_timesteps    | 3024          |
# | value_loss         | 0.8967927     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0017802271 |
# | clipfrac           | 0.012        |
# | explained_variance | -0.202       |
# | fps                | 811          |
# | nupdates           | 4            |
# | policy_entropy     | 5.683654     |
# | policy_loss        | -0.006356355 |
# | serial_timesteps   | 1000         |
# | time_elapsed       | 4.6          |
# | total_timesteps    | 4032         |
# | value_loss         | 0.76580393   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0020460035 |
# | clipfrac           | 0.018        |
# | explained_variance | 0.142        |
# | fps                | 830          |
# | nupdates           | 5            |
# | policy_entropy     | 5.685218     |
# | policy_loss        | -0.005648895 |
# | serial_timesteps   | 1250         |
# | time_elapsed       | 5.84         |
# | total_timesteps    | 5040         |
# | value_loss         | 0.90167713   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0007099105 |
# | clipfrac           | 0.00125      |
# | explained_variance | -0.013       |
# | fps                | 796          |
# | nupdates           | 6            |
# | policy_entropy     | 5.6849732    |
# | policy_loss        | 0.0014993286 |
# | serial_timesteps   | 1500         |
# | time_elapsed       | 7.05         |
# | total_timesteps    | 6048         |
# | value_loss         | 136.81778    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0006433389  |
# | clipfrac           | 0.00225       |
# | explained_variance | 0.298         |
# | fps                | 843           |
# | nupdates           | 7             |
# | policy_entropy     | 5.6823416     |
# | policy_loss        | -0.0032071467 |
# | serial_timesteps   | 1750          |
# | time_elapsed       | 8.31          |
# | total_timesteps    | 7056          |
# | value_loss         | 0.24521294    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.001989757  |
# | clipfrac           | 0.012        |
# | explained_variance | -0.024       |
# | fps                | 860          |
# | nupdates           | 8            |
# | policy_entropy     | 5.6758204    |
# | policy_loss        | -0.002669856 |
# | serial_timesteps   | 2000         |
# | time_elapsed       | 9.5          |
# | total_timesteps    | 8064         |
# | value_loss         | 41.84011     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00036663655 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00287      |
# | fps                | 831           |
# | nupdates           | 9             |
# | policy_entropy     | 5.6733637     |
# | policy_loss        | 0.0003441229  |
# | serial_timesteps   | 2250          |
# | time_elapsed       | 10.7          |
# | total_timesteps    | 9072          |
# | value_loss         | 217.48196     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00027733346 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0154        |
# | fps                | 854           |
# | nupdates           | 10            |
# | policy_entropy     | 5.6732926     |
# | policy_loss        | 0.00022500164 |
# | serial_timesteps   | 2500          |
# | time_elapsed       | 11.9          |
# | total_timesteps    | 10080         |
# | value_loss         | 85.795456     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00019894639 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00202      |
# | fps                | 886           |
# | nupdates           | 11            |
# | policy_entropy     | 5.6743217     |
# | policy_loss        | 0.00040484784 |
# | serial_timesteps   | 2750          |
# | time_elapsed       | 13            |
# | total_timesteps    | 11088         |
# | value_loss         | 114.05849     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0002024498   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0195         |
# | fps                | 884            |
# | nupdates           | 12             |
# | policy_entropy     | 5.6747303      |
# | policy_loss        | -0.00074379315 |
# | serial_timesteps   | 3000           |
# | time_elapsed       | 14.2           |
# | total_timesteps    | 12096          |
# | value_loss         | 43.431786      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0010845546  |
# | clipfrac           | 0.007         |
# | explained_variance | -0.0109       |
# | fps                | 839           |
# | nupdates           | 13            |
# | policy_entropy     | 5.6725097     |
# | policy_loss        | -0.0031518368 |
# | serial_timesteps   | 3250          |
# | time_elapsed       | 15.3          |
# | total_timesteps    | 13104         |
# | value_loss         | 0.17734638    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.005898274  |
# | clipfrac           | 0.08275      |
# | explained_variance | 0.0166       |
# | fps                | 790          |
# | nupdates           | 14           |
# | policy_entropy     | 5.6707506    |
# | policy_loss        | -0.009952699 |
# | serial_timesteps   | 3500         |
# | time_elapsed       | 16.5         |
# | total_timesteps    | 14112        |
# | value_loss         | 0.24341005   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0037109219 |
# | clipfrac           | 0.05         |
# | explained_variance | -0.0525      |
# | fps                | 831          |
# | nupdates           | 15           |
# | policy_entropy     | 5.6682715    |
# | policy_loss        | -0.006366183 |
# | serial_timesteps   | 3750         |
# | time_elapsed       | 17.8         |
# | total_timesteps    | 15120        |
# | value_loss         | 0.09464851   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00021245777 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00202      |
# | fps                | 809           |
# | nupdates           | 16            |
# | policy_entropy     | 5.670822      |
# | policy_loss        | -0.0003701289 |
# | serial_timesteps   | 4000          |
# | time_elapsed       | 19            |
# | total_timesteps    | 16128         |
# | value_loss         | 38.85501      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002758157  |
# | clipfrac           | 0.00025       |
# | explained_variance | 0.0047        |
# | fps                | 809           |
# | nupdates           | 17            |
# | policy_entropy     | 5.673158      |
# | policy_loss        | -0.0009753555 |
# | serial_timesteps   | 4250          |
# | time_elapsed       | 20.2          |
# | total_timesteps    | 17136         |
# | value_loss         | 43.920116     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0014550326  |
# | clipfrac           | 0.0055        |
# | explained_variance | -0.244        |
# | fps                | 829           |
# | nupdates           | 18            |
# | policy_entropy     | 5.6763268     |
# | policy_loss        | -0.0015760912 |
# | serial_timesteps   | 4500          |
# | time_elapsed       | 21.5          |
# | total_timesteps    | 18144         |
# | value_loss         | 0.10143034    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002592728   |
# | clipfrac           | 0.0255        |
# | explained_variance | 0.104         |
# | fps                | 864           |
# | nupdates           | 19            |
# | policy_entropy     | 5.6794333     |
# | policy_loss        | -0.0025013867 |
# | serial_timesteps   | 4750          |
# | time_elapsed       | 22.7          |
# | total_timesteps    | 19152         |
# | value_loss         | 0.3081273     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00041478733 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0127       |
# | fps                | 855           |
# | nupdates           | 20            |
# | policy_entropy     | 5.6788044     |
# | policy_loss        | 0.0006349674  |
# | serial_timesteps   | 5000          |
# | time_elapsed       | 23.8          |
# | total_timesteps    | 20160         |
# | value_loss         | 107.93681     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00080147036 |
# | clipfrac           | 0.0025        |
# | explained_variance | 0.272         |
# | fps                | 885           |
# | nupdates           | 21            |
# | policy_entropy     | 5.6811285     |
# | policy_loss        | -0.0029106103 |
# | serial_timesteps   | 5250          |
# | time_elapsed       | 25            |
# | total_timesteps    | 21168         |
# | value_loss         | 0.24669638    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0022343867  |
# | clipfrac           | 0.02          |
# | explained_variance | -0.0768       |
# | fps                | 901           |
# | nupdates           | 22            |
# | policy_entropy     | 5.685127      |
# | policy_loss        | -0.0018364616 |
# | serial_timesteps   | 5500          |
# | time_elapsed       | 26.1          |
# | total_timesteps    | 22176         |
# | value_loss         | 0.23504177    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.00024392   |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0225       |
# | fps                | 796          |
# | nupdates           | 23           |
# | policy_entropy     | 5.6845527    |
# | policy_loss        | 0.0006960516 |
# | serial_timesteps   | 5750         |
# | time_elapsed       | 27.2         |
# | total_timesteps    | 23184        |
# | value_loss         | 42.997963    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0022107277  |
# | clipfrac           | 0.01975       |
# | explained_variance | 0.000446      |
# | fps                | 958           |
# | nupdates           | 24            |
# | policy_entropy     | 5.684989      |
# | policy_loss        | -0.0042019235 |
# | serial_timesteps   | 6000          |
# | time_elapsed       | 28.5          |
# | total_timesteps    | 24192         |
# | value_loss         | 0.08627258    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00022480045 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.000957      |
# | fps                | 804           |
# | nupdates           | 25            |
# | policy_entropy     | 5.682721      |
# | policy_loss        | 0.00032015733 |
# | serial_timesteps   | 6250          |
# | time_elapsed       | 29.5          |
# | total_timesteps    | 25200         |
# | value_loss         | 118.10957     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00036340748 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0101        |
# | fps                | 780           |
# | nupdates           | 26            |
# | policy_entropy     | 5.6804914     |
# | policy_loss        | -0.0016796459 |
# | serial_timesteps   | 6500          |
# | time_elapsed       | 30.8          |
# | total_timesteps    | 26208         |
# | value_loss         | 15.161142     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0016797496  |
# | clipfrac           | 0.01025       |
# | explained_variance | -0.207        |
# | fps                | 811           |
# | nupdates           | 27            |
# | policy_entropy     | 5.6767387     |
# | policy_loss        | -0.0055809347 |
# | serial_timesteps   | 6750          |
# | time_elapsed       | 32.1          |
# | total_timesteps    | 27216         |
# | value_loss         | 0.11042509    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.004383777   |
# | clipfrac           | 0.054         |
# | explained_variance | 0.0545        |
# | fps                | 774           |
# | nupdates           | 28            |
# | policy_entropy     | 5.6717653     |
# | policy_loss        | -0.0050816154 |
# | serial_timesteps   | 7000          |
# | time_elapsed       | 33.3          |
# | total_timesteps    | 28224         |
# | value_loss         | 0.22032389    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00019148899  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00583       |
# | fps                | 782            |
# | nupdates           | 29             |
# | policy_entropy     | 5.6696377      |
# | policy_loss        | -0.00073264155 |
# | serial_timesteps   | 7250           |
# | time_elapsed       | 34.6           |
# | total_timesteps    | 29232          |
# | value_loss         | 78.4402        |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00015706167  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0145         |
# | fps                | 779            |
# | nupdates           | 30             |
# | policy_entropy     | 5.6693597      |
# | policy_loss        | -0.00039197446 |
# | serial_timesteps   | 7500           |
# | time_elapsed       | 35.9           |
# | total_timesteps    | 30240          |
# | value_loss         | 158.92212      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00017971618 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0239        |
# | fps                | 789           |
# | nupdates           | 31            |
# | policy_entropy     | 5.6690607     |
# | policy_loss        | -0.0008193891 |
# | serial_timesteps   | 7750          |
# | time_elapsed       | 37.2          |
# | total_timesteps    | 31248         |
# | value_loss         | 36.419567     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014120631 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0171        |
# | fps                | 769           |
# | nupdates           | 32            |
# | policy_entropy     | 5.669641      |
# | policy_loss        | 0.00078219845 |
# | serial_timesteps   | 8000          |
# | time_elapsed       | 38.4          |
# | total_timesteps    | 32256         |
# | value_loss         | 116.79219     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015108498 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0319        |
# | fps                | 785           |
# | nupdates           | 33            |
# | policy_entropy     | 5.6697173     |
# | policy_loss        | -0.0010642691 |
# | serial_timesteps   | 8250          |
# | time_elapsed       | 39.7          |
# | total_timesteps    | 33264         |
# | value_loss         | 63.442684     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023316151 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.012         |
# | fps                | 750           |
# | nupdates           | 34            |
# | policy_entropy     | 5.669454      |
# | policy_loss        | 0.00010729832 |
# | serial_timesteps   | 8500          |
# | time_elapsed       | 41            |
# | total_timesteps    | 34272         |
# | value_loss         | 192.74084     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.7871377e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0274         |
# | fps                | 728            |
# | nupdates           | 35             |
# | policy_entropy     | 5.669335       |
# | policy_loss        | -0.00019714331 |
# | serial_timesteps   | 8750           |
# | time_elapsed       | 42.4           |
# | total_timesteps    | 35280          |
# | value_loss         | 239.73735      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0016558156  |
# | clipfrac           | 0.013         |
# | explained_variance | 0.171         |
# | fps                | 722           |
# | nupdates           | 36            |
# | policy_entropy     | 5.669982      |
# | policy_loss        | -0.0057536624 |
# | serial_timesteps   | 9000          |
# | time_elapsed       | 43.7          |
# | total_timesteps    | 36288         |
# | value_loss         | 0.2905476     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0014161491   |
# | clipfrac           | 0.0045         |
# | explained_variance | 0.0155         |
# | fps                | 768            |
# | nupdates           | 37             |
# | policy_entropy     | 5.673289       |
# | policy_loss        | -2.5913963e-05 |
# | serial_timesteps   | 9250           |
# | time_elapsed       | 45.1           |
# | total_timesteps    | 37296          |
# | value_loss         | 36.943066      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 7.7481214e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0577        |
# | fps                | 739           |
# | nupdates           | 38            |
# | policy_entropy     | 5.677391      |
# | policy_loss        | 0.00039491657 |
# | serial_timesteps   | 9500          |
# | time_elapsed       | 46.4          |
# | total_timesteps    | 38304         |
# | value_loss         | 81.889465     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.099433e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0456         |
# | fps                | 753            |
# | nupdates           | 39             |
# | policy_entropy     | 5.6790466      |
# | policy_loss        | -0.00048712362 |
# | serial_timesteps   | 9750           |
# | time_elapsed       | 47.8           |
# | total_timesteps    | 39312          |
# | value_loss         | 179.6367       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00018832767 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0709        |
# | fps                | 815           |
# | nupdates           | 40            |
# | policy_entropy     | 5.681238      |
# | policy_loss        | 0.00014567535 |
# | serial_timesteps   | 10000         |
# | time_elapsed       | 49.1          |
# | total_timesteps    | 40320         |
# | value_loss         | 72.20499      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.173256e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0844        |
# | fps                | 806           |
# | nupdates           | 41            |
# | policy_entropy     | 5.682198      |
# | policy_loss        | -0.0001329598 |
# | serial_timesteps   | 10250         |
# | time_elapsed       | 50.3          |
# | total_timesteps    | 41328         |
# | value_loss         | 72.349915     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0014007846  |
# | clipfrac           | 0.00725       |
# | explained_variance | 0.204         |
# | fps                | 849           |
# | nupdates           | 42            |
# | policy_entropy     | 5.6804814     |
# | policy_loss        | -0.0043222406 |
# | serial_timesteps   | 10500         |
# | time_elapsed       | 51.6          |
# | total_timesteps    | 42336         |
# | value_loss         | 0.083780676   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0011171858   |
# | clipfrac           | 0.001          |
# | explained_variance | 0.453          |
# | fps                | 757            |
# | nupdates           | 43             |
# | policy_entropy     | 5.6794887      |
# | policy_loss        | -0.00026089727 |
# | serial_timesteps   | 10750          |
# | time_elapsed       | 52.8           |
# | total_timesteps    | 43344          |
# | value_loss         | 0.809459       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0005522465  |
# | clipfrac           | 0.00025       |
# | explained_variance | 0.0589        |
# | fps                | 776           |
# | nupdates           | 44            |
# | policy_entropy     | 5.681355      |
# | policy_loss        | -0.0028991294 |
# | serial_timesteps   | 11000         |
# | time_elapsed       | 54.1          |
# | total_timesteps    | 44352         |
# | value_loss         | 20.77796      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.004844984   |
# | clipfrac           | 0.061750002   |
# | explained_variance | 0.156         |
# | fps                | 776           |
# | nupdates           | 45            |
# | policy_entropy     | 5.6816325     |
# | policy_loss        | -0.0054525123 |
# | serial_timesteps   | 11250         |
# | time_elapsed       | 55.4          |
# | total_timesteps    | 45360         |
# | value_loss         | 0.16279097    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00027153007  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.366          |
# | fps                | 786            |
# | nupdates           | 46             |
# | policy_entropy     | 5.6813197      |
# | policy_loss        | -0.00042371312 |
# | serial_timesteps   | 11500          |
# | time_elapsed       | 56.7           |
# | total_timesteps    | 46368          |
# | value_loss         | 0.14923888     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00053265644 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0778        |
# | fps                | 760           |
# | nupdates           | 47            |
# | policy_entropy     | 5.6836615     |
# | policy_loss        | -4.312117e-05 |
# | serial_timesteps   | 11750         |
# | time_elapsed       | 57.9          |
# | total_timesteps    | 47376         |
# | value_loss         | 73.99603      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.3925251e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0989         |
# | fps                | 751            |
# | nupdates           | 48             |
# | policy_entropy     | 5.6846986      |
# | policy_loss        | -9.2990274e-05 |
# | serial_timesteps   | 12000          |
# | time_elapsed       | 59.3           |
# | total_timesteps    | 48384          |
# | value_loss         | 72.95222       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 6.575013e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.122         |
# | fps                | 737           |
# | nupdates           | 49            |
# | policy_entropy     | 5.6855173     |
# | policy_loss        | -1.280741e-05 |
# | serial_timesteps   | 12250         |
# | time_elapsed       | 60.6          |
# | total_timesteps    | 49392         |
# | value_loss         | 71.0794       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00034425262 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.121         |
# | fps                | 744           |
# | nupdates           | 50            |
# | policy_entropy     | 5.6868286     |
# | policy_loss        | -0.0003714508 |
# | serial_timesteps   | 12500         |
# | time_elapsed       | 62            |
# | total_timesteps    | 50400         |
# | value_loss         | 105.49446     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 6.9186215e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.144          |
# | fps                | 730            |
# | nupdates           | 51             |
# | policy_entropy     | 5.687723       |
# | policy_loss        | -0.00032278325 |
# | serial_timesteps   | 12750          |
# | time_elapsed       | 63.3           |
# | total_timesteps    | 51408          |
# | value_loss         | 110.24062      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00020456783 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0954        |
# | fps                | 733           |
# | nupdates           | 52            |
# | policy_entropy     | 5.686908      |
# | policy_loss        | -5.604148e-05 |
# | serial_timesteps   | 13000         |
# | time_elapsed       | 64.7          |
# | total_timesteps    | 52416         |
# | value_loss         | 214.1842      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.0121131e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.176         |
# | fps                | 764           |
# | nupdates           | 53            |
# | policy_entropy     | 5.6869435     |
# | policy_loss        | -0.0005127323 |
# | serial_timesteps   | 13250         |
# | time_elapsed       | 66            |
# | total_timesteps    | 53424         |
# | value_loss         | 35.64587      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.7726076e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.155         |
# | fps                | 791           |
# | nupdates           | 54            |
# | policy_entropy     | 5.6882544     |
# | policy_loss        | 7.724085e-05  |
# | serial_timesteps   | 13500         |
# | time_elapsed       | 67.4          |
# | total_timesteps    | 54432         |
# | value_loss         | 99.79555      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00012764051  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.125          |
# | fps                | 774            |
# | nupdates           | 55             |
# | policy_entropy     | 5.6892557      |
# | policy_loss        | -0.00023432077 |
# | serial_timesteps   | 13750          |
# | time_elapsed       | 68.6           |
# | total_timesteps    | 55440          |
# | value_loss         | 137.88852      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0001663997   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.128          |
# | fps                | 824            |
# | nupdates           | 56             |
# | policy_entropy     | 5.6890216      |
# | policy_loss        | -0.00030438713 |
# | serial_timesteps   | 14000          |
# | time_elapsed       | 69.9           |
# | total_timesteps    | 56448          |
# | value_loss         | 142.31699      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00014592947 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.154         |
# | fps                | 834           |
# | nupdates           | 57            |
# | policy_entropy     | 5.689426      |
# | policy_loss        | -0.0010023594 |
# | serial_timesteps   | 14250         |
# | time_elapsed       | 71.1          |
# | total_timesteps    | 57456         |
# | value_loss         | 22.380821     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00018607752  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.883          |
# | fps                | 813            |
# | nupdates           | 58             |
# | policy_entropy     | 5.69107        |
# | policy_loss        | -0.00086866703 |
# | serial_timesteps   | 14500          |
# | time_elapsed       | 72.3           |
# | total_timesteps    | 58464          |
# | value_loss         | 0.3230996      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0015123782  |
# | clipfrac           | 0.0065        |
# | explained_variance | 0.917         |
# | fps                | 791           |
# | nupdates           | 59            |
# | policy_entropy     | 5.6916337     |
# | policy_loss        | -0.0025670507 |
# | serial_timesteps   | 14750         |
# | time_elapsed       | 73.6          |
# | total_timesteps    | 59472         |
# | value_loss         | 0.16373831    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00061971514  |
# | clipfrac           | 0.0005         |
# | explained_variance | 0.839          |
# | fps                | 862            |
# | nupdates           | 60             |
# | policy_entropy     | 5.691741       |
# | policy_loss        | -0.00082766777 |
# | serial_timesteps   | 15000          |
# | time_elapsed       | 74.8           |
# | total_timesteps    | 60480          |
# | value_loss         | 0.44372395     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0011044457  |
# | clipfrac           | 0.0025        |
# | explained_variance | 0.122         |
# | fps                | 799           |
# | nupdates           | 61            |
# | policy_entropy     | 5.692318      |
# | policy_loss        | -0.0003936338 |
# | serial_timesteps   | 15250         |
# | time_elapsed       | 76            |
# | total_timesteps    | 61488         |
# | value_loss         | 204.86348     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0025882586 |
# | clipfrac           | 0.024        |
# | explained_variance | 0.226        |
# | fps                | 849          |
# | nupdates           | 62           |
# | policy_entropy     | 5.6921334    |
# | policy_loss        | -0.004202494 |
# | serial_timesteps   | 15500        |
# | time_elapsed       | 77.3         |
# | total_timesteps    | 62496        |
# | value_loss         | 0.25780633   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0026397307  |
# | clipfrac           | 0.022         |
# | explained_variance | 0.749         |
# | fps                | 810           |
# | nupdates           | 63            |
# | policy_entropy     | 5.689882      |
# | policy_loss        | -0.0049543804 |
# | serial_timesteps   | 15750         |
# | time_elapsed       | 78.4          |
# | total_timesteps    | 63504         |
# | value_loss         | 0.07321389    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005756013  |
# | clipfrac           | 0.00075       |
# | explained_variance | 0.158         |
# | fps                | 788           |
# | nupdates           | 64            |
# | policy_entropy     | 5.687773      |
# | policy_loss        | -0.0010041534 |
# | serial_timesteps   | 16000         |
# | time_elapsed       | 79.7          |
# | total_timesteps    | 64512         |
# | value_loss         | 35.40347      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.541504e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.186          |
# | fps                | 843            |
# | nupdates           | 65             |
# | policy_entropy     | 5.6891203      |
# | policy_loss        | -0.00026094576 |
# | serial_timesteps   | 16250          |
# | time_elapsed       | 80.9           |
# | total_timesteps    | 65520          |
# | value_loss         | 33.6575        |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 6.212934e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.169         |
# | fps                | 788           |
# | nupdates           | 66            |
# | policy_entropy     | 5.691618      |
# | policy_loss        | -9.272204e-06 |
# | serial_timesteps   | 16500         |
# | time_elapsed       | 82.1          |
# | total_timesteps    | 66528         |
# | value_loss         | 88.063065     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0057038735 |
# | clipfrac           | 0.08050001   |
# | explained_variance | 0.294        |
# | fps                | 813          |
# | nupdates           | 67           |
# | policy_entropy     | 5.6906853    |
# | policy_loss        | -0.009619281 |
# | serial_timesteps   | 16750        |
# | time_elapsed       | 83.4         |
# | total_timesteps    | 67536        |
# | value_loss         | 0.04495144   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0062150033 |
# | clipfrac           | 0.08725      |
# | explained_variance | -0.196       |
# | fps                | 808          |
# | nupdates           | 68           |
# | policy_entropy     | 5.6819983    |
# | policy_loss        | -0.007854064 |
# | serial_timesteps   | 17000        |
# | time_elapsed       | 84.6         |
# | total_timesteps    | 68544        |
# | value_loss         | 0.09045635   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0005684532 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.233        |
# | fps                | 823          |
# | nupdates           | 69           |
# | policy_entropy     | 5.6712723    |
# | policy_loss        | 0.0005406153 |
# | serial_timesteps   | 17250        |
# | time_elapsed       | 85.9         |
# | total_timesteps    | 69552        |
# | value_loss         | 32.532494    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00036450813 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.183         |
# | fps                | 802           |
# | nupdates           | 70            |
# | policy_entropy     | 5.6682343     |
# | policy_loss        | -0.0025541817 |
# | serial_timesteps   | 17500         |
# | time_elapsed       | 87.1          |
# | total_timesteps    | 70560         |
# | value_loss         | 33.80604      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00083198526 |
# | clipfrac           | 0.002         |
# | explained_variance | 0.581         |
# | fps                | 813           |
# | nupdates           | 71            |
# | policy_entropy     | 5.665975      |
# | policy_loss        | -0.0010707922 |
# | serial_timesteps   | 17750         |
# | time_elapsed       | 88.3          |
# | total_timesteps    | 71568         |
# | value_loss         | 0.10705403    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0035012923  |
# | clipfrac           | 0.036         |
# | explained_variance | 0.413         |
# | fps                | 805           |
# | nupdates           | 72            |
# | policy_entropy     | 5.6641426     |
# | policy_loss        | -0.0043055275 |
# | serial_timesteps   | 18000         |
# | time_elapsed       | 89.6          |
# | total_timesteps    | 72576         |
# | value_loss         | 0.6628063     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0018689173  |
# | clipfrac           | 0.0135        |
# | explained_variance | 0.347         |
# | fps                | 788           |
# | nupdates           | 73            |
# | policy_entropy     | 5.663837      |
# | policy_loss        | -0.0034098797 |
# | serial_timesteps   | 18250         |
# | time_elapsed       | 90.8          |
# | total_timesteps    | 73584         |
# | value_loss         | 0.046681736   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0020327019  |
# | clipfrac           | 0.01475       |
# | explained_variance | 0.552         |
# | fps                | 795           |
# | nupdates           | 74            |
# | policy_entropy     | 5.659107      |
# | policy_loss        | -0.0034017358 |
# | serial_timesteps   | 18500         |
# | time_elapsed       | 92.1          |
# | total_timesteps    | 74592         |
# | value_loss         | 0.2129956     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013910264  |
# | clipfrac           | 0.0057499995  |
# | explained_variance | 0.493         |
# | fps                | 836           |
# | nupdates           | 75            |
# | policy_entropy     | 5.657838      |
# | policy_loss        | -0.0010093427 |
# | serial_timesteps   | 18750         |
# | time_elapsed       | 93.4          |
# | total_timesteps    | 75600         |
# | value_loss         | 0.055633977   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004011826  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.12          |
# | fps                | 766           |
# | nupdates           | 76            |
# | policy_entropy     | 5.6598015     |
# | policy_loss        | 0.00045941427 |
# | serial_timesteps   | 19000         |
# | time_elapsed       | 94.6          |
# | total_timesteps    | 76608         |
# | value_loss         | 105.571045    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.471148e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0952         |
# | fps                | 778            |
# | nupdates           | 77             |
# | policy_entropy     | 5.6620784      |
# | policy_loss        | -0.00020204857 |
# | serial_timesteps   | 19250          |
# | time_elapsed       | 95.9           |
# | total_timesteps    | 77616          |
# | value_loss         | 114.74494      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0041325763  |
# | clipfrac           | 0.05625       |
# | explained_variance | 0.305         |
# | fps                | 814           |
# | nupdates           | 78            |
# | policy_entropy     | 5.6610765     |
# | policy_loss        | -0.0054505207 |
# | serial_timesteps   | 19500         |
# | time_elapsed       | 97.2          |
# | total_timesteps    | 78624         |
# | value_loss         | 0.028279632   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0018244595  |
# | clipfrac           | 0.010749999   |
# | explained_variance | 0.123         |
# | fps                | 831           |
# | nupdates           | 79            |
# | policy_entropy     | 5.652226      |
# | policy_loss        | -0.0031659324 |
# | serial_timesteps   | 19750         |
# | time_elapsed       | 98.4          |
# | total_timesteps    | 79632         |
# | value_loss         | 0.032866474   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0032063571 |
# | clipfrac           | 0.02975      |
# | explained_variance | -0.0421      |
# | fps                | 771          |
# | nupdates           | 80           |
# | policy_entropy     | 5.642788     |
# | policy_loss        | -0.004558313 |
# | serial_timesteps   | 20000        |
# | time_elapsed       | 99.6         |
# | total_timesteps    | 80640        |
# | value_loss         | 0.03936811   |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0028567286 |
# | clipfrac           | 0.02725      |
# | explained_variance | 0.541        |
# | fps                | 825          |
# | nupdates           | 81           |
# | policy_entropy     | 5.636346     |
# | policy_loss        | -0.00336825  |
# | serial_timesteps   | 20250        |
# | time_elapsed       | 101          |
# | total_timesteps    | 81648        |
# | value_loss         | 0.038824923  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0009794567  |
# | clipfrac           | 0.0022500001  |
# | explained_variance | 0.574         |
# | fps                | 803           |
# | nupdates           | 82            |
# | policy_entropy     | 5.629918      |
# | policy_loss        | -0.0018974512 |
# | serial_timesteps   | 20500         |
# | time_elapsed       | 102           |
# | total_timesteps    | 82656         |
# | value_loss         | 0.24874206    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0013941549  |
# | clipfrac           | 0.0037500001  |
# | explained_variance | 0.802         |
# | fps                | 806           |
# | nupdates           | 83            |
# | policy_entropy     | 5.625696      |
# | policy_loss        | -0.0015863875 |
# | serial_timesteps   | 20750         |
# | time_elapsed       | 103           |
# | total_timesteps    | 83664         |
# | value_loss         | 0.02677069    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0041488023  |
# | clipfrac           | 0.049         |
# | explained_variance | 0.611         |
# | fps                | 801           |
# | nupdates           | 84            |
# | policy_entropy     | 5.6247444     |
# | policy_loss        | -0.0047277138 |
# | serial_timesteps   | 21000         |
# | time_elapsed       | 105           |
# | total_timesteps    | 84672         |
# | value_loss         | 0.0540998     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00076397764 |
# | clipfrac           | 0.00075       |
# | explained_variance | 0.56          |
# | fps                | 795           |
# | nupdates           | 85            |
# | policy_entropy     | 5.623909      |
# | policy_loss        | -0.0013164865 |
# | serial_timesteps   | 21250         |
# | time_elapsed       | 106           |
# | total_timesteps    | 85680         |
# | value_loss         | 0.7982113     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0040134587  |
# | clipfrac           | 0.04675       |
# | explained_variance | 0.371         |
# | fps                | 793           |
# | nupdates           | 86            |
# | policy_entropy     | 5.6217833     |
# | policy_loss        | -0.0057684314 |
# | serial_timesteps   | 21500         |
# | time_elapsed       | 107           |
# | total_timesteps    | 86688         |
# | value_loss         | 0.020200929   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.002846406   |
# | clipfrac           | 0.02575       |
# | explained_variance | 0.464         |
# | fps                | 819           |
# | nupdates           | 87            |
# | policy_entropy     | 5.614146      |
# | policy_loss        | -0.0034653598 |
# | serial_timesteps   | 21750         |
# | time_elapsed       | 108           |
# | total_timesteps    | 87696         |
# | value_loss         | 0.047925245   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0008396385  |
# | clipfrac           | 0.00125       |
# | explained_variance | 0.206         |
# | fps                | 825           |
# | nupdates           | 88            |
# | policy_entropy     | 5.60647       |
# | policy_loss        | -0.0016056281 |
# | serial_timesteps   | 22000         |
# | time_elapsed       | 110           |
# | total_timesteps    | 88704         |
# | value_loss         | 0.045811877   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0037097624 |
# | clipfrac           | 0.042        |
# | explained_variance | 0.373        |
# | fps                | 792          |
# | nupdates           | 89           |
# | policy_entropy     | 5.598366     |
# | policy_loss        | -0.003030933 |
# | serial_timesteps   | 22250        |
# | time_elapsed       | 111          |
# | total_timesteps    | 89712        |
# | value_loss         | 0.033217173  |
# -------------------------------------
# -------------------------------------
# ...
# | policy_entropy     | 5.589503      |
# | policy_loss        | -0.0016231511 |
# | serial_timesteps   | 32500         |
# | time_elapsed       | 162           |
# | total_timesteps    | 131040        |
# | value_loss         | 0.27895746    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.001393703   |
# | clipfrac           | 0.0037500001  |
# | explained_variance | 0.543         |
# | fps                | 786           |
# | nupdates           | 131           |
# | policy_entropy     | 5.587889      |
# | policy_loss        | -0.0011804511 |
# | serial_timesteps   | 32750         |
# | time_elapsed       | 163           |
# | total_timesteps    | 132048        |
# | value_loss         | 0.63443613    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023233047 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.222         |
# | fps                | 818           |
# | nupdates           | 132           |
# | policy_entropy     | 5.584803      |
# | policy_loss        | 0.00022665251 |
# | serial_timesteps   | 33000         |
# | time_elapsed       | 164           |
# | total_timesteps    | 133056        |
# | value_loss         | 31.962137     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.7307395e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.273         |
# | fps                | 737           |
# | nupdates           | 133           |
# | policy_entropy     | 5.58411       |
# | policy_loss        | 0.00028163634 |
# | serial_timesteps   | 33250         |
# | time_elapsed       | 166           |
# | total_timesteps    | 134064        |
# | value_loss         | 60.08737      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011103019 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.246         |
# | fps                | 783           |
# | nupdates           | 134           |
# | policy_entropy     | 5.584235      |
# | policy_loss        | 0.00045973077 |
# | serial_timesteps   | 33500         |
# | time_elapsed       | 167           |
# | total_timesteps    | 135072        |
# | value_loss         | 91.37781      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00014624784  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.177          |
# | fps                | 795            |
# | nupdates           | 135            |
# | policy_entropy     | 5.5838823      |
# | policy_loss        | -5.7428613e-05 |
# | serial_timesteps   | 33750          |
# | time_elapsed       | 168            |
# | total_timesteps    | 136080         |
# | value_loss         | 98.26601       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00012401547  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00922        |
# | fps                | 785            |
# | nupdates           | 136            |
# | policy_entropy     | 5.5827074      |
# | policy_loss        | -0.00029661803 |
# | serial_timesteps   | 34000          |
# | time_elapsed       | 170            |
# | total_timesteps    | 137088         |
# | value_loss         | 71.693375      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.478773e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.181         |
# | fps                | 810           |
# | nupdates           | 137           |
# | policy_entropy     | 5.5822883     |
# | policy_loss        | -0.0005515446 |
# | serial_timesteps   | 34250         |
# | time_elapsed       | 171           |
# | total_timesteps    | 138096        |
# | value_loss         | 62.74022      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00026533    |
# | clipfrac           | 0.0           |
# | explained_variance | 0.299         |
# | fps                | 771           |
# | nupdates           | 138           |
# | policy_entropy     | 5.5827293     |
# | policy_loss        | -0.0006610259 |
# | serial_timesteps   | 34500         |
# | time_elapsed       | 172           |
# | total_timesteps    | 139104        |
# | value_loss         | 30.342724     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00027263898 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.237         |
# | fps                | 787           |
# | nupdates           | 139           |
# | policy_entropy     | 5.583276      |
# | policy_loss        | 4.5581997e-05 |
# | serial_timesteps   | 34750         |
# | time_elapsed       | 173           |
# | total_timesteps    | 140112        |
# | value_loss         | 31.666508     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.212015e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.265         |
# | fps                | 779           |
# | nupdates           | 140           |
# | policy_entropy     | 5.5839915     |
# | policy_loss        | 3.8997816e-05 |
# | serial_timesteps   | 35000         |
# | time_elapsed       | 175           |
# | total_timesteps    | 141120        |
# | value_loss         | 61.898323     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00036804698 |
# | clipfrac           | 0.00025       |
# | explained_variance | 0.283         |
# | fps                | 773           |
# | nupdates           | 141           |
# | policy_entropy     | 5.584545      |
# | policy_loss        | -0.003335552  |
# | serial_timesteps   | 35250         |
# | time_elapsed       | 176           |
# | total_timesteps    | 142128        |
# | value_loss         | 23.701126     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0008922081  |
# | clipfrac           | 0.001         |
# | explained_variance | -0.0478       |
# | fps                | 794           |
# | nupdates           | 142           |
# | policy_entropy     | 5.584707      |
# | policy_loss        | -0.0019966094 |
# | serial_timesteps   | 35500         |
# | time_elapsed       | 177           |
# | total_timesteps    | 143136        |
# | value_loss         | 82.10503      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00039320675 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.329         |
# | fps                | 813           |
# | nupdates           | 143           |
# | policy_entropy     | 5.5854645     |
# | policy_loss        | -0.002012836  |
# | serial_timesteps   | 35750         |
# | time_elapsed       | 178           |
# | total_timesteps    | 144144        |
# | value_loss         | 29.567501     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0034480018 |
# | clipfrac           | 0.0355       |
# | explained_variance | 0.785        |
# | fps                | 843          |
# | nupdates           | 144          |
# | policy_entropy     | 5.5860763    |
# | policy_loss        | -0.005690648 |
# | serial_timesteps   | 36000        |
# | time_elapsed       | 180          |
# | total_timesteps    | 145152       |
# | value_loss         | 0.33274674   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0026700564  |
# | clipfrac           | 0.02425       |
# | explained_variance | 0.896         |
# | fps                | 868           |
# | nupdates           | 145           |
# | policy_entropy     | 5.584085      |
# | policy_loss        | -0.0045312266 |
# | serial_timesteps   | 36250         |
# | time_elapsed       | 181           |
# | total_timesteps    | 146160        |
# | value_loss         | 0.14495197    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0006884933  |
# | clipfrac           | 0.00025       |
# | explained_variance | 0.457         |
# | fps                | 823           |
# | nupdates           | 146           |
# | policy_entropy     | 5.584723      |
# | policy_loss        | -0.0012821164 |
# | serial_timesteps   | 36500         |
# | time_elapsed       | 182           |
# | total_timesteps    | 147168        |
# | value_loss         | 0.37136197    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.005012266   |
# | clipfrac           | 0.066         |
# | explained_variance | 0.75          |
# | fps                | 864           |
# | nupdates           | 147           |
# | policy_entropy     | 5.5821033     |
# | policy_loss        | -0.0046379385 |
# | serial_timesteps   | 36750         |
# | time_elapsed       | 183           |
# | total_timesteps    | 148176        |
# | value_loss         | 0.14455383    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0015966641  |
# | clipfrac           | 0.00625       |
# | explained_variance | 0.34          |
# | fps                | 799           |
# | nupdates           | 148           |
# | policy_entropy     | 5.578298      |
# | policy_loss        | -0.0020052928 |
# | serial_timesteps   | 37000         |
# | time_elapsed       | 184           |
# | total_timesteps    | 149184        |
# | value_loss         | 0.060422286   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0030204132  |
# | clipfrac           | 0.024         |
# | explained_variance | 0.314         |
# | fps                | 766           |
# | nupdates           | 149           |
# | policy_entropy     | 5.574598      |
# | policy_loss        | -0.0023938215 |
# | serial_timesteps   | 37250         |
# | time_elapsed       | 186           |
# | total_timesteps    | 150192        |
# | value_loss         | 0.19256325    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0005102344 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.294        |
# | fps                | 765          |
# | nupdates           | 150          |
# | policy_entropy     | 5.5698047    |
# | policy_loss        | -0.000880264 |
# | serial_timesteps   | 37500        |
# | time_elapsed       | 187          |
# | total_timesteps    | 151200       |
# | value_loss         | 31.718378    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.0001468785   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.347          |
# | fps                | 791            |
# | nupdates           | 151            |
# | policy_entropy     | 5.567215       |
# | policy_loss        | -0.00026856034 |
# | serial_timesteps   | 37750          |
# | time_elapsed       | 188            |
# | total_timesteps    | 152208         |
# | value_loss         | 30.537308      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00025597741 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.258         |
# | fps                | 827           |
# | nupdates           | 152           |
# | policy_entropy     | 5.567278      |
# | policy_loss        | -0.0006157991 |
# | serial_timesteps   | 38000         |
# | time_elapsed       | 190           |
# | total_timesteps    | 153216        |
# | value_loss         | 31.144562     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0026457491  |
# | clipfrac           | 0.023000002   |
# | explained_variance | 0.739         |
# | fps                | 830           |
# | nupdates           | 153           |
# | policy_entropy     | 5.5666914     |
# | policy_loss        | -0.0043724054 |
# | serial_timesteps   | 38250         |
# | time_elapsed       | 191           |
# | total_timesteps    | 154224        |
# | value_loss         | 0.07623012    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00079259183 |
# | clipfrac           | 0.00025       |
# | explained_variance | 0.297         |
# | fps                | 792           |
# | nupdates           | 154           |
# | policy_entropy     | 5.565693      |
# | policy_loss        | 0.0007409556  |
# | serial_timesteps   | 38500         |
# | time_elapsed       | 192           |
# | total_timesteps    | 155232        |
# | value_loss         | 30.072975     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.7288736e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.316         |
# | fps                | 808           |
# | nupdates           | 155           |
# | policy_entropy     | 5.5678387     |
# | policy_loss        | 0.00032474304 |
# | serial_timesteps   | 38750         |
# | time_elapsed       | 193           |
# | total_timesteps    | 156240        |
# | value_loss         | 58.75136      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.002107839  |
# | clipfrac           | 0.014999999  |
# | explained_variance | 0.579        |
# | fps                | 801          |
# | nupdates           | 156          |
# | policy_entropy     | 5.569949     |
# | policy_loss        | -0.003691812 |
# | serial_timesteps   | 39000        |
# | time_elapsed       | 194          |
# | total_timesteps    | 157248       |
# | value_loss         | 0.06705787   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0021130315  |
# | clipfrac           | 0.01725       |
# | explained_variance | 0.96          |
# | fps                | 818           |
# | nupdates           | 157           |
# | policy_entropy     | 5.5703425     |
# | policy_loss        | -0.0029592214 |
# | serial_timesteps   | 39250         |
# | time_elapsed       | 196           |
# | total_timesteps    | 158256        |
# | value_loss         | 0.2255966     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.003013009  |
# | clipfrac           | 0.0295       |
# | explained_variance | 0.243        |
# | fps                | 776          |
# | nupdates           | 158          |
# | policy_entropy     | 5.5710306    |
# | policy_loss        | -0.004944686 |
# | serial_timesteps   | 39500        |
# | time_elapsed       | 197          |
# | total_timesteps    | 159264       |
# | value_loss         | 3.528227     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.006009288   |
# | clipfrac           | 0.080249995   |
# | explained_variance | 0.652         |
# | fps                | 844           |
# | nupdates           | 159           |
# | policy_entropy     | 5.571402      |
# | policy_loss        | -0.0044637513 |
# | serial_timesteps   | 39750         |
# | time_elapsed       | 198           |
# | total_timesteps    | 160272        |
# | value_loss         | 0.051756322   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005042845  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.316         |
# | fps                | 809           |
# | nupdates           | 160           |
# | policy_entropy     | 5.572501      |
# | policy_loss        | -0.0007836386 |
# | serial_timesteps   | 40000         |
# | time_elapsed       | 199           |
# | total_timesteps    | 161280        |
# | value_loss         | 29.621738     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0016697234  |
# | clipfrac           | 0.00575       |
# | explained_variance | 0.748         |
# | fps                | 821           |
# | nupdates           | 161           |
# | policy_entropy     | 5.572948      |
# | policy_loss        | -0.0020626131 |
# | serial_timesteps   | 40250         |
# | time_elapsed       | 201           |
# | total_timesteps    | 162288        |
# | value_loss         | 0.06384941    |
# --------------------------------------

# %%
from stable_baselines.common.policies import FeedForwardPolicy

# %%
model = PPO2.load(final_model_dir)

# Enjoy trained agent
env = gym.make(env_name)
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
