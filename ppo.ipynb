# %%
import os
import gym
from IPython import display
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import SubprocVecEnv
from stable_baselines.common.vec_env import DummyVecEnv
from utils.ppo import PPO
from utils.models import Policy

# %%
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
LOGS = os.getcwd()

# %%
def makedirs(path):
    if not os.path.exists(path):
        os.makedirs(path)

# %%
env_name = 'MountainCarContinuous-v0'
run_id = 1
n_steps = 250
total_timesteps = 1000000

LOGS = os.path.join(LOGS, env_name, 'run{}'.format(run_id))
makedirs(LOGS)
tb_log = os.path.join(LOGS, 'tb')
makedirs(tb_log)
model_dir = os.path.join(LOGS, 'models')
makedirs(model_dir)
final_model_dir = os.path.join(LOGS, 'model')
n_cpu = 4

# %%
env = SubprocVecEnv([lambda: gym.make(env_name) for i in range(n_cpu)])

model = PPO(Policy, env, n_steps=n_steps, tensorboard_log=tb_log, verbose=1, full_tensorboard_log=True)
model.learn(total_timesteps, env, save_file=os.path.join(model_dir, 'model'))
model.save(final_model_dir)
del model # remove to demonstrate saving and loading
# Out:
# INFO:tensorflow:Summary name model/pi_fc0/w:0 is illegal; using model/pi_fc0/w_0 instead.
# INFO:tensorflow:Summary name model/pi_fc0/b:0 is illegal; using model/pi_fc0/b_0 instead.
# INFO:tensorflow:Summary name model/vf_fc0/w:0 is illegal; using model/vf_fc0/w_0 instead.
# INFO:tensorflow:Summary name model/vf_fc0/b:0 is illegal; using model/vf_fc0/b_0 instead.
# INFO:tensorflow:Summary name model/pi_fc1/w:0 is illegal; using model/pi_fc1/w_0 instead.
# INFO:tensorflow:Summary name model/pi_fc1/b:0 is illegal; using model/pi_fc1/b_0 instead.
# INFO:tensorflow:Summary name model/vf_fc1/w:0 is illegal; using model/vf_fc1/w_0 instead.
# INFO:tensorflow:Summary name model/vf_fc1/b:0 is illegal; using model/vf_fc1/b_0 instead.
# INFO:tensorflow:Summary name model/vf/w:0 is illegal; using model/vf/w_0 instead.
# INFO:tensorflow:Summary name model/vf/b:0 is illegal; using model/vf/b_0 instead.
# INFO:tensorflow:Summary name model/pi/w:0 is illegal; using model/pi/w_0 instead.
# INFO:tensorflow:Summary name model/pi/b:0 is illegal; using model/pi/b_0 instead.
# INFO:tensorflow:Summary name model/pi/logstd:0 is illegal; using model/pi/logstd_0 instead.
# INFO:tensorflow:Summary name model/q/w:0 is illegal; using model/q/w_0 instead.
# INFO:tensorflow:Summary name model/q/b:0 is illegal; using model/q/b_0 instead.
# INFO:tensorflow:Summary name model/pi_fc0/w:0/gradient is illegal; using model/pi_fc0/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc0/b:0/gradient is illegal; using model/pi_fc0/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc0/w:0/gradient is illegal; using model/vf_fc0/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc0/b:0/gradient is illegal; using model/vf_fc0/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc1/w:0/gradient is illegal; using model/pi_fc1/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi_fc1/b:0/gradient is illegal; using model/pi_fc1/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc1/w:0/gradient is illegal; using model/vf_fc1/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf_fc1/b:0/gradient is illegal; using model/vf_fc1/b_0/gradient instead.
# INFO:tensorflow:Summary name model/vf/w:0/gradient is illegal; using model/vf/w_0/gradient instead.
# INFO:tensorflow:Summary name model/vf/b:0/gradient is illegal; using model/vf/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/w:0/gradient is illegal; using model/pi/w_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/b:0/gradient is illegal; using model/pi/b_0/gradient instead.
# INFO:tensorflow:Summary name model/pi/logstd:0/gradient is illegal; using model/pi/logstd_0/gradient instead.
# No of updates: 1000
# Total timesteps : 1000000
# Batch size: 1000
# ---------------------------------------
# | approxkl           | 2.4643901e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.1           |
# | fps                | 603            |
# | nupdates           | 1              |
# | policy_entropy     | 1.4171939      |
# | policy_loss        | -0.00038083387 |
# | serial_timesteps   | 250            |
# | time_elapsed       | 0.00017        |
# | total_timesteps    | 1008           |
# | value_loss         | 0.27227548     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.8646795e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00141      |
# | fps                | 1119          |
# | nupdates           | 2             |
# | policy_entropy     | 1.4133189     |
# | policy_loss        | -0.0008025287 |
# | serial_timesteps   | 500           |
# | time_elapsed       | 1.66          |
# | total_timesteps    | 2016          |
# | value_loss         | 0.26508492    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 6.006518e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00747        |
# | fps                | 1098           |
# | nupdates           | 3              |
# | policy_entropy     | 1.4098756      |
# | policy_loss        | -0.00039228812 |
# | serial_timesteps   | 750            |
# | time_elapsed       | 2.56           |
# | total_timesteps    | 3024           |
# | value_loss         | 42.819393      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 3.7077913e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0138         |
# | fps                | 1089           |
# | nupdates           | 4              |
# | policy_entropy     | 1.4088756      |
# | policy_loss        | -0.00038451471 |
# | serial_timesteps   | 1000           |
# | time_elapsed       | 3.47           |
# | total_timesteps    | 4032           |
# | value_loss         | 42.79821       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 7.562573e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00146        |
# | fps                | 1116           |
# | nupdates           | 5              |
# | policy_entropy     | 1.4084228      |
# | policy_loss        | -0.00054620754 |
# | serial_timesteps   | 1250           |
# | time_elapsed       | 4.39           |
# | total_timesteps    | 5040           |
# | value_loss         | 0.23644067     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 6.314374e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.309         |
# | fps                | 1093           |
# | nupdates           | 6              |
# | policy_entropy     | 1.4056494      |
# | policy_loss        | -0.00036316886 |
# | serial_timesteps   | 1500           |
# | time_elapsed       | 5.29           |
# | total_timesteps    | 6048           |
# | value_loss         | 0.20729372     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00014794058 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.142         |
# | fps                | 1076          |
# | nupdates           | 7             |
# | policy_entropy     | 1.4022523     |
# | policy_loss        | -0.0008223155 |
# | serial_timesteps   | 1750          |
# | time_elapsed       | 6.21          |
# | total_timesteps    | 7056          |
# | value_loss         | 0.19420314    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016572383 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.35         |
# | fps                | 1110          |
# | nupdates           | 8             |
# | policy_entropy     | 1.3995304     |
# | policy_loss        | -0.0001528409 |
# | serial_timesteps   | 2000          |
# | time_elapsed       | 7.14          |
# | total_timesteps    | 8064          |
# | value_loss         | 0.29902452    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 9.843972e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.597         |
# | fps                | 1151           |
# | nupdates           | 9              |
# | policy_entropy     | 1.396916       |
# | policy_loss        | -0.00011500961 |
# | serial_timesteps   | 2250           |
# | time_elapsed       | 8.05           |
# | total_timesteps    | 9072           |
# | value_loss         | 0.12307276     |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 6.927644e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.836       |
# | fps                | 1032         |
# | nupdates           | 10           |
# | policy_entropy     | 1.3944979    |
# | policy_loss        | -0.000407563 |
# | serial_timesteps   | 2500         |
# | time_elapsed       | 8.92         |
# | total_timesteps    | 10080        |
# | value_loss         | 0.18786035   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00058748154 |
# | clipfrac           | 0.00075       |
# | explained_variance | -1.13         |
# | fps                | 1040          |
# | nupdates           | 11            |
# | policy_entropy     | 1.3924811     |
# | policy_loss        | -0.0012601324 |
# | serial_timesteps   | 2750          |
# | time_elapsed       | 9.89          |
# | total_timesteps    | 11088         |
# | value_loss         | 0.26214993    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013409875 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.678        |
# | fps                | 1096          |
# | nupdates           | 12            |
# | policy_entropy     | 1.3922168     |
# | policy_loss        | 0.00029280435 |
# | serial_timesteps   | 3000          |
# | time_elapsed       | 10.9          |
# | total_timesteps    | 12096         |
# | value_loss         | 0.2138084     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.961658e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.596         |
# | fps                | 1022           |
# | nupdates           | 13             |
# | policy_entropy     | 1.3919744      |
# | policy_loss        | -0.00027413017 |
# | serial_timesteps   | 3250           |
# | time_elapsed       | 11.8           |
# | total_timesteps    | 13104          |
# | value_loss         | 0.12668937     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00023731196  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.523         |
# | fps                | 1063           |
# | nupdates           | 14             |
# | policy_entropy     | 1.3895757      |
# | policy_loss        | -0.00058033835 |
# | serial_timesteps   | 3500           |
# | time_elapsed       | 12.8           |
# | total_timesteps    | 14112          |
# | value_loss         | 0.15627268     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00015609851  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.421         |
# | fps                | 1174           |
# | nupdates           | 15             |
# | policy_entropy     | 1.3885485      |
# | policy_loss        | -0.00027726401 |
# | serial_timesteps   | 3750           |
# | time_elapsed       | 13.7           |
# | total_timesteps    | 15120          |
# | value_loss         | 0.23254581     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 8.579356e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.291         |
# | fps                | 1089           |
# | nupdates           | 16             |
# | policy_entropy     | 1.3888466      |
# | policy_loss        | -0.00055055646 |
# | serial_timesteps   | 4000           |
# | time_elapsed       | 14.6           |
# | total_timesteps    | 16128          |
# | value_loss         | 0.23820016     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00021286414 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.03         |
# | fps                | 1187          |
# | nupdates           | 17            |
# | policy_entropy     | 1.3884445     |
# | policy_loss        | -9.137891e-05 |
# | serial_timesteps   | 4250          |
# | time_elapsed       | 15.5          |
# | total_timesteps    | 17136         |
# | value_loss         | 0.05730349    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 6.844163e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -1.21          |
# | fps                | 1104           |
# | nupdates           | 18             |
# | policy_entropy     | 1.3849015      |
# | policy_loss        | -0.00044952676 |
# | serial_timesteps   | 4500           |
# | time_elapsed       | 16.3           |
# | total_timesteps    | 18144          |
# | value_loss         | 0.094896786    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 6.670959e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.393         |
# | fps                | 998            |
# | nupdates           | 19             |
# | policy_entropy     | 1.3810835      |
# | policy_loss        | -0.00022237533 |
# | serial_timesteps   | 4750           |
# | time_elapsed       | 17.2           |
# | total_timesteps    | 19152          |
# | value_loss         | 0.26103535     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00012920916 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.23         |
# | fps                | 1125          |
# | nupdates           | 20            |
# | policy_entropy     | 1.3790808     |
# | policy_loss        | -8.821135e-05 |
# | serial_timesteps   | 5000          |
# | time_elapsed       | 18.2          |
# | total_timesteps    | 20160         |
# | value_loss         | 0.3921022     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.755344e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -1.65          |
# | fps                | 1075           |
# | nupdates           | 21             |
# | policy_entropy     | 1.3769207      |
# | policy_loss        | -0.00044200983 |
# | serial_timesteps   | 5250           |
# | time_elapsed       | 19.1           |
# | total_timesteps    | 21168          |
# | value_loss         | 0.08521116     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.2791906e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.794         |
# | fps                | 1061           |
# | nupdates           | 22             |
# | policy_entropy     | 1.37261        |
# | policy_loss        | -0.00011458486 |
# | serial_timesteps   | 5500           |
# | time_elapsed       | 20.1           |
# | total_timesteps    | 22176          |
# | value_loss         | 0.10890663     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00023902091 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.192        |
# | fps                | 1067          |
# | nupdates           | 23            |
# | policy_entropy     | 1.3694148     |
# | policy_loss        | -0.0007512966 |
# | serial_timesteps   | 5750          |
# | time_elapsed       | 21            |
# | total_timesteps    | 23184         |
# | value_loss         | 0.1472886     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.837926e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.096        |
# | fps                | 1035          |
# | nupdates           | 24            |
# | policy_entropy     | 1.3672485     |
# | policy_loss        | 0.00010432201 |
# | serial_timesteps   | 6000          |
# | time_elapsed       | 22            |
# | total_timesteps    | 24192         |
# | value_loss         | 0.26518357    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.1958757e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.727         |
# | fps                | 1095           |
# | nupdates           | 25             |
# | policy_entropy     | 1.3648938      |
# | policy_loss        | -0.00012765566 |
# | serial_timesteps   | 6250           |
# | time_elapsed       | 22.9           |
# | total_timesteps    | 25200          |
# | value_loss         | 0.05311566     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 5.762128e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.955         |
# | fps                | 1030           |
# | nupdates           | 26             |
# | policy_entropy     | 1.3631475      |
# | policy_loss        | -0.00014431943 |
# | serial_timesteps   | 6500           |
# | time_elapsed       | 23.8           |
# | total_timesteps    | 26208          |
# | value_loss         | 0.096868515    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.8377657e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0343         |
# | fps                | 1123           |
# | nupdates           | 27             |
# | policy_entropy     | 1.3625687      |
# | policy_loss        | -0.00015209871 |
# | serial_timesteps   | 6750           |
# | time_elapsed       | 24.8           |
# | total_timesteps    | 27216          |
# | value_loss         | 0.16493243     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 4.4274697e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0983        |
# | fps                | 1036          |
# | nupdates           | 28            |
# | policy_entropy     | 1.3623475     |
# | policy_loss        | 4.124376e-05  |
# | serial_timesteps   | 7000          |
# | time_elapsed       | 25.7          |
# | total_timesteps    | 28224         |
# | value_loss         | 0.250048      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.34986e-05   |
# | clipfrac           | 0.0           |
# | explained_variance | -0.914        |
# | fps                | 1046          |
# | nupdates           | 29            |
# | policy_entropy     | 1.3596253     |
# | policy_loss        | -0.0005518995 |
# | serial_timesteps   | 7250          |
# | time_elapsed       | 26.7          |
# | total_timesteps    | 29232         |
# | value_loss         | 0.021274276   |
# --------------------------------------
# ----------------------------------------
# | approxkl           | 2.8318573e-05   |
# | clipfrac           | 0.0             |
# | explained_variance | -0.739          |
# | fps                | 1057            |
# | nupdates           | 30              |
# | policy_entropy     | 1.354842        |
# | policy_loss        | -0.000103468585 |
# | serial_timesteps   | 7500            |
# | time_elapsed       | 27.6            |
# | total_timesteps    | 30240           |
# | value_loss         | 0.051297504     |
# ----------------------------------------
# ---------------------------------------
# | approxkl           | 1.567735e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.192         |
# | fps                | 1029           |
# | nupdates           | 31             |
# | policy_entropy     | 1.3515832      |
# | policy_loss        | -2.4239362e-05 |
# | serial_timesteps   | 7750           |
# | time_elapsed       | 28.6           |
# | total_timesteps    | 31248          |
# | value_loss         | 0.13199174     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00033880546 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.261        |
# | fps                | 1145          |
# | nupdates           | 32            |
# | policy_entropy     | 1.3500512     |
# | policy_loss        | -0.001255374  |
# | serial_timesteps   | 8000          |
# | time_elapsed       | 29.6          |
# | total_timesteps    | 32256         |
# | value_loss         | 0.30053803    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020428817 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.03         |
# | fps                | 1040          |
# | nupdates           | 33            |
# | policy_entropy     | 1.3480345     |
# | policy_loss        | 5.9019465e-05 |
# | serial_timesteps   | 8250          |
# | time_elapsed       | 30.4          |
# | total_timesteps    | 33264         |
# | value_loss         | 0.041355863   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.1317224e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.801         |
# | fps                | 1053           |
# | nupdates           | 34             |
# | policy_entropy     | 1.3442928      |
# | policy_loss        | -0.00030306142 |
# | serial_timesteps   | 8500           |
# | time_elapsed       | 31.4           |
# | total_timesteps    | 34272          |
# | value_loss         | 0.050735965    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00023685666  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.344         |
# | fps                | 1033           |
# | nupdates           | 35             |
# | policy_entropy     | 1.3406316      |
# | policy_loss        | -0.00080191315 |
# | serial_timesteps   | 8750           |
# | time_elapsed       | 32.4           |
# | total_timesteps    | 35280          |
# | value_loss         | 0.13628945     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.0002562983   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0724         |
# | fps                | 1022           |
# | nupdates           | 36             |
# | policy_entropy     | 1.3383478      |
# | policy_loss        | -0.00041098258 |
# | serial_timesteps   | 9000           |
# | time_elapsed       | 33.3           |
# | total_timesteps    | 36288          |
# | value_loss         | 0.26617092     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.1519633e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.767        |
# | fps                | 1080          |
# | nupdates           | 37            |
# | policy_entropy     | 1.3353678     |
# | policy_loss        | -0.0003611731 |
# | serial_timesteps   | 9250          |
# | time_elapsed       | 34.3          |
# | total_timesteps    | 37296         |
# | value_loss         | 0.016654355   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.9836704e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.741         |
# | fps                | 1044           |
# | nupdates           | 38             |
# | policy_entropy     | 1.3299211      |
# | policy_loss        | -0.00059472024 |
# | serial_timesteps   | 9500           |
# | time_elapsed       | 35.2           |
# | total_timesteps    | 38304          |
# | value_loss         | 0.022380074    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00036545223 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0369       |
# | fps                | 1045          |
# | nupdates           | 39            |
# | policy_entropy     | 1.3249242     |
# | policy_loss        | -0.0013903074 |
# | serial_timesteps   | 9750          |
# | time_elapsed       | 36.2          |
# | total_timesteps    | 39312         |
# | value_loss         | 0.102693215   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.493446e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0786       |
# | fps                | 1082          |
# | nupdates           | 40            |
# | policy_entropy     | 1.321587      |
# | policy_loss        | 0.00041888314 |
# | serial_timesteps   | 10000         |
# | time_elapsed       | 37.2          |
# | total_timesteps    | 40320         |
# | value_loss         | 0.2618566     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.668688e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0713        |
# | fps                | 1040          |
# | nupdates           | 41            |
# | policy_entropy     | 1.3191773     |
# | policy_loss        | -0.0003917804 |
# | serial_timesteps   | 10250         |
# | time_elapsed       | 38.1          |
# | total_timesteps    | 41328         |
# | value_loss         | 0.0132110305  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.2482553e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.627        |
# | fps                | 1094          |
# | nupdates           | 42            |
# | policy_entropy     | 1.3137196     |
# | policy_loss        | -0.0005810595 |
# | serial_timesteps   | 10500         |
# | time_elapsed       | 39            |
# | total_timesteps    | 42336         |
# | value_loss         | 0.028712      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00048368747 |
# | clipfrac           | 0.0005        |
# | explained_variance | -0.0631       |
# | fps                | 1150          |
# | nupdates           | 43            |
# | policy_entropy     | 1.3087504     |
# | policy_loss        | -0.0016260635 |
# | serial_timesteps   | 10750         |
# | time_elapsed       | 40            |
# | total_timesteps    | 43344         |
# | value_loss         | 0.10512736    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003274093  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.002         |
# | fps                | 1107          |
# | nupdates           | 44            |
# | policy_entropy     | 1.3068849     |
# | policy_loss        | -0.0004101209 |
# | serial_timesteps   | 11000         |
# | time_elapsed       | 40.8          |
# | total_timesteps    | 44352         |
# | value_loss         | 0.23629628    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.2568543e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.275         |
# | fps                | 1087           |
# | nupdates           | 45             |
# | policy_entropy     | 1.3053087      |
# | policy_loss        | -0.00045985042 |
# | serial_timesteps   | 11250          |
# | time_elapsed       | 41.7           |
# | total_timesteps    | 45360          |
# | value_loss         | 0.011458207    |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 9.203947e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.378       |
# | fps                | 1117         |
# | nupdates           | 46           |
# | policy_entropy     | 1.2988728    |
# | policy_loss        | -0.001723777 |
# | serial_timesteps   | 11500        |
# | time_elapsed       | 42.7         |
# | total_timesteps    | 46368        |
# | value_loss         | 0.0100072855 |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 8.4950254e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0171        |
# | fps                | 1031           |
# | nupdates           | 47             |
# | policy_entropy     | 1.2913752      |
# | policy_loss        | -0.00054287515 |
# | serial_timesteps   | 11750          |
# | time_elapsed       | 43.6           |
# | total_timesteps    | 47376          |
# | value_loss         | 0.09435795     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 4.228903e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00634      |
# | fps                | 1096          |
# | nupdates           | 48            |
# | policy_entropy     | 1.2872632     |
# | policy_loss        | 2.8085196e-07 |
# | serial_timesteps   | 12000         |
# | time_elapsed       | 44.5          |
# | total_timesteps    | 48384         |
# | value_loss         | 0.22359811    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.109337e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0872         |
# | fps                | 1088           |
# | nupdates           | 49             |
# | policy_entropy     | 1.2844247      |
# | policy_loss        | -0.00064390374 |
# | serial_timesteps   | 12250          |
# | time_elapsed       | 45.5           |
# | total_timesteps    | 49392          |
# | value_loss         | 0.0076361997   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.8556852e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0773        |
# | fps                | 1093          |
# | nupdates           | 50            |
# | policy_entropy     | 1.2778268     |
# | policy_loss        | -0.0013966438 |
# | serial_timesteps   | 12500         |
# | time_elapsed       | 46.4          |
# | total_timesteps    | 50400         |
# | value_loss         | 0.007732039   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.123508e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0671         |
# | fps                | 1143           |
# | nupdates           | 51             |
# | policy_entropy     | 1.2711438      |
# | policy_loss        | -0.00035476196 |
# | serial_timesteps   | 12750          |
# | time_elapsed       | 47.3           |
# | total_timesteps    | 51408          |
# | value_loss         | 0.079947904    |
# ---------------------------------------
# ----------------------------------------
# | approxkl           | 5.836765e-06    |
# | clipfrac           | 0.0             |
# | explained_variance | -0.0211         |
# | fps                | 1080            |
# | nupdates           | 52              |
# | policy_entropy     | 1.2673148       |
# | policy_loss        | -0.000118756274 |
# | serial_timesteps   | 13000           |
# | time_elapsed       | 48.2            |
# | total_timesteps    | 52416           |
# | value_loss         | 0.22617635      |
# ----------------------------------------
# --------------------------------------
# | approxkl           | 5.965888e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.11         |
# | fps                | 1074          |
# | nupdates           | 53            |
# | policy_entropy     | 1.2642016     |
# | policy_loss        | -0.0005878113 |
# | serial_timesteps   | 13250         |
# | time_elapsed       | 49.1          |
# | total_timesteps    | 53424         |
# | value_loss         | 0.008611141   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.6107526e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0565       |
# | fps                | 1065          |
# | nupdates           | 54            |
# | policy_entropy     | 1.258201      |
# | policy_loss        | -0.0010965385 |
# | serial_timesteps   | 13500         |
# | time_elapsed       | 50            |
# | total_timesteps    | 54432         |
# | value_loss         | 0.0077474937  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.7976253e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0383         |
# | fps                | 1134           |
# | nupdates           | 55             |
# | policy_entropy     | 1.2524014      |
# | policy_loss        | -0.00024097635 |
# | serial_timesteps   | 13750          |
# | time_elapsed       | 51             |
# | total_timesteps    | 55440          |
# | value_loss         | 0.08252658     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 5.539498e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0376         |
# | fps                | 1086           |
# | nupdates           | 56             |
# | policy_entropy     | 1.2492197      |
# | policy_loss        | -0.00044377433 |
# | serial_timesteps   | 14000          |
# | time_elapsed       | 51.9           |
# | total_timesteps    | 56448          |
# | value_loss         | 0.20272738     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 7.450641e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0156        |
# | fps                | 1088           |
# | nupdates           | 57             |
# | policy_entropy     | 1.2463658      |
# | policy_loss        | -0.00077301863 |
# | serial_timesteps   | 14250          |
# | time_elapsed       | 52.8           |
# | total_timesteps    | 57456          |
# | value_loss         | 0.008028575    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.5531673e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.194        |
# | fps                | 1072          |
# | nupdates           | 58            |
# | policy_entropy     | 1.2401495     |
# | policy_loss        | -0.0012072057 |
# | serial_timesteps   | 14500         |
# | time_elapsed       | 53.7          |
# | total_timesteps    | 58464         |
# | value_loss         | 0.008934203   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013656332 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0291       |
# | fps                | 1077          |
# | nupdates           | 59            |
# | policy_entropy     | 1.2344714     |
# | policy_loss        | -0.0005668286 |
# | serial_timesteps   | 14750         |
# | time_elapsed       | 54.6          |
# | total_timesteps    | 59472         |
# | value_loss         | 0.07746485    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.498443e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0138        |
# | fps                | 1116          |
# | nupdates           | 60            |
# | policy_entropy     | 1.2322708     |
# | policy_loss        | 0.00011959973 |
# | serial_timesteps   | 15000         |
# | time_elapsed       | 55.6          |
# | total_timesteps    | 60480         |
# | value_loss         | 45.91621      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.32257e-06   |
# | clipfrac           | 0.0           |
# | explained_variance | -0.169        |
# | fps                | 1017          |
# | nupdates           | 61            |
# | policy_entropy     | 1.2303951     |
# | policy_loss        | -0.0006043467 |
# | serial_timesteps   | 15250         |
# | time_elapsed       | 56.5          |
# | total_timesteps    | 61488         |
# | value_loss         | 0.010532533   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.9529603e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.146        |
# | fps                | 1105          |
# | nupdates           | 62            |
# | policy_entropy     | 1.2244859     |
# | policy_loss        | -0.0011089696 |
# | serial_timesteps   | 15500         |
# | time_elapsed       | 57.5          |
# | total_timesteps    | 62496         |
# | value_loss         | 0.0074425084  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.7483544e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0579        |
# | fps                | 1064          |
# | nupdates           | 63            |
# | policy_entropy     | 1.2186743     |
# | policy_loss        | -0.0002471638 |
# | serial_timesteps   | 15750         |
# | time_elapsed       | 58.4          |
# | total_timesteps    | 63504         |
# | value_loss         | 0.07027127    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.7645506e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0407        |
# | fps                | 1027          |
# | nupdates           | 64            |
# | policy_entropy     | 1.2156463     |
# | policy_loss        | -0.0004537868 |
# | serial_timesteps   | 16000         |
# | time_elapsed       | 59.3          |
# | total_timesteps    | 64512         |
# | value_loss         | 0.2016188     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000118519645 |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0281        |
# | fps                | 1147           |
# | nupdates           | 65             |
# | policy_entropy     | 1.2129546      |
# | policy_loss        | -0.00089278095 |
# | serial_timesteps   | 16250          |
# | time_elapsed       | 60.3           |
# | total_timesteps    | 65520          |
# | value_loss         | 0.0072565414   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.2415379e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0885        |
# | fps                | 1071          |
# | nupdates           | 66            |
# | policy_entropy     | 1.2074852     |
# | policy_loss        | -0.0008955644 |
# | serial_timesteps   | 16500         |
# | time_elapsed       | 61.2          |
# | total_timesteps    | 66528         |
# | value_loss         | 0.007118455   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.6241202e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.253          |
# | fps                | 1043           |
# | nupdates           | 67             |
# | policy_entropy     | 1.2019112      |
# | policy_loss        | -0.00036694153 |
# | serial_timesteps   | 16750          |
# | time_elapsed       | 62.1           |
# | total_timesteps    | 67536          |
# | value_loss         | 0.073372975    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.7990502e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0117       |
# | fps                | 1039          |
# | nupdates           | 68            |
# | policy_entropy     | 1.1986165     |
# | policy_loss        | 9.128541e-06  |
# | serial_timesteps   | 17000         |
# | time_elapsed       | 63.1          |
# | total_timesteps    | 68544         |
# | value_loss         | 0.2042722     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.7456484e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0922        |
# | fps                | 1041          |
# | nupdates           | 69            |
# | policy_entropy     | 1.1963308     |
# | policy_loss        | -0.0010777779 |
# | serial_timesteps   | 17250         |
# | time_elapsed       | 64            |
# | total_timesteps    | 69552         |
# | value_loss         | 0.007939875   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 2.145752e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.062        |
# | fps                | 1090         |
# | nupdates           | 70           |
# | policy_entropy     | 1.1911463    |
# | policy_loss        | -0.000575781 |
# | serial_timesteps   | 17500        |
# | time_elapsed       | 65           |
# | total_timesteps    | 70560        |
# | value_loss         | 0.00791922   |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 5.367247e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0682         |
# | fps                | 1025           |
# | nupdates           | 71             |
# | policy_entropy     | 1.1863452      |
# | policy_loss        | -0.00018055845 |
# | serial_timesteps   | 17750          |
# | time_elapsed       | 65.9           |
# | total_timesteps    | 71568          |
# | value_loss         | 0.06650109     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.5723276e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.032         |
# | fps                | 1084          |
# | nupdates           | 72            |
# | policy_entropy     | 1.1847693     |
# | policy_loss        | 6.7245946e-07 |
# | serial_timesteps   | 18000         |
# | time_elapsed       | 66.9          |
# | total_timesteps    | 72576         |
# | value_loss         | 0.17557536    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.0416227e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0635       |
# | fps                | 1042          |
# | nupdates           | 73            |
# | policy_entropy     | 1.1838353     |
# | policy_loss        | -0.0005242441 |
# | serial_timesteps   | 18250         |
# | time_elapsed       | 67.8          |
# | total_timesteps    | 73584         |
# | value_loss         | 0.006443668   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.5452204e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.202         |
# | fps                | 1018           |
# | nupdates           | 74             |
# | policy_entropy     | 1.1786153      |
# | policy_loss        | -0.00095739117 |
# | serial_timesteps   | 18500          |
# | time_elapsed       | 68.8           |
# | total_timesteps    | 74592          |
# | value_loss         | 0.009477506    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 4.015109e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0393         |
# | fps                | 1057           |
# | nupdates           | 75             |
# | policy_entropy     | 1.1735996      |
# | policy_loss        | -0.00028238603 |
# | serial_timesteps   | 18750          |
# | time_elapsed       | 69.8           |
# | total_timesteps    | 75600          |
# | value_loss         | 0.07268472     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.8044271e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0306        |
# | fps                | 1066           |
# | nupdates           | 76             |
# | policy_entropy     | 1.1712         |
# | policy_loss        | -0.00015268072 |
# | serial_timesteps   | 19000          |
# | time_elapsed       | 70.7           |
# | total_timesteps    | 76608          |
# | value_loss         | 0.18759874     |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 6.970368e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -0.128       |
# | fps                | 1119         |
# | nupdates           | 77           |
# | policy_entropy     | 1.168732     |
# | policy_loss        | -0.001076065 |
# | serial_timesteps   | 19250        |
# | time_elapsed       | 71.7         |
# | total_timesteps    | 77616        |
# | value_loss         | 0.0071364553 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 2.1442134e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.154        |
# | fps                | 1119          |
# | nupdates           | 78            |
# | policy_entropy     | 1.1631868     |
# | policy_loss        | -0.0012003391 |
# | serial_timesteps   | 19500         |
# | time_elapsed       | 72.6          |
# | total_timesteps    | 78624         |
# | value_loss         | 0.008783837   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.7134115e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0273        |
# | fps                | 1072          |
# | nupdates           | 79            |
# | policy_entropy     | 1.1573305     |
# | policy_loss        | -0.0004725065 |
# | serial_timesteps   | 19750         |
# | time_elapsed       | 73.4          |
# | total_timesteps    | 79632         |
# | value_loss         | 0.06624466    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.6766811e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0442        |
# | fps                | 1076          |
# | nupdates           | 80            |
# | policy_entropy     | 1.1540614     |
# | policy_loss        | -0.0001574552 |
# | serial_timesteps   | 20000         |
# | time_elapsed       | 74.4          |
# | total_timesteps    | 80640         |
# | value_loss         | 0.1737674     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.5102875e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.027          |
# | fps                | 1050           |
# | nupdates           | 81             |
# | policy_entropy     | 1.1513832      |
# | policy_loss        | -0.00054476596 |
# | serial_timesteps   | 20250          |
# | time_elapsed       | 75.3           |
# | total_timesteps    | 81648          |
# | value_loss         | 0.006222193    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.3501507e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0674       |
# | fps                | 1105          |
# | nupdates           | 82            |
# | policy_entropy     | 1.1461779     |
# | policy_loss        | -0.0010120097 |
# | serial_timesteps   | 20500         |
# | time_elapsed       | 76.3          |
# | total_timesteps    | 82656         |
# | value_loss         | 0.0079067955  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.57192e-05    |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0454        |
# | fps                | 1047           |
# | nupdates           | 83             |
# | policy_entropy     | 1.1404148      |
# | policy_loss        | -0.00056961464 |
# | serial_timesteps   | 20750          |
# | time_elapsed       | 77.2           |
# | total_timesteps    | 83664          |
# | value_loss         | 0.071977       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.0701253e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0421        |
# | fps                | 1089          |
# | nupdates           | 84            |
# | policy_entropy     | 1.1367372     |
# | policy_loss        | 1.0025265e-05 |
# | serial_timesteps   | 21000         |
# | time_elapsed       | 78.1          |
# | total_timesteps    | 84672         |
# | value_loss         | 0.1595132     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.3961635e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.107         |
# | fps                | 1154           |
# | nupdates           | 85             |
# | policy_entropy     | 1.1346262      |
# | policy_loss        | -0.00065145345 |
# | serial_timesteps   | 21250          |
# | time_elapsed       | 79.1           |
# | total_timesteps    | 85680          |
# | value_loss         | 0.008554637    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.5564076e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0374       |
# | fps                | 1066          |
# | nupdates           | 86            |
# | policy_entropy     | 1.1298368     |
# | policy_loss        | -0.001050932  |
# | serial_timesteps   | 21500         |
# | time_elapsed       | 79.9          |
# | total_timesteps    | 86688         |
# | value_loss         | 0.005662053   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.00749685e-05 |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0569        |
# | fps                | 1083           |
# | nupdates           | 87             |
# | policy_entropy     | 1.1242166      |
# | policy_loss        | -0.00056644436 |
# | serial_timesteps   | 21750          |
# | time_elapsed       | 80.9           |
# | total_timesteps    | 87696          |
# | value_loss         | 0.07153423     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 9.809002e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0388         |
# | fps                | 1038           |
# | nupdates           | 88             |
# | policy_entropy     | 1.1202615      |
# | policy_loss        | -0.00023548913 |
# | serial_timesteps   | 22000          |
# | time_elapsed       | 81.8           |
# | total_timesteps    | 88704          |
# | value_loss         | 0.16174684     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00018394177 |
# | clipfrac           | 0.0           |
# ...
# | total_timesteps    | 976752        |
# | value_loss         | 3.8404826e-07 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016242477 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0202        |
# | fps                | 1054          |
# | nupdates           | 970           |
# | policy_entropy     | -1.8007424    |
# | policy_loss        | -0.0001418897 |
# | serial_timesteps   | 242500        |
# | time_elapsed       | 951           |
# | total_timesteps    | 977760        |
# | value_loss         | 2.300058e-06  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.7583332e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0338         |
# | fps                | 1037           |
# | nupdates           | 971            |
# | policy_entropy     | -1.8040642     |
# | policy_loss        | -0.00046792708 |
# | serial_timesteps   | 242750         |
# | time_elapsed       | 952            |
# | total_timesteps    | 978768         |
# | value_loss         | 3.56736e-06    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 4.7671587e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0048         |
# | fps                | 1091           |
# | nupdates           | 972            |
# | policy_entropy     | -1.8072724     |
# | policy_loss        | -0.00048778486 |
# | serial_timesteps   | 243000         |
# | time_elapsed       | 953            |
# | total_timesteps    | 979776         |
# | value_loss         | 2.450923e-06   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 3.485074e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0173        |
# | fps                | 1027           |
# | nupdates           | 973            |
# | policy_entropy     | -1.8111213     |
# | policy_loss        | -0.00087344396 |
# | serial_timesteps   | 243250         |
# | time_elapsed       | 954            |
# | total_timesteps    | 980784         |
# | value_loss         | 4.056071e-06   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00031788714 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00668      |
# | fps                | 1057          |
# | nupdates           | 974           |
# | policy_entropy     | -1.8147753    |
# | policy_loss        | -0.0011865009 |
# | serial_timesteps   | 243500        |
# | time_elapsed       | 955           |
# | total_timesteps    | 981792        |
# | value_loss         | 1.1885726e-06 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00060154335  |
# | clipfrac           | 0.00025        |
# | explained_variance | 0.0499         |
# | fps                | 1069           |
# | nupdates           | 975            |
# | policy_entropy     | -1.8178308     |
# | policy_loss        | -0.00058989687 |
# | serial_timesteps   | 243750         |
# | time_elapsed       | 956            |
# | total_timesteps    | 982800         |
# | value_loss         | 1.3194108e-06  |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.9954441e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0166         |
# | fps                | 1051           |
# | nupdates           | 976            |
# | policy_entropy     | -1.820437      |
# | policy_loss        | -0.00015440128 |
# | serial_timesteps   | 244000         |
# | time_elapsed       | 957            |
# | total_timesteps    | 983808         |
# | value_loss         | 1.0813651e-06  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0011367312  |
# | clipfrac           | 0.0019999999  |
# | explained_variance | -0.00465      |
# | fps                | 1056          |
# | nupdates           | 977           |
# | policy_entropy     | -1.8229146    |
# | policy_loss        | -0.0017892709 |
# | serial_timesteps   | 244250        |
# | time_elapsed       | 958           |
# | total_timesteps    | 984816        |
# | value_loss         | 3.255602e-07  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0003728401  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0305        |
# | fps                | 1025          |
# | nupdates           | 978           |
# | policy_entropy     | -1.826325     |
# | policy_loss        | -0.0006313928 |
# | serial_timesteps   | 244500        |
# | time_elapsed       | 958           |
# | total_timesteps    | 985824        |
# | value_loss         | 1.0446229e-06 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00034747252 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0951       |
# | fps                | 1052          |
# | nupdates           | 979           |
# | policy_entropy     | -1.8285019    |
# | policy_loss        | -8.002273e-06 |
# | serial_timesteps   | 244750        |
# | time_elapsed       | 959           |
# | total_timesteps    | 986832        |
# | value_loss         | 1.1661979e-06 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0014353278  |
# | clipfrac           | 0.0027500002  |
# | explained_variance | 0.00203       |
# | fps                | 1065          |
# | nupdates           | 980           |
# | policy_entropy     | -1.8306978    |
# | policy_loss        | -0.0007352756 |
# | serial_timesteps   | 245000        |
# | time_elapsed       | 960           |
# | total_timesteps    | 987840        |
# | value_loss         | 1.2346388e-06 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00010263772  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.000898      |
# | fps                | 1075           |
# | nupdates           | 981            |
# | policy_entropy     | -1.8335325     |
# | policy_loss        | -0.00048018456 |
# | serial_timesteps   | 245250         |
# | time_elapsed       | 961            |
# | total_timesteps    | 988848         |
# | value_loss         | 2.2085726e-07  |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0006665159 |
# | clipfrac           | 0.00075      |
# | explained_variance | 0.00276      |
# | fps                | 1109         |
# | nupdates           | 982          |
# | policy_entropy     | -1.8371931   |
# | policy_loss        | -0.001337591 |
# | serial_timesteps   | 245500       |
# | time_elapsed       | 962          |
# | total_timesteps    | 989856       |
# | value_loss         | 1.291048e-06 |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 7.043872e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00576       |
# | fps                | 1069           |
# | nupdates           | 983            |
# | policy_entropy     | -1.8401947     |
# | policy_loss        | -0.00024895513 |
# | serial_timesteps   | 245750         |
# | time_elapsed       | 963            |
# | total_timesteps    | 990864         |
# | value_loss         | 1.1393109e-06  |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 3.0410412e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00083        |
# | fps                | 1028           |
# | nupdates           | 984            |
# | policy_entropy     | -1.8432856     |
# | policy_loss        | -0.00036700565 |
# | serial_timesteps   | 246000         |
# | time_elapsed       | 964            |
# | total_timesteps    | 991872         |
# | value_loss         | 1.0131774e-06  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00048867264 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0234        |
# | fps                | 1116          |
# | nupdates           | 985           |
# | policy_entropy     | -1.8466921    |
# | policy_loss        | -0.0023147399 |
# | serial_timesteps   | 246250        |
# | time_elapsed       | 965           |
# | total_timesteps    | 992880        |
# | value_loss         | 1.8933756e-07 |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00011499829  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0418         |
# | fps                | 1068           |
# | nupdates           | 986            |
# | policy_entropy     | -1.8502468     |
# | policy_loss        | -0.00026287974 |
# | serial_timesteps   | 246500         |
# | time_elapsed       | 966            |
# | total_timesteps    | 993888         |
# | value_loss         | 1.402932e-06   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00039934315  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0571        |
# | fps                | 1085           |
# | nupdates           | 987            |
# | policy_entropy     | -1.8536949     |
# | policy_loss        | -0.00089702645 |
# | serial_timesteps   | 246750         |
# | time_elapsed       | 967            |
# | total_timesteps    | 994896         |
# | value_loss         | 3.6925744e-06  |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00027591304  |
# | clipfrac           | 0.0            |
# | explained_variance | 1.11e-05       |
# | fps                | 1031           |
# | nupdates           | 988            |
# | policy_entropy     | -1.8565991     |
# | policy_loss        | -0.00014842214 |
# | serial_timesteps   | 247000         |
# | time_elapsed       | 968            |
# | total_timesteps    | 995904         |
# | value_loss         | 2.1324975e-05  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 6.778686e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0785       |
# | fps                | 1036          |
# | nupdates           | 989           |
# | policy_entropy     | -1.8600568    |
# | policy_loss        | -0.0010295542 |
# | serial_timesteps   | 247250        |
# | time_elapsed       | 969           |
# | total_timesteps    | 996912        |
# | value_loss         | 5.373122e-05  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018917248 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0459       |
# | fps                | 1070          |
# | nupdates           | 990           |
# | policy_entropy     | -1.8637943    |
# | policy_loss        | -0.0007604269 |
# | serial_timesteps   | 247500        |
# | time_elapsed       | 970           |
# | total_timesteps    | 997920        |
# | value_loss         | 6.558934e-05  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00012582508 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0462       |
# | fps                | 1047          |
# | nupdates           | 991           |
# | policy_entropy     | -1.865608     |
# | policy_loss        | -0.0002266191 |
# | serial_timesteps   | 247750        |
# | time_elapsed       | 971           |
# | total_timesteps    | 998928        |
# | value_loss         | 8.383126e-05  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.9936326e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.032         |
# | fps                | 1097           |
# | nupdates           | 992            |
# | policy_entropy     | -1.8665047     |
# | policy_loss        | -4.1536197e-05 |
# | serial_timesteps   | 248000         |
# | time_elapsed       | 972            |
# | total_timesteps    | 999936         |
# | value_loss         | 3.5595058e-05  |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00038503503 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.32         |
# | fps                | 1043          |
# | nupdates           | 993           |
# | policy_entropy     | -1.8683863    |
# | policy_loss        | -0.0016357902 |
# | serial_timesteps   | 248250        |
# | time_elapsed       | 973           |
# | total_timesteps    | 1000944       |
# | value_loss         | 8.1981125e-05 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013253116 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00961      |
# | fps                | 1022          |
# | nupdates           | 994           |
# | policy_entropy     | -1.8711574    |
# | policy_loss        | 0.00028419754 |
# | serial_timesteps   | 248500        |
# | time_elapsed       | 974           |
# | total_timesteps    | 1001952       |
# | value_loss         | 7.471757e-05  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.3401942e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0358        |
# | fps                | 1098          |
# | nupdates           | 995           |
# | policy_entropy     | -1.8728803    |
# | policy_loss        | -0.0003255052 |
# | serial_timesteps   | 248750        |
# | time_elapsed       | 975           |
# | total_timesteps    | 1002960       |
# | value_loss         | 0.0001560147  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00026446622 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0804       |
# | fps                | 1076          |
# | nupdates           | 996           |
# | policy_entropy     | -1.8748633    |
# | policy_loss        | -0.0005348236 |
# | serial_timesteps   | 249000        |
# | time_elapsed       | 975           |
# | total_timesteps    | 1003968       |
# | value_loss         | 2.5185214e-05 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00022229148 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.149        |
# | fps                | 1036          |
# | nupdates           | 997           |
# | policy_entropy     | -1.8795015    |
# | policy_loss        | -0.0016356659 |
# | serial_timesteps   | 249250        |
# | time_elapsed       | 976           |
# | total_timesteps    | 1004976       |
# | value_loss         | 1.3238381e-05 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0008031347  |
# | clipfrac           | 0.0005        |
# | explained_variance | -0.0413       |
# | fps                | 1013          |
# | nupdates           | 998           |
# | policy_entropy     | -1.8836285    |
# | policy_loss        | -0.0008493281 |
# | serial_timesteps   | 249500        |
# | time_elapsed       | 977           |
# | total_timesteps    | 1005984       |
# | value_loss         | 6.8013687e-06 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00096596475 |
# | clipfrac           | 0.0019999999  |
# | explained_variance | -0.00613      |
# | fps                | 994           |
# | nupdates           | 999           |
# | policy_entropy     | -1.8856413    |
# | policy_loss        | -0.0026085603 |
# | serial_timesteps   | 249750        |
# | time_elapsed       | 978           |
# | total_timesteps    | 1006992       |
# | value_loss         | 5.0535677e-06 |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0008803947  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0203       |
# | fps                | 1028          |
# | nupdates           | 1000          |
# | policy_entropy     | -1.8874116    |
# | policy_loss        | 4.0823055e-05 |
# | serial_timesteps   | 250000        |
# | time_elapsed       | 979           |
# | total_timesteps    | 1008000       |
# | value_loss         | 8.413224e-07  |
# --------------------------------------

# %%
model = PPO.load(final_model_dir)

# Enjoy trained agent
env = gym.make(env_name)
obs = env.reset()
dones = False
while not dones:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    print(dones)
    env.render()
# Out:
# Loading a model without an environment, this model cannot be trained until it has a valid environment.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-4ad70c682bfc> in <module>()
#       6 dones = False
#       7 while not dones:
# ----> 8     action, _states = model.predict(obs)
#       9     obs, rewards, dones, info, mean, logstd = env.step(action)
#      10     print(dones)
#
# /home/auton-local/anaconda3/envs/carla9.4_py35/lib/python3.5/site-packages/stable_baselines/common/base_class.py in predict(self, observation, state, mask, deterministic)
#     720
#     721         observation = observation.reshape((-1,) + self.observation_space.shape)
# --> 722         actions, _, states, _ = self.step(observation, state, mask, deterministic=deterministic)
#     723
#     724         clipped_actions = actions
#
# ValueError: too many values to unpack (expected 4)
